# %%
import os
import re
import pandas as pd
import urllib
from nltk import SnowballStemmer
from gensim.models import Word2Vec
#import langdetect
import tika
import time
from tika import parser
import pickle

# %% [markdown]
# # Raw Articles pdf Data
# Convert pdf to text using Tika apache server

# %%
# specify the target data folder

target_dir = 'C:/Thesis/Data/European_Journal_of_work_and_OP'

# %%
# prep pdf extraction
pdf_files = []
wrd_files = []

for f in os.listdir(target_dir):
    if f.endswith(".pdf") | f.endswith(".PDF"):
        thispdf = os.path.join(target_dir, f)
        pdf_files = pdf_files + [thispdf]
    if f.endswith(".doc") | f.endswith(".docx") | f.endswith(".DOC") | f.endswith(".DOCX"):
        thiswrd = os.path.join(target_dir, f)
        wrd_files = wrd_files + [thiswrd]

# %%
port = 4321 # port to use for Tika server (chosen arbitrarily)
server_str = 'http://localhost:' + str(port)
tika_path  = 'C:\Software\ tika-server-1.23.jar'
tika_run   = 'java -jar' + tika_path + ' --port ' + str(port)
print('Command to start Tika:')
print(tika_run)
print('---')
print('Number of pdf files: ' + str(len(pdf_files)))
print('Number of word files: ' + str(len(wrd_files)))

# %%
# process the PDF files, store text in memory
tika.TikaClientOnly = True 

pdf_metadata = [parser.from_file(t, server_str, xmlContent=False)["metadata"] for t in (pdf_files + wrd_files)]

# %%
# save data metadata
pickle.dump(pdf_metadata, open( "C:/Thesis/Data/save/European_Journal_of_work_and_OP/metadata/metadata_all.p", "wb" ) )

# %% [markdown]
# # Text Data
#
# Eliminate title, sections (eg: content between Method and Discussion) and Reference. It is saved as a pre-processed data

# %%
# process the PDF files, store text in memory
tika.TikaClientOnly = True 

pdf_text = [parser.from_file(t, server_str, xmlContent=False)["content"] for t in (pdf_files + wrd_files)]

# %%
# save data
pickle.dump(pdf_text, open( "C:/Thesis/Data/save/Academy_of_MJ/save_alltextData.p", "wb" ) )

# %% [markdown]
# #  Load the Text data

# %%
import pickle
#load the text data
pdf_data = pickle.load(open("C:/Thesis/Data/save/European_Journal_of_work_and_OP/save_alltextData.p", "rb"))

# %%
len(pdf_data)
# Out:
# 647

# %% [markdown]
# #  Convert pdf text to lower case

# %%
#Convert each string to lowercase
pdf_text = []
for i in pdf_data:
    if i is not None:
        pdf_text.append(i.lower())

# %% [markdown]
# # Get country names

# %%
# Since it is case sensetive, firstly get the list of country before converting the text to lowercase
country_list = ['america', 'vietnam', 'usa']
import pycountry

for country in pycountry.countries:
    country_list.append(country.name.lower())

# %%
#Convert country list to lower case. it will be called in filter function
#country_lower = [x.lower() for x in country_list]
#print(country_list)

# %% [markdown]
# # Get city names (and additional countries)

# %%
from geotext import GeoText

cities_list = []
for i in pdf_text:
    place = GeoText(i)
    #print(place.cities)
    #print(place.countries)
    cities_list.append(place.cities + place.countries)

t = []
for i in cities_list:
    t += i
    
# print(len(t))    
    
cities_list = list(set(t))
# cities_list

# %%
#Convert cities list to lower case. it will be called in filter function
cities_lower =[]
for i in cities_list:
    #for j in i:
    cities_lower.append(i.lower())
print(len(cities_lower))
# Out:
# 0

# %% [markdown]
# # Excluding pdfs if it doesnot have the standard format
# check the standard format of pdf- if it contains method and discussion section or not

# %%
import re
pdf_included =[]
pdf_excluded =[]

for i in pdf_text:
    flag_1 = re.search(r'\n(general )?discussion\n', i)
    flag_2 = re.search(r'\nmethods?\n', i)
   
    if flag_1 and flag_2: 
        pdf_included.append(i)
     
    else:
        pdf_excluded.append(i)
len(pdf_included)
# Out:
# 452

# %%
len(pdf_excluded)
# Out:
# 194

# %%
# Within JM: acknowledgement section appears in two approaches:1: before or after keyword section (only few pdfs)
# 2: before reference section (maximum pdfs)
# thus, focusing on the majority occurance of acknowledgements before reference second, we removed it based on that condition.

# step-1 remove content after acknowledgements section( it will include appendix, reference section)
pdf_remove_step1 = [re.sub(r"(?is)\nacknowledgments\n.*", "", f) for f in pdf_included]

# step-2 if there is no acknowledgements section than start with appendix (it will include reference section.)
pdf_remove_step2 = [re.sub(r"(?is)\nappendix\n.*", "", f) for f in pdf_remove_step1]

# step-3 remove all from reference section
pdf_remove_step3 = [re.sub(r"(?is)\nreferences\n.*", "", f) for f in pdf_remove_step2]

# get the reference section
references = [re.sub(r"^(.|\n)+\nreferences\n", "", f) for f in pdf_included]

# %%
len(pdf_remove_step3)
# Out:
# 452

# %%
# step-4: remove content between method and discussion section (it contains method and result section)
def remove_method_result(method, discussion, text):
    
    import re    
    start = method
    end = discussion
    #start of pattern, followed by any number of times 'any character OR a newline' and terminated by the end pattern.
    #pattern = start + '.*'+'(.|\n)*'+end
    pattern = start +'(.|\n)*'+end
    #pdf_method_dis = [re.sub(pattern, '', f) for f in pdf_text]
    pdf_method_dis = re.sub(pattern, '', text)

    return pdf_method_dis

# %%
import re
#  remove method and result
pdf_remove_step4 = [remove_method_result('\nmethods?\n', '\n(general )?discussion\n', t) for t in pdf_remove_step3]

# %%
len(pdf_remove_step4)
# Out:
# 452

# %% [markdown]
# # Pre-processing
# Regular expression is used to clean up the data

# %%
# testing it works
ref_doc = 20
print(pdf_remove_step4[ref_doc])
print('--**************************************-')
print('-**************************************--')
print('-**************************************--')
# print(pdf_remove_step4[ref_doc])
# Out:
# capturing the noonday demon: development and validation of the state boredom inventory
#
#
# full terms & conditions of access and use can be found at
# https://www.tandfonline.com/action/journalinformation?journalcode=pewo20
#
# european journal of work and organizational psychology
#
# issn: 1359-432x (print) 1464-0643 (online) journal homepage: https://www.tandfonline.com/loi/pewo20
#
# capturing the noonday demon: development and
# validation of the state boredom inventory
#
# patricia l. baratta & jeffrey r. spence
#
# to cite this article: patricia l. baratta & jeffrey r. spence (2018) capturing the noonday demon:
# development and validation of the state boredom inventory, european journal of work and
# organizational psychology, 27:4, 477-492, doi: 10.1080/1359432x.2018.1481830
#
# to link to this article:  https://doi.org/10.1080/1359432x.2018.1481830
#
# view supplementary material
#
# published online: 05 jun 2018.
#
# submit your article to this journal
#
# article views: 371
#
# view related articles
#
# view crossmark data
#
# citing articles: 1 view citing articles
#
# https://www.tandfonline.com/action/journalinformation?journalcode=pewo20
# https://www.tandfonline.com/loi/pewo20
# https://www.tandfonline.com/action/showcitformats?doi=10.1080/1359432x.2018.1481830
# https://doi.org/10.1080/1359432x.2018.1481830
# https://www.tandfonline.com/doi/suppl/10.1080/1359432x.2018.1481830
# https://www.tandfonline.com/doi/suppl/10.1080/1359432x.2018.1481830
# https://www.tandfonline.com/action/authorsubmission?journalcode=pewo20&show=instructions
# https://www.tandfonline.com/action/authorsubmission?journalcode=pewo20&show=instructions
# https://www.tandfonline.com/doi/mlt/10.1080/1359432x.2018.1481830
# https://www.tandfonline.com/doi/mlt/10.1080/1359432x.2018.1481830
# http://crossmark.crossref.org/dialog/?doi=10.1080/1359432x.2018.1481830&domain=pdf&date_stamp=2018-06-05
# http://crossmark.crossref.org/dialog/?doi=10.1080/1359432x.2018.1481830&domain=pdf&date_stamp=2018-06-05
# https://www.tandfonline.com/doi/citedby/10.1080/1359432x.2018.1481830#tabmodule
# https://www.tandfonline.com/doi/citedby/10.1080/1359432x.2018.1481830#tabmodule
#
#
# capturing the noonday demon: development and validation of the state boredom
# inventory
# patricia l. baratta and jeffrey r. spence
#
# department of psychology, university of guelph, guelph, on, canada
#
# abstract
# for centuries, scholars have positioned state boredom as an impediment to organizational productivity
# and performance given its unpleasant and distracting qualities. however, research on state boredom
# has been impeded by a lack of definitional consensus and measurement issues. in this article, we
# sought to advance organizational research on state boredom by developing the state boredom
# inventory (sbi), an 11-item measure grounded in a theoretically derived definition of state boredom.
# across five studies using 10 independent samples, we develop the sbi and provide validity evidence for
# our measure, including content validity and convergent and discriminant validity. our data support the
# conceptualization of state boredom as a higher-order multidimensional construct with three underlying
# dimensions: disengagement, unpleasant low arousal, and inattention.
#
# article history
# received 27 october 2017
# accepted 21 may 2018
#
# keywords
# boredom; multidimensional;
# scale development; scale
# validation; diary study
#
# although sometimes viewed as a symptom of modernity,
# feeling bored has been studied as a part of the human condi-
# tion for centuries (jackson, 1981; wenzel, 1967). our modern
# understanding of state boredom originates from the greek
# word acedia (ἀκηδία), which translates to “without care” and
# was used to describe idleness with respect to religious duties
# beginning in the fourth century c.e. (peters, 1975; wenzel,
# 1967). acedia was considered to be one of eight vices and
# was closely tied to the avoidance of formal duties among
# catholic monks. nicknamed the “noonday demon”, acedia
# was thought to strike around midday, distracting monks
# from their work and tempting them to leave the monastery
# in search of stimulation (ponticus, 2006). catholic monk john
# cassian (2000) described acedia as making monks either idle
# or restless. he writes, “[acedia] either allows [the monk] to stay
# in his cell without any spiritual progress, in as it were a state of
# inactivity and surrender, or drives him out from there and
# makes him, in addition, unstable and feckless” (p. 221).
#
# these early accounts suggest that little has changed with
# respect to how people experience boredom at work. if
# cassian’s description of acedia were updated with references
# to contemporary workplaces, it might refer to “cubicles”
# instead of “cells” and rather than a “monk” being “unstable
# and feckless”, an “employee” might be “distracting and inef-
# fective”. the link between boredom and counterproductivity
# has carried through to today, with researchers recognizing
# that feeling bored may result in distraction at work. for exam-
# ple, trait boredom, or a chronic propensity to feel bored,
# relates to poor performance, absenteeism, turnover, withdra-
# wal, and deviance (bruusema, kessler, & spector, 2011; kass,
# vodanovich, & callendar, 2001; watt & hargis, 2010).
#
# despite etymological and contemporary associations
# between feeling bored and employee effectiveness,
#
# organizational research on state boredom is limited. this
# may be due to the fact that the organizational behaviour
# literature (and psychology more broadly) is wrought with
# divergent and sometimes contradictory definitions of feeling
# bored in addition to suboptimal scales (fisher, 1993; reijseger
# et al., 2013; vodanovich, 2003). we sought to contribute to
# organizational research on state boredom by developing a
# measure that is consistent with a theoretically derived defini-
# tion and that builds on the strengths of existing scales while
# addressing their limitations. in the sections discussed next, we
# synthesize theories and definitions of state boredom with the
# aim of building consensus towards a unifying definition. then
# we review how state boredom is typically measured, outline
# the implications for testing organizational theory, and explain
# why a new scale is needed. finally, using hinkin’s (1998)
# deductive approach to scale development, we provide valida-
# tion evidence for our measure across five studies using 10
# samples.
#
# defining state boredom
#
# the word boredom itself did not appear in the english lan-
# guage until the mid-19th century. dickens’s (1853/2003) novel
# bleak house is often cited as the first printed use of the term.
# despite the fact that the word “boredom” has been around for
# over 100 years and the concept (acedia) has been around for
# centuries, contemporary scholars have yet to agree on a defi-
# nition of feeling bored. in psychology, existing definitions
# diverge from one another quite severely. for example, it has
# been defined as “low arousal and dissatisfaction” (mikulas &
# vodanovich, 1993, p. 3), “subjective monotony and. . . frustra-
# tion” (hill & perkins, 1985, p. 235), “effortful maintenance of
# attention” (leary, rogers, canfield, & coe, 1986, p. 968), and
#
# contact patricia l. baratta pbaratta@uoguelph.ca
#
# european journal of work and organizational psychology
# 2018, vol. 27, no. 4, 477–492
# https://doi.org/10.1080/1359432x.2018.1481830
#
# © 2018 informa uk limited, trading as taylor & francis group
#
# http://www.tandfonline.com
# http://crossmark.crossref.org/dialog/?doi=10.1080/1359432x.2018.1481830&domain=pdf
#
#
# “feeling unchallenged and perceiving one’s activities as mean-
# ingless” (van tilburg & igou, 2012, p. 182). these examples
# illustrate that there can be little overlap in the content of
# many definitions, with some arguing for antithetical content
# (e.g., low arousal versus frustration).
#
# the absence of an accepted definition makes it difficult to
# build a theory on how state boredom relates to organizational
# variables because researchers who define it differently are
# essentially theorizing about different constructs. given the
# disparate content of these definitions, it is unlikely that
# researchers would expect each of these constructs to exhibit
# comparable associations with other variables. for example, an
# employee who experiences meaninglessness and lack of chal-
# lenge may demonstrate a very different pattern of behaviours
# than an employee who is frustrated. divergence in how bore-
# dom is defined limits researchers’ ability to build a unified
# theory identifying causes and outcomes of feeling bored as
# well as mechanisms explaining why it predicts certain
# variables.
#
# to resolve these inconsistencies, we conducted a compre-
# hensive review of the boredom literature to build consensus
# towards a definition. our definition integrates the most com-
# monly discussed and theoretically relevant components of
# state boredom. our review suggested that state boredom
# has been approached using multiple theoretical perspectives,
# primarily psychodynamic, arousal, and attentional theories
# (eren, 2016; fahlman, mercer-lynn, flora, & eastwood, 2013;
# raffaelli, mills, & christoff, 2017). we searched all peer-
# reviewed articles through the end of 2017 that specified
# “bored*” as a key word. our search resulted in 661 hits, of
# which 126 included a definition of boredom. we coded each
# definition based on its themes or components and identified
# four major themes—disengagement (n = 79; 63%), a negative
# or unpleasant state (n = 69; 55%), low arousal (n = 52; 41%),
# and inattention (n = 27; 21%)—and six infrequent themes—
# meaninglessness (n = 16; 13%), distorted time perception
# (n = 16; 13%), monotony (n = 7; 6%), attribution (n = 8; 6%),
# high arousal (n = 8; 6%), and feeling under-challenged (n = 6;
# 5%). in the next few sections, we review each major theme
# and integrate them into a definition of state boredom.
#
# state boredom and disengagement
#
# psychodynamic theorists consider state boredom to be an
# unpleasant state resulting from an unfulfilled urge for psychic
# stimulation (fenichel, 1951; gabriel, 1988; greenson, 1953;
# lewinsky, 1943). they propose that boredom serves as a
# defence mechanism that prevents individuals from acting on
# impulses. more specifically, bored individuals are thought to
# have an intense need for psychic stimulation, but cannot
# specify what they want because the urge has been uncon-
# sciously repressed. as a result, they experience dissatisfaction
# with their current situation and an aimless tension to engage
# in rewarding activity (fenichel, 1951; lewinsky, 1943). “this
# uncertainty and vagueness about one’s own wishes is. . . char-
# acteristic of boredom” (lewinsky, 1943, p. 148).
#
# most contemporary definitions are consistent with these
# ideas as they describe boredom as feeling dissatisfied, unin-
# terested, or withdrawn from the environment (e.g., elpidorou,
#
# 2017; farmer & sundberg, 1986; fisher, 1993; vafeas & hughes,
# 2016). more recently, eastwood and colleagues (e.g.,
# eastwood, frischen, fenske, & smilek, 2012; fahlman et al.,
# 2013) defined state boredom as “the aversive experience of
# wanting, but being unable to engage in stimulating and satis-
# fying activity” (p. 69). in line with psychodynamic theorists,
# they further specified that in addition to “wanting but being
# unable”, the bored individual is “unaware of what it is that one
# desires” (eastwood et al., 2012, p. 484). similarly, mann and
# cadman (2014) suggested that bored individuals are unable to
# specify what to do, stating that “boredom stems from a situa-
# tion where none of the possible things that a person can
# realistically do appeal to the person in question” (p. 165).
# taken together, psychodynamic theory suggests that disen-
# gagement is a key component of state boredom, which we
# define as a longing to engage in an unspecified satisfying
# activity.
#
# state boredom and unpleasant low arousal
#
# according to arousal theory, state boredom occurs when our
# physiological arousal falls below an optimal level (fiske &
# maddi, 1961; hebb, 1955; o’hanlon, 1981). decreased arousal
# is thought to result from under-stimulating environments,
# leading to a mismatch between one’s current and desired
# level of arousal. because individuals are motivated to maintain
# an optimal level of stimulation, individuals who experience
# arousal below this level perceive it to be unpleasant
# (berlyne, 1960; fiske & maddi, 1961; hebb, 1955; o’hanlon,
# 1981). overall then, arousal theory suggests that state bore-
# dom is an unpleasant, low arousal state.
#
# in alignment with arousal theory, organizational research-
# ers stipulate that boredom occurs when the work context is
# under-stimulating (reijseger et al., 2013; skowronski, 2012; van
# der heijden, schepers, & nijssen, 2012). early organizational
# research on state boredom focused on routine factory jobs
# and vigilance tasks as feeling bored was thought to result
# from monotonous stimuli with under-arousing properties
# (loukidou, lou-clarke, & daniels, 2009; o’hanlon, 1981). most
# contemporary definitions of state boredom define it in relation
# to low physiological arousal, involving feelings of weariness,
# lethargy, fatigue, and drowsiness (geiwitz, 1966; greenson,
# 1953; levy, 1984; marsh, 1983; mikulas & vodonovich, 1993).
# for example, hamilton (1981) referred to it as a “low arousal,
# drowsy sort of boredom” (p. 358).
#
# a few researchers contend that state boredom is accom-
# panied by increased arousal (berlyne, 1960; hill & perkins,
# 1985) and qualitative data show that bored individuals some-
# times report feeling restless alongside lethargy (harris, 2000;
# martin, sadlo, & stew, 2006; vandewiele, 1980). it seems logi-
# cally and physiologically inconsistent to suggest that state
# boredom comprises both high and low arousal; however,
# arousal theory provides insight into why this occurs. arousal
# theory asserts that people are motivated to maintain an opti-
# mal level of arousal (fiske & maddi, 1961; hebb, 1955); thus, to
# maintain this level, bored individuals who experience lethar-
# gic, low arousal may make efforts to increase arousal either
# through changing their environment or by increasing their
# internal level of physiological arousal (burn, 2017; mikulas &
#
# 478 p. l. baratta and j. r. spence
#
#
#
# vodanovich, 1993; o’hanlon, 1981). reports of feeling restless
# when bored are associated with situations involving constraint
# (geiwitz, 1966; martin et al., 2006; mikulas & vodanovich, 1993)
# and may be indicative of individuals trying to escape boredom
# through self-stimulation since changing the environment is
# not possible. we contend that whereas low arousal is an
# essential component of state boredom, high arousal is likely
# a result of attempting to escape it and is, therefore, an out-
# come of feeling bored.
#
# in addition to low arousal, arousal theory states that boredom
# is experienced as unpleasant (because arousal is below the
# optimal level). this is consistent with circumplex models of affect
# in which affective states are positioned around a circumplex
# along two orthogonal continuums: valence and activation
# (russell, 1980). these continuums result in a circumplex divided
# into four quadrants: activation/pleasant, activation/unpleasant,
# deactivation/pleasant, and deactivation/unpleasant (feldman
# barrett & russell, 1998). state boredom is thought to inhabit
# the deactivation/unpleasant quadrant (reijseger et al., 2013;
# schaufeli & salanova, 2014; vogel-walcutt, fiorella, carper, &
# schatz, 2012). states that load similarly on the two continuums
# are grouped in the same quadrant, with boredom being plotted
# alongside drowsiness, sluggishness, and tiredness in the same
# deactivation/unpleasant quadrant (russell, 1980; yik, russell, &
# steiger, 2011). this reaffirms the idea that unpleasant, low arou-
# sal is a critical component of boredom, which we define as a
# negative, deactivated state that is manifested in emotions such as
# weariness and lethargy.
#
# state boredom and inattention
#
# attentional theories suggest that boredom occurs when sustain-
# ing attention is effortful (culp, 2006; eastwoodet al., 2012; fahlman
# et al., 2013; hunter & eastwood, 2016; leary et al., 1986). individuals
# feel bored when they cannot engage attention with external or
# internal stimuli required for participating in satisfying activity or
# when they need to exert conscious effort to maintain attention to
# increase task engagement (eastwood et al., 2012). evidence of the
# role of attention in boredom is found in cases of individuals with
# mild traumatic brain injury who suffered damage to brain areas
# implicated in attention. these individuals report feeling bored
# more frequently and have higher levels of trait boredom
# (goldberg & danckert, 2013; kreutzer, seel, & gourley, 2001; as
# cited in hunter & eastwood, 2016). other research has found that
# individuals high in trait boredom experience more attentional
# lapses and day-to-day attentional errors, such as zoning out and
# misplacing keys (malkovsky, merrifield, goldberg, & danckert,
# 2012). qualitative data show that bored individuals report inatten-
# tion,mindwandering, anddaydreaming (game, 2007; harris, 2000;
# marsh, 1983; martin et al., 2006), and tasks that require sustained
# attention like vigilance tasks are rated as boring (london, schubert,
# & washburn, 1972; scerbo, greenwald, & sawin, 1993).
#
# many contemporary definitions of state boredom include an
# attentional component in which the bored individual has difficulty
# concentrating and/or maintaining attention (crockett, myhre, &
# rokke, 2015; fisher, 1993; harju & hakanen, 2016; isacescu &
# danckert, 2016). culp (2006) described it as a “lack of attentional
# interest” (p. 999), and leary et al. (1986) positioned it as “an
# affective consequence of effortful maintenance of attention” (p.
#
# 968). overall, attentional theories suggest that inattention is an
# integral component of state boredom, which we define as an
# inability to focus attention or difficulty in maintaining attention.
#
# an integrated definition of state boredom
#
# together, we define state boredom as a lethargic, deactivated
# negative state (unpleasant low arousal) in which one is unable
# to focus attention (inattention) and experiences a longing to
# engage in an unspecified satisfying activity (disengagement).
# this definition reflects the higher-order multidimensional
# structure of state boredom, which comprises three compo-
# nents. multidimensional constructs have several distinct,
# related dimensions that are treated as a single, higher-order
# theoretical concept (edwards, 2001). they are understood in
# terms of their dimensions and do not exist independently of
# them. we expect that state boredom is a higher-order con-
# struct that manifests itself in experiences of disengagement,
# unpleasant low arousal, and inattention (baratta & spence,
# 2015; law, wong, & mobley, 1998). in this structure, the dis-
# tinct, but related dimensions of disengagement, unpleasant
# low arousal, and inattention are collectively referred to as state
# boredom. figure 1 displays the expected factor structure.
#
# the measurement of state boredom
#
# in the current paper, our goal was to measure the experience
# of feeling bored. some existing measures of boredom do not
# measure the discrete, episodic construct of state boredom,
# and instead focus on dispositional or environmental charac-
# teristics. the boredom proneness scale (bps; farmer &
# sundberg, 1986) is used frequently, but was designed to
# assess trait boredom or a chronic predisposition to feeling
# bored. whereas trait boredom is dispositional and stable
# over time, state boredom is a momentary state that fluctuates
# in response to situations. although individuals high in trait
# boredom feel bored more often, trait measures provide little
# insight into how bored one is at a given moment or the
# affective experience of feeling bored (van hooff & van hooft,
# 2014). most other scales, such as lee’s (1986) job boredom
# scale (ljbs), restrict the measurement of boredom to specific
# contexts and were not designed to measure how bored one is
# currently (vodanovich, 2003). the ljbs (lee, 1986), for exam-
# ple, includes items like “how well do you like the work that
# you do?”, illustrating that these scales are better-suited for
#
# figure 1. higher-order multidimensional factor structure of state boredom.
#
# european journal of work and organizational psychology 479
#
#
#
# assessing overall perceptions of a particular context and not
# how bored one is at a given moment.
#
# organizational researchers have adapted existing measures
# to reflect state-like qualities, but these measures suffer from
# construct contamination as they confound state boredom
# with antecedents like work characteristics and affective and
# behavioural consequences (e.g., bauer & spector, 2015;
# guglielmi, simbula, mazzetti, tabanelli, & bonfiglioli, 2013;
# reijseger et al., 2013; van der heijden et al., 2012; van wyk,
# de beer, pienaar, & schaufeli, 2016). for instance, guglielmi
# et al. (2013) measured boredom using items that reflect
# under-stimulating work characteristics like skill underutiliza-
# tion (“i feel that i am working below my abilities most of the
# time”) and low task variety (“many things i have to do are
# repetitive and monotonous”). reijseger et al. (2013) created
# the dutch boredom scale, which captures “affective, cognitive,
# and behavioural reactions” (p. 509) to work boredom. for
# example, one item, “i tend to do other things during my
# work”, overlaps with counterproductive work behaviour, a
# potential outcome of feeling bored. the inclusion of these
# items is problematic when conducting research linking bore-
# dom to organizational variables as overlapping content
# between measures of conceptually distinct constructs can
# lead to inflated correlations (bozeman & perrewé, 2001).
#
# some measures are content deficient as they fail to capture
# all of boredom’s dimensions. reijseger et al. (2013) defined
# boredom as “a state of low arousal and dissatisfaction” (p.
# 509), but did not include items that directly measure this.
# instead, one item, “during work time i daydream”, was
# included to indirectly tap into unpleasant low arousal as
# they argued that daydreaming is a manifestation of low arou-
# sal. similarly, van hooff and van hooft’s (2014) measure of
# work boredom, although useful for gauging perceptions of
# boring work, does not include items that directly tap into
# the affective component of boredom (unpleasant low arousal).
#
# to date, the multidimensional state boredom scale (msbs;
# fahlman et al., 2013) is the only validated multidimensional mea-
# sure of state boredom. the msbs is a 29-item measure that
# assesses state boredom along five dimensions: disengagement,
# low arousal, high arousal, time perception, and inattention.
# although the msbs is comprehensive, it may be too broad as it
# incorporates high arousal and time perception as dimensions of
# boredom when they may be more theoretically consistent as out-
# comes (see casini & macar, 1999; hansen & trope, 2013; mikulas &
# vodanovich, 1993; for supporting arguments).moreover, themsbs
# disengagement and low arousal dimensions include content
# beyond their definitions. some of the disengagement items
# describe potential causes of feeling bored, such as constraint (“i
# am stuck in a situation that i feel is irrelevant”) or routinization (e.g.,
# “everything seems repetitive and routine tome”). routinework, for
# example, may lead some, but not all, individuals to feel bored; for
# some, it leads to creativity (ohly, sonnentag, & pluntke, 2006).
# similarly, the low arousal items reflect sadness (e.g., “i feel
# down”), which is distinct from feelings of lethargy indicative of
# feeling bored. the sadness octant in the circumplex model is
# adjacent to the tiredness octant in which boredom is grouped,
# highlighting that although these states are related, they should be
# treated as distinct (yik et al., 2011). we sought to address the
# limitations of existing scales by developing a state boredom
#
# measure that is conceptually consistent with our theoretically
# derived definition.
#
# overview of studies
#
# we followed hinkin’s (1998) recommendations for scale develop-
# ment and present the results of these studies in three phases:
# phase 1 describes the item generation stage wherein we created
# a large pool of boredom items and reduced them to an 11-item
# scale. phase 2 tested the scale’s psychometric properties andphase
# 3 provides convergent and discriminant validity evidence.
#
# phase 1: item generation and reduction
#
# item generation
#
# we generated a pool of items using the deductive approach to
# item development wherein items are created using a theoretical
# framework (hinkin, 1998). given that items should assess only
# one idea or construct (hinkin, 1998), we created three subscales
# for each of state boredom’s dimensions. the content of each
# item was intended to reflect the definition of its corresponding
# dimension (see akremi, gond, swaen, de roeck, & igalens, 2015;
# walumbwa, avolio, gardner, wernsing, & peterson, 2008; for a
# similar methodology). for example, our inattention items
# reflected the definition: an inability to focus attention or diffi-
# culty in maintaining attention. we ensured that the item word-
# ing was clear and succinct to facilitate respondents’
# interpretation of the items (clark & watson, 1995; hinkin,
# 1998). we supplemented these items with 19 items from the
# msbs disengagement, low arousal, and inattention subscales,
# which enabled us to test the extent to which the msbs items are
# consistent with our definition of state boredom.
#
# study 1: item reduction using item-sort tasks
#
# we used two item-sort tasks to evaluate the items’ substantive
# validity, which is defined as the extent to which an item’s
# content reflects the focal construct (anderson & gerbing,
# 1991). item-sort tasks enable researchers to remove items
# that are not conceptually consistent with their construct defi-
# nitions (anderson & gerbing, 1991; ferris, brown, berry, & lian,
# 2008; hinkin, 1998). the first sort-task (sample 1) sought to
# confirm that each item was consistent with its respective state
# boredom dimension and the second sort-task (sample 2)
# sought to ensure that each item did not reflect the content
# of related constructs (hunt, sparkman, & wilcox, 1982).
#
# once referred to as the “noonday demon”, state boredom has
# a history of being identified as a counterproductive force
# whose distracting qualities deter individuals from their work
# duties (cassian, 2000; ponticus, 2006). state boredom’s close
# historic connection to the shirking of formal duties points to a
# potentially important role that feeling bored may play in the
# day-to-day lives of employees. we suspect that our knowledge
# of state boredom and its explanatory potential in organiza-
# tional research may be limited due to inconsistent definitions
# and the absence of a scientifically sound measure. in our
# research, we sought to address definitional and measurement
# limitations by presenting a consensus-based, theoretically
# derived definition of state boredom and by developing a
# psychometrically sound measure that is consistent with this
# definition. we anticipate that a theoretically grounded defini-
# tion and measure of state boredom will enable organizational
# researchers to better investigate how state boredom functions
# at work.
#
# after reviewing the boredom literature in search of com-
# monalities across definitions, we defined state boredom as a
# lethargic, deactivated negative state (unpleasant low arousal)
# in which one is unable to focus attention (inattention) and
# experiences a vague longing to engage in satisfying activity
# (disengagement). this definition is consistent with a higher-
# order multidimensional structure, indicating that boredom
#
# comprises three related but distinct factors (disengagement,
# unpleasant low arousal, and inattention) that collectively
# represent state boredom.
#
# across five studies using 10 independent samples, we
# found validation evidence for our scale. in study 1, we found
# support for the content validity of the sbi, indicating that our
# items are conceptually consistent with each dimension defini-
# tion. in study 2, we used irt to select the best-performing
# items, resulting in 11 items that effectively discriminate
# between individuals at high and low levels of disengagement,
# unpleasant low arousal, and inattention. in study 3, we pro-
# vided evidence for the sbi’s psychometric properties and sup-
# port for its higher-order multidimensional factor structure. in
# study 4, we found evidence for convergent and discriminant
# validity, indicating that boredom is related to, but distinct
# from, theoretically relevant constructs and is unrelated to
# theoretically irrelevant constructs. finally, in study 5, we pro-
# vided evidence of convergent validity using a daily diary
# study, demonstrating that day-level state boredom is related
# to daily na, pa, and work engagement. we also found overlap
# between the sbi and other measures of boredom.
#
# contributions
#
# the present studies contribute to organizational research on
# state boredom in several ways. first, by building consensus
# towards a definition of state boredom, we ensure that
# researchers seeking to study it are theorizing about the same
# construct. researchers who rely on different definitions make
# it difficult for others to integrate theories on state boredom as
# it is unclear whether they are theorizing about state boredom
# or another construct. a shared understanding of state bore-
# dom is essential for building a unified theory identifying
# causes and outcomes of feeling bored as well as mechanisms
# explaining why it predicts specific outcomes. second, organi-
# zational research on state boredom has been impeded due to
# the absence of a proper measure. in our research, we provide
# researchers with a measure of state boredom that is opera-
# tionally consistent with its construct definition and is
# grounded in theory. many early measures like the bps
# (farmer & sundberg, 1986) and the ljbs (lee, 1986) are ill-
# suited for measuring boredom as a state as these measures
# assess trait rather than state boredom and are context-specific.
#
# other measures used in organizational research are
# suboptimal as they suffer from construct deficiency and
# contamination (e.g., guglielmi et al., 2013; van der heijden
# et al., 2012). these scales omit content from the definition
# of state boredom, failing to tap into its disengagement,
# unpleasant low arousal, and inattention dimensions.
# moreover, many scales confound the experience of feeling
# bored with other constructs by incorporating items that
# overlap with distinct constructs. this is problematic as
# redundant content between measures of distinct con-
# structs can lead researchers to make unsubstantiated
# claims about how boredom functions at work. for
# instance, guglielmi et al. (2013) found that boredom was
# related to work characteristics like learning opportunities;
# however, given that their boredom scale reflected work
# characteristics (e.g., skill underutilization), concluding that
#
# table 8. convergent validity correlations (sample 10).
#
# 1 2 3 4 5 6 7 8
#
# 1. state boredom .91
# 2. negative affect .56 .95
# 3. positive affect −.45 −.42 .93
# 4. vigour −.74 −.24 .48 .93
# 5. dedication −.51 −.30 .62 .99 .93
# 6. absorption −.43 −.25 .50 .92 1.00 .90
# 7. trait boredom .64 .44 −.59 −.49 −.65 −.54 .85
# 8. work boredom .63 .41 −.40 −.30 −.45 −.47 .75 .94
#
# note. the within-person reliabilities and cronbach’s alpha are presented for
# within-person and between-person variables, respectively. boredom reliabil-
# ities are the average within-person reliabilities for the disengagement, unplea-
# sant low arousal, and inattention subscales. the correlation between
# absorption and dedication was rounded down to 1.00 as it was greater than
# 1. bolded correlations are statistically significant at p < .05.
#
# european journal of work and organizational psychology 489
#
#
#
# boredom was related to work characteristics is misleading.
# we anticipate that use of the sbi will enable researchers
# to make more accurate conclusions about how feeling
# bored relates to other organizational variables.
#
# limitations
#
# although our research has strengths, there are limitations. we
# relied on self-reports to test our hypotheses, highlighting the
# possibility of cmv (podsakoff et al., 2003). our decision to use
# self-reports was based on the nature of our variables as many
# were subjective states (conway & lance, 2010). the central con-
# struct, state boredom, is an internal state that is unlikely to be
# accurately estimated using other reports. in studies 4 and 5, many
# of the other constructs also reflected internal states (e.g., na) that
# would have been difficult to gauge using other-reports. moreover,
# given that we expected the relations between state boredom and
# other affective variables to be driven by overlap in momentary
# affect, it did not make logical sense to temporally separate the
# measurement of these constructs. when possible, we separated
# the measurement occasions between the sbi and dispositional
# constructs, which is thought to reduce cmv.
#
# another limitation of this research is that although we
# provided evidence that feeling bored and its unpleasant low
# arousal dimension are distinct from other negative, low activa-
# tion states like depression, apathy, and anhedonia, we did not
# provide evidence that it is distinct from a broader range of
# deactivating, unpleasant states, particularly fatigue. given that
# boredom and fatigue are proximally located in the circumplex
# model of affect (russell, 1980), future research may want to
# examine the extent to which the sbi is discriminant from
# measures of fatigue.
#
# conclusion
#
# we worked to advance organizational research on state bore-
# dom by building consensus towards a theoretically grounded
# definition and by developing an empirically validated measure
# that is operationally consistent with this definition. across five
# studies using 10 independent samples, we supported the
# validation of the sbi. the results of these psychometric pur-
# suits revealed that a higher-order multidimensional structure
# with disengagement, unpleasant low arousal, and inattention
# factors is an appropriate model of state boredom. we hope
# that the results of this research provide researchers with a
# common ground for building a more accurate and compre-
# hensive understanding of state boredom in the workplace.
#
# notes
#
# 1. due to space restrictions, we present the icc figures in the supple-
# mental materials.
#
# 2. the means and standard deviations for each sbi subscale (studies
# 2–5) are in the supplemental materials.
#
# disclosure statement
#
# no potential conflict of interest was reported by the authors.
#
# funding
#
# this work was supported by the social sciences and humanities research
# council of canada.
#
# --**************************************-
# -**************************************--
# -**************************************--

# %%
# remove journal title here?
pdf_p = [re.sub('journal of management', '', t) for t in pdf_remove_step4]
pdf_p = [re.sub('et al.', '', t) for t in pdf_p]
pdf_p = [re.sub('e.g.', '', t) for t in pdf_p] 
pdf_p = [re.sub('e-mail:', '', t) for t in pdf_p] 
# CHECK ORDER OF OPERATIONS BELOW:
#remove email address <-- IMPROVED, BUT E-MAIL SEEMS TO BE BROKEN UP, BUT STILL PRESENT IN DOCUMENTS AT TIMES         
pdf_p = [re.sub(r'[\w\.\-]+@[\w\.\-]+\.(?:com|net|org|live|edu)', "", t) for t in pdf_p]

# %%
pdf_p = [re.sub( r'https?://[^\s<>"]+|www\.[^\s<>"]+', "", t) for t in pdf_p]
pdf_p = [re.sub("[\S\.\-\?\!\=]+\.(net|com|org|info|edu|gov|uk|de|ca|jp|fr|au|us|ru|ch|it|nel|se|no|es|mil)(/[\S\.\-\?\!\=]*)?\s?", " ", t) for t in pdf_p]

# %%
pdf_p[20]
# Out:
# '\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\ncapturing the noonday demon: development and validation of the state boredom inventory\n\n\nfull terms & conditions of access and use can be found at\n\n\neuropean journal of work and organizational psychology\n\nissn: 1359-432x (print) 1464-0643 (online) journal homepage: \n\ncapturing the noonday demon: development and\nvalidation of the state boredom inventory\n\npatricia l. baratta & jeffrey r. spence\n\nto cite this article: patricia l. baratta & jeffrey r. spence (2018) capturing the noonday demon:\ndevelopment and validation of the state boredom inventory, european journal of work and\norganizational psychology, 27:4, 477-492, doi: 10.1080/1359432x.2018.1481830\n\nto link to this article:  \n\nview supplementary material \n\npublished online: 05 jun 2018.\n\nsubmit your article to this journal \n\narticle views: 371\n\nview related articles \n\nview crossmark data\n\nciting articles: 1 view citing articles \n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\ncapturing the noonday demon: development and validation of the state boredom\ninventory\npatricia l. baratta and jeffrey r. spence\n\ndepartment of psychology, university of guelph, guelph, on, canada\n\nabstract\nfor centuries, scholars have positioned state boredom as an impediment to organizational productivity\nand performancven its unpleasant and distracting qualities. however, research on state boredom\nhas been impeded by a lack of definitional consensus and measurement issues. in this article, we\nsought to advance organizational research on state boredom by developing the state boredom\ninventory (sbi), an 11-item measurounded in a theoretically derived definition of state boredom.\nacross five studies using 10 independent samples, we develop the sbi and provide validity evidence for\nour measure, including content validity and convnt and discriminant validity. our data support the\nconceptualization of state boredom as a higher-order multidimensional construct with three underlying\ndimensions: disgement, unpleasant low arousal, and inattention.\n\narticle history\nreceived 27 october 2017\naccepted 21 may 2018\n\nkeywords\nboredom; multidimensional;\nscale development; scale\nvalidation; diary study\n\nalthough sometimes viewed as a symptom of modernity,\nfeeling bored has been studied as a part of the human condi-\ntion for centuries (jackson, 1981; wenzel, 1967). our modern\nunderstanding of state boredom originates from theek\nword acedia (ἀκηδία), which translates to “without care” and\nwas used to describe idleness with respect to religious duties\nbeginning in the fourth century c.e. (peters, 1975; wenzel,\n1967). acedia was considered to be one of t vices and\nwas closely tied to the avoidance of formal duties among\ncatholic monks. nicknamed the “noonday demon”, acedia\nwas thought to strike around midday, distracting monks\nfrom their work and tempting them to leave the monastery\nin search of stimulation (ponticus, 2006). catholic monk john\ncassian (2000) described acedia as making monks either idle\nor restless. he writes, “[acedia] either allows [the monk] to stay\nin his cell without any spiritual progress, in as it were a state of\ninactivity and surrender, or drives him out from there and\nmakes him, in addition, unstable and feckless” (p. 221).\n\nthese early accounts suggest that little has changed with\nrespect to how people experience boredom at work. if\ncassian’s description of acedia were updated with references\nto contemporary workplaces, it might refer to “cubicles”\ninstead of “cells” and rather than a “monk” being “unstable\nand feckless”, an “employee” might be “distracting and inef-\nfective”. the link between boredom and counterproductivity\nhas carried through to today, with researchers recognizing\nthat feeling bored may result in distraction at work. for exam-\nple, trait boredom, or a chronic propensity to feel bored,\nrelates to  ...

# %%
#remove hyphon only if it is at the end of the line.
#pdf_p = [re.sub(r'(\W[a-z]+)-\n(\W[a-z]+)', r'\1\2', t) for t in pdf_p]
pdf_p = [re.sub(r'-\n', '', t) for t in pdf_p]

# %%
#remove text within ()
pdf_p = [re.sub(r"\([^)]*\)", "", t) for t in pdf_p]
# remove text with [] eg citation
pdf_p = [re.sub(r"\[[^)]*\]", "", t) for t in pdf_p]
#Remove numbers
pdf_p = [re.sub('[0-9]+', '', f) for f in pdf_p]

# %%
pdf_p = [re.sub('[\n\r]+', ' ', f) for f in pdf_p] # remove newline and linebreak characters, replace with space
pdf_p = [re.sub('[@/%#$,=\+:’“”]', ' ', f) for f in pdf_p] # remove stray non-word characters

# %%
#pdf_p = [re.sub(r"\s\([A-Z][a-z]+,\s[A-Z][a-z]?\.[^\)]*,\s\d{4}\)", "", f) for f in pdf_p] # is this supposed to filter out citations?

# save all periods, exclamation marks and question marks, but get rid of unnecessary characters
pdf_p = [re.sub('[\.!?]+ ', 'XYZXYZ', t) for t in pdf_p]
pdf_p = [re.sub('-', 'ZYXXYZ', t) for t in pdf_p]
pdf_p = [re.sub('[\W_]+', ' ', f) for f in pdf_p]
pdf_p = [re.sub('XYZXYZ', '. ', f) for f in pdf_p]
pdf_p = [re.sub('ZYXXYZ', '-', f) for f in pdf_p]
#pdf_p[0]

#Remove placeholder x repetitions
pdf_p = [re.sub(' x+ ', '', f) for f in pdf_p]

# remove single characters
pdf_p = [re.sub(' [a-z] ' ,  ' ', f) for f in pdf_p]
pdf_p = [re.sub(' [a-z]\.', '.', f) for f in pdf_p]
pdf_p = [re.sub(' \.', '.', f) for f in pdf_p]

# %%
print(pdf_p[ref_doc])
print('---')
print('---')
print('---')
# print(pdf_p[ref_doc])
# Out:
#  capturing the noonday demon development and validation of the state boredom inventory full terms conditions of access and use can be found at european journal of work and organizational psychology issn -x - journal homepage capturing the noonday demon development and validation of the state boredom inventory patricia. baratta jeffrey. spence to cite this article patricia. baratta jeffrey. spence capturing the noonday demon development and validation of the state boredom inventory european journal of work and organizational psychology - doi.. to link to this article view supplementary material published online jun. submit your article to this journal article views view related articles view crossmark data citing articles view citing articles capturing the noonday demon development and validation of the state boredom inventory patricia. baratta and jeffrey. spence department of psychology university of guelph guelph on canada abstract for centuries scholars have positioned state boredom as an impediment to organizational productivity and performancven its unpleasant and distracting qualities. however research on state boredom has been impeded by lack of definitional consensus and measurement issues. in this article we sought to advance organizational research on state boredom by developing the state boredom inventory an -item measurounded in theoretically derived definition of state boredom. across five studies using independent samples we develop the sbi and provide validity evidence for our measure including content validity and convnt and discriminant validity. our data support the conceptualization of state boredom as higher-order multidimensional construct with three underlying dimensions disgement unpleasant low arousal and inattention. article history received october accepted may keywords boredom multidimensional scale development scale validation diary study although sometimes viewed as symptom of modernity feeling bored has been studied as part of the human condition for centuries. our modern understanding of state boredom originates from theek word acedia which translates to without care and was used to describe idleness with respect to religious duties beginning in the fourth century.. acedia was considered to be one of vices and was closely tied to the avoidance of formal duties among catholic monks. nicknamed the noonday demon acedia was thought to strike around midday distracting monks from their work and tempting them to leave the monastery in search of stimulation. catholic monk john cassian described acedia as making monks either idle or restless. he writes to stay in his cell without any spiritual progress in as it were state of inactivity and surrender or drives him out from there and makes him in addition unstable and feckless. these early accounts suggest that little has changed with respect to how people experience boredom at work. if cassian description of acedia were updated with references to contemporary workplaces it might refer to cubicles instead of cells and rather than monk being unstable and feckless an employee might be distracting and ineffective. the link between boredom and counterproductivity has carried through to today with researchers recognizing that feeling bored may result in distraction at work. for example trait boredom or chronic propensity to feel bored relates to poor performance absenteeism turnover withdrawal and deviance. despite etymological and contemporary associations between feeling bored and employee effectiveness organizational research on state boredom is limited. this may be due to the fact that the organizational behaviour literature is wrought with divnt and sometimes contradictory definitions of feeling bored in addition to suboptimal scales. we sought to contribute to organizational research on state boredom by developing measure that is consistent with theoretically derived definition and that builds on the strhs of existing scales while addressing their limitati ...
# ---
# ---
# ---

# %%
def get_author_names(txt):

    refs = re.sub('[0-9]{4}.*\n','',txt)

    l = re.compile(" [a-z]\.").split(refs)
    l = [ll for ll in l if not bool(re.search('[0-9]+', ll))]
    l = [ll for ll in l if len(ll) < 35]
    l = [re.sub('[\n ,\&\.]', '', ll) for ll in l]
    l = [re.sub('[!(*);&$]', '', l1) for l1 in l]
    authors = [ll for ll in l if len(ll) > 1]

    return(authors)
#for n in names:
#    print(n)

#refs = re.sub('\n.*[0-9].*', '', refs)
#refs = re.sub('\n[^,]+\n', '\n', refs)
#print(refs)

# %%
authors = []
for r in references:
    authors += get_author_names(r)
    
author_nam = list(set(list(authors)))

# result is still not perfect, but I have not found any stray 'plain English' so far
print(author_nam[100:250])
print(len(author_nam))
# Out:
# ['searle', 'degeus', 'soares', 'inaninterpersonalcontextin', 'greller', 'slocum', 'boteroi', 'cheathorgan', 'roseboroughm', 'kenworthy', 'ojajarvi', 'björkqvist', 'henseke', 'mellenbergh', 'moorman', 'gleser', 'ie-peterlangwatson', 'beauvais', 'stettler', 'edmonson', 'crick', 'thepowell', 'kompier', 'newton', 'loher', 'letens', 'pousette', 'pidd', 'hoff', 'takahashi', 'mobley', 'demarie', 'prabhu', 'vankeer', 'lechner', 'person-environmentfitin', 'borchgrevink', 'nikolaou', 'krauskroßnagel', 'espinosa', 'brüesch', 'bizman', 'strittmatter', '-haubé', 'barattaand', 'sleebos', 'sobral', 'dobbins', 'degoey', 'kimmel', 'sexton', 'dilella', 'freedy', 'vanvianen', 'leandre', 'wilkinson', 'mcneil', 'springerlepine', 'te’eni', 'henry', 'linnemeyer', 'norman', 'becerra', 'brauner', 'claypool', 'batey', 'driscoll', 'férnandez', '-pcooper', 'theneedforrevengein', 'voneye', 'estabrooks', 'gsheets', 'cantarelli', 'mislin', '-jchevalier', 'intergroupbehaviourin', 'urquhart', 'giluk', 'thye', 'uys', 'binning', 'roisman', 'boumans', 'west', 'hummertm', 'costa', 'letzel', 'forsbrandebo', 'driver-linn', 'vangils', 'hovmark', 'jrboyar', 'mcardle', 'boada-grau', 'bhawuk', 'aarts', 'kleen', 'goldfarb', 'yarnold', 'aselage', 'suzuki', 'sainio', 'main', '-tchen', 'vanroelen', 'cukier', 'sivasubramaniam', 'harland', 'oaksca:sagevoss', 'nunnally', 'arnold', 'yorkny:mcgraw-hillcarr', 'vanderwoud', 'edens', 'vandamkwillemsen', 'percival', 'moreno-jimenezbpastor', 'mouly', 'banaji', 'kofodimos', 'justicebemeasuredin', 'carayon', 'boudrias', 'scheel', 'coid', 'sörbom', 'fukushima', 'bucklew', 'street', 'darling-hammond', 'tapias', '-ébrunet', 'sagekhuntia', 'avalloni', 'geare', 'ayanian', 'bavetta', 'ofincompletedatain', 'kärreman', 'buelens', 'javidan', 'challagalla', 'chrisopoulos', 'dunster', 'bongers', 'crace', 'naveh', 'mäkikangas', 'worthley']
# 14487

# %%
# GET REFERENCE LISTS OF STOPWORDS, I.E. WORDS THAT ARE ESSENTIALLY MEANINGLESS
# Get all the list of authors names

from nltk.corpus import stopwords as wrd

sw = wrd.words('english') + author_nam + country_list + cities_lower

#print(sw)

# %%
#include corpus-specific stopwords
sw += ['vol', 'doi', 'article', 'articles', 'reuse', 'sagepub', 'journal', 'journals', 'com', 'quarter', 'quarterly', 'annual', 'proceedings']
sw += ['sage', 'editorial', 'report', 'publications', 'publication', 'publisher', 'jom', 'manuscript', 'manuscripts', 'submission', 'submissions']
sw += ['editor', 'editors', 'orcid', 'id', 'month', 'mailto', 'author', 'authors', 'homepage', 'sciencedirect', 'scopus']
sw += ['january', 'february', 'march', 'april', 'may', 'june', 'july', 'august', 'september', 'october', 'november', 'december']
sw += ['monday', 'tuesday', 'wednesday', 'thursday', 'friday', 'saturday', 'sunday']

# add a metric ton of generic terms
sw += ['a', 'about', 'above', 'across', 'after', 'afterwards']
sw += ['again', 'against', 'all', 'almost', 'alone', 'along']
sw += ['already', 'also', 'although', 'always', 'am', 'among']
sw += ['amongst', 'amoungst', 'amount', 'an', 'and', 'another']
sw += ['any', 'anyhow', 'anyone', 'anything', 'anyway', 'anywhere']
sw += ['are', 'around', 'as', 'at', 'back', 'be', 'became']
sw += ['because', 'become', 'becomes', 'becoming', 'been']
sw += ['before', 'beforehand', 'behind', 'being', 'below']
sw += ['beside', 'besides', 'between', 'beyond', 'bill', 'both']
sw += ['bottom', 'but', 'by', 'call', 'can', 'cannot', 'cant']
sw += ['co', 'computer', 'con', 'could', 'couldnt', 'cry', 'de']
sw += ['describe', 'detail', 'did', 'do', 'done', 'down', 'due']
sw += ['during', 'each', 'eg', 'eight', 'either', 'eleven', 'else']
sw += ['elsewhere', 'empty', 'enough', 'etc', 'even', 'ever']
sw += ['every', 'everyone', 'everything', 'everywhere', 'except']
sw += ['few', 'fifteen', 'fifty', 'fill', 'find', 'fire', 'first']
sw += ['five', 'for', 'former', 'formerly', 'forty', 'found']
sw += ['four', 'from', 'front', 'full', 'further', 'get', 'give']
sw += ['go', 'had', 'has', 'hasnt', 'have', 'he', 'hence', 'her']
sw += ['here', 'hereafter', 'hereby', 'herein', 'hereupon', 'hers']
sw += ['herself', 'him', 'himself', 'his', 'how', 'however']
sw += ['hundred', 'i', 'ie', 'if', 'in', 'inc', 'indeed']
sw += ['interest', 'into', 'is', 'it', 'its', 'itself', 'keep']
sw += ['last', 'latter', 'latterly', 'least', 'less', 'ltd', 'made']
sw += ['many', 'may', 'me', 'meanwhile', 'might', 'mill', 'mine']
sw += ['more', 'moreover', 'most', 'mostly', 'move', 'much']
sw += ['must', 'my', 'myself', 'name', 'namely', 'neither', 'never']
sw += ['nevertheless', 'next', 'nine', 'no', 'nobody', 'none']
sw += ['noone', 'nor', 'not', 'nothing', 'now', 'nowhere', 'of']
sw += ['off', 'often', 'on','once', 'one', 'only', 'onto', 'or']
sw += ['other', 'others', 'otherwise', 'our', 'ours', 'ourselves']
sw += ['out', 'over', 'own', 'part', 'per', 'perhaps', 'please']
sw += ['put', 'rather', 're', 's', 'same', 'see', 'seem', 'seemed']
sw += ['seeming', 'seems', 'serious', 'several', 'she', 'should']
sw += ['show', 'side', 'since', 'sincere', 'six', 'sixty', 'so']
sw += ['some', 'somehow', 'someone', 'something', 'sometime']
sw += ['sometimes', 'somewhere', 'still', 'such', 'system', 'take']
sw += ['ten', 'than', 'that', 'the', 'their', 'them', 'themselves']
sw += ['then', 'thence', 'there', 'thereafter', 'thereby']
sw += ['therefore', 'therein', 'thereupon', 'these', 'they']
sw += ['thick', 'thin', 'third', 'this', 'those', 'though', 'three']
sw += ['three', 'through', 'throughout', 'thru', 'thus', 'to']
sw += ['together', 'too', 'top', 'toward', 'towards', 'twelve']
sw += ['twenty', 'two', 'un', 'under', 'until', 'up', 'upon']
sw += ['us', 'very', 'via', 'was', 'we', 'well', 'were', 'what']
sw += ['whatever', 'when', 'whence', 'whenever', 'where']
sw += ['whereafter', 'whereas', 'whereby', 'wherein', 'whereupon']
sw += ['wherever', 'whether', 'which', 'while', 'whither', 'who']
sw += ['whoever', 'whole', 'whom', 'whose', 'why', 'will', 'with']
sw += ['within', 'without', 'would', 'yet', 'you', 'your']
sw += ['yours', 'yourself', 'yourselves']

sw = list(set(sw))

# %%
# Function to filter out the stopwords and authors names
def filterWords(msg, words):
    m = msg.split(' ')
    words_end = [w + '.' for w in words]
    filtered_words = list(filter(lambda word: word not in words, m))
    filtered_words = [(w if w not in words_end else '.') for w in filtered_words]
    result = ' '.join(filtered_words)
    return(result)

# %%
# GET RID OF THE STOPWORDS IN TEXTS
data_proc = [filterWords(f, sw) for f in pdf_p]

# %%
import pickle
# exclude author list from metadata
author_metadata = pickle.load(open("C:/Thesis/Data/save/Master_Data/author_list/author_list.p", "rb"))

# %%
# GET RID OF THE author names (extracted from the metadata)
data_proc_1 = [filterWords(f, author_metadata) for f in data_proc] #running

# %%
data_proc_1[ref_doc]
# Out:
# ' capturing noonday demon development validation state boredom inventory terms conditions access use work organizational psychology issn -x - capturing noonday demon development validation state boredom inventory . . cite . . capturing noonday demon development validation state boredom inventory work organizational psychology - doi.. view supplementary material published online . submit views view related view crossmark data citing view citing capturing noonday demon development validation state boredom inventory . . department psychology guelph guelph abstract centuries scholars positioned state boredom impediment organizational productivity performancven unpleasant distracting qualities. state boredom impeded lack definitional consensus measurement issues. sought advance organizational state boredom developing state boredom inventory -item measurounded theoretically derived definition state boredom. studies independent samples develop sbi provide validity evidence measure including content validity convnt discriminant validity. data support conceptualization state boredom higher-order multidimensional construct underlying dimensions disgement unpleasant arousal inattention. history received accepted keywords boredom multidimensional scale development scale validation diary study viewed symptom modernity feeling bored studied human condition centuries. modern understanding state boredom originates theek word acedia translates care used idleness respect religious duties beginning fourth century.. acedia considered vices closely tied avoidance formal duties catholic . nicknamed noonday demon acedia thought strike midday distracting work tempting leave monastery search stimulation. catholic cassian described acedia making idle restless. writes stay cell spiritual progress state inactivity surrender drives makes addition unstable feckless. early accounts suggest changed respect people experience boredom work. cassian description acedia updated references contemporary workplaces refer cubicles instead cells unstable feckless employee distracting ineffective. boredom counterproductivity carried researchers recognizing feeling bored result distraction work. example trait boredom chronic propensity feel bored relates poor performance absenteeism turnover withdrawal deviance. despite etymological contemporary associations feeling bored employee effectiveness organizational state boredom limited. fact organizational behaviour literature wrought divnt contradictory definitions feeling bored addition suboptimal scales. sought contribute organizational state boredom developing measure consistent theoretically derived definition builds strhs existing scales addressing limitations. sections discussed synthesize theories definitions state boredom aim building consensus unifying definition. review state boredom typically measured outline implications testing organizational theory explain new scale needed. finally deductive approach scale development provide validation evidence measure studies samples. defining state boredom word boredom appear ish language mid-th century. novel bleak cited printed use term. despite fact word boredom years concept centuries contemporary scholars agree definition feeling bored. psychology existing definitions div quite severely. example defined arousal dissatisfaction subjective monotony and... frustration effortful maintenance attention contact . work organizational psychology .  .  informa uk limited trading feeling unchalld perceiving activities meaningless. examples illustrate overlap content definitions arguing antithetical content. absence accepted definition makes difficult build theory state boredom relates organizational variables researchers define differently essentially theorizing different constructs. given disparate content definitions unlikely researchers expect constructs exhibit comparable associations variables. example employee experiences meaninglessness lack chall demonstrate different patt ...

# %%
data_proc2 = [re.sub("([a-z]+\.)+[a-z]+","", f) for f in data_proc_1]
data_proc2 = [re.sub('\s([?\.!"](?:\s|$))' , r'\1', f) for f in data_proc2]
data_proc2 = [re.sub("^\s+","", f) for f in data_proc2]
data_proc2 = [re.sub("\s+\Z","", f) for f in data_proc2]
data_proc2 = [re.sub("(\.)+",".", f) for f in data_proc2]
data_proc2 = [re.sub(" +"," ", f) for f in data_proc2]
data_proc2 = [re.sub("( +\.)",".", f) for f in data_proc2]
data_proc2 = [re.sub("\.$","", f) for f in data_proc2]

# %%
print(data_proc2[ref_doc].split('. '))

sents = []
for d in data_proc2:
    sents += d.split('. ')
# Out:
# ['capturing noonday demon development validation state boredom inventory terms conditions access use work organizational psychology issn -x - capturing noonday demon development validation state boredom inventory.', 'cite.', 'capturing noonday demon development validation state boredom inventory work organizational psychology - doi', 'view supplementary material published online', 'submit views view related view crossmark data citing view citing capturing noonday demon development validation state boredom inventory.', 'department psychology guelph guelph abstract centuries scholars positioned state boredom impediment organizational productivity performancven unpleasant distracting qualities', 'state boredom impeded lack definitional consensus measurement issues', 'sought advance organizational state boredom developing state boredom inventory -item measurounded theoretically derived definition state boredom', 'studies independent samples develop sbi provide validity evidence measure including content validity convnt discriminant validity', 'data support conceptualization state boredom higher-order multidimensional construct underlying dimensions disgement unpleasant arousal inattention', 'history received accepted keywords boredom multidimensional scale development scale validation diary study viewed symptom modernity feeling bored studied human condition centuries', 'modern understanding state boredom originates theek word acedia translates care used idleness respect religious duties beginning fourth century', 'acedia considered vices closely tied avoidance formal duties catholic', 'nicknamed noonday demon acedia thought strike midday distracting work tempting leave monastery search stimulation', 'catholic cassian described acedia making idle restless', 'writes stay cell spiritual progress state inactivity surrender drives makes addition unstable feckless', 'early accounts suggest changed respect people experience boredom work', 'cassian description acedia updated references contemporary workplaces refer cubicles instead cells unstable feckless employee distracting ineffective', 'boredom counterproductivity carried researchers recognizing feeling bored result distraction work', 'example trait boredom chronic propensity feel bored relates poor performance absenteeism turnover withdrawal deviance', 'despite etymological contemporary associations feeling bored employee effectiveness organizational state boredom limited', 'fact organizational behaviour literature wrought divnt contradictory definitions feeling bored addition suboptimal scales', 'sought contribute organizational state boredom developing measure consistent theoretically derived definition builds strhs existing scales addressing limitations', 'sections discussed synthesize theories definitions state boredom aim building consensus unifying definition', 'review state boredom typically measured outline implications testing organizational theory explain new scale needed', 'finally deductive approach scale development provide validation evidence measure studies samples', 'defining state boredom word boredom appear ish language mid-th century', 'novel bleak cited printed use term', 'despite fact word boredom years concept centuries contemporary scholars agree definition feeling bored', 'psychology existing definitions div quite severely', 'example defined arousal dissatisfaction subjective monotony and', 'frustration effortful maintenance attention contact', 'work organizational psychology.', 'informa uk limited trading feeling unchalld perceiving activities meaningless', 'examples illustrate overlap content definitions arguing antithetical content', 'absence accepted definition makes difficult build theory state boredom relates organizational variables researchers define differently essentially theorizing different constructs', 'given disparate content definitions unlikely researchers expect constructs exhibit comparable associations variables', 'example employee experien ...

# %%
print(sents[0:100])
# Out:
# ['tf-pewo', 'terms conditions access use work organizational psychology issn -x - emotional regulation mediator interpersonal mistreatment distress', 'jennica', 'cite', 'jennica', 'emotional regulation mediator interpersonal mistreatment distress work organizational psychology - doi', 'published online jul', 'submit views view related citing view citing emotional regulation mediator interpersonal mistreatment distress', 'jennica', 'department human resources wisconsin oshkosh oshkosh wi department marquette milwaukee wi theory emotional labour literature focusing mistreatment employees customers used examine interpersonal mistreatment customers coworkers supervisors', 'specifically examined relationships sources interpersonal mistreatment psychological distress', 'examine possibility emotional regulation strategies mediated relationships', 'study focused acting mediating emotional regulation strategy', 'sample working adults results study mediating role acting mistreatment distress mistreatment customers coworkers supervisors', 'study included measures deep acting acting potential mediators sources mistreatment distress', 'sample working adults second study acting mediated relationship mistreatment distress mistreatment customers coworkers supervisors', 'deep acting mediate relationships sources mistreatment psychological distress', 'conclude acting plays important mediating role relationship interpersonal mistreatment customers coworkers psychological distress', 'keywords emotional labour emotional regulation interpersonal mistreatment interpersonal conflict incivility abusive supervision occupational stress', 'unfortunate probably recall time work lives treated rudely verbally abused harassed interpersonal conflicts customers coworkers supervisors', 'encounters include threatened actual physical altercations referred interpersonal mistreatment researchers areas studied', 'example area organizational behaviour identified number types mistreatment coworkers supervisors incivility abusive supervision', 'area occupational stress examined variables general interpersonal conflict stemming coworkers supervisors', 'produced considerable evidence threneral conclusions interper sonal mistreatment prevalent likely result negative outcomes experience important distinguish various sources interpersonal mistreatment interpersonal mistreatment emotion-provoking event', 'related largely separate literature area emotional labour studied interpersonal mistreatment', 'exceptions focused interpersonal mistreatment arising interactions customers', 'similar literature coworkers supervisors sources interpersonal mistreatment correspondence addressed', 'department human resources wisconsin oshkosh algoma blvd', 'oshkosh wi', 'work organizational psychology.', 'emotional labour shown interpersonal mistreatment customers prevalent leads negative outcomes important distinguish sources interpersonal mistreatment interpersonal mistreatment experiences emotion-provoking events', 'important departure literature focus regulation emotions order display organizationally appropriate emotions interpersonal mistreatment', 'generally suggests emotional regulation plays important mediating role interpersonal mistreatment customers negative outcomes', 'addition direct effects interpersonal mistreatment outcomes interpersonal mistreatment indirect effect outcomes emotional regulation', 'response calls closer integration literatures note important understudied issues', 'studies included separate measures sources interpersonal mistreatment', 'lead overestimate relationship single source interpersonal mistreatment outcomes', 'makes impossible determine relative impact interpersonal mistreatment sources outcomes', 'second studies examined emotional regulation mediator relationships interpersonal mistreatment sources outcomes simultaneously', 'leaves ambiguity regarding underlying mechanism interpersonal mistreatment sources outcomes', 'purpose study address issues', 'd ...

# %%
# save data
pickle.dump(data_proc2, open( "C:/Thesis/Data/save/Master_Data/pre_processed_data/data_preprocessed.p", "wb" ) )

# %%
import io

# writing documents one sentence per line to form a larger data set (allowing use of a generator for model training):
with open("C:/Thesis/Data/save/Master_Data/pre_processed_data/data_preprocessed_txt.txt", "a",encoding="utf-8") as outfile:
    
    for s in sents:
        outstring = s + '\n'
        outfile.write(outstring)
        
# (additionally you could keep document boundaries intact, 
# e.g. by writing a file per document or marking start and end of articles in the larger file)

# %%
#import io
#with open("C:/Thesis/Data/save/Master_Data/MD_3/data_proc_latest/JM_data_proc_txt.txt", "w",encoding="utf-8") as outfile:
#    for i in range(len(data_proc)):
#        outstring = ""
#        outstring += str(data_proc[i])
#        outfile.write(outstring)
