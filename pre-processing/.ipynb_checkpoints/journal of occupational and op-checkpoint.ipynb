# %%
import os
import re
import pandas as pd
import urllib
from nltk import SnowballStemmer
from gensim.models import Word2Vec
#import langdetect
import tika
import time
from tika import parser
import pickle

# %% [markdown]
# # Raw Articles pdf Data
# Convert pdf to text using Tika apache server

# %%
# specify the target data folder
target_dir = 'C:/Thesis/Data/Journal_of_occupational_and_OP'

# %%
# prep pdf extraction
pdf_files = []
wrd_files = []

for f in os.listdir(target_dir):
    if f.endswith(".pdf") | f.endswith(".PDF"):
        thispdf = os.path.join(target_dir, f)
        pdf_files = pdf_files + [thispdf]
    if f.endswith(".doc") | f.endswith(".docx") | f.endswith(".DOC") | f.endswith(".DOCX"):
        thiswrd = os.path.join(target_dir, f)
        wrd_files = wrd_files + [thiswrd]

# %%
port = 4321 # port to use for Tika server (chosen arbitrarily)
server_str = 'http://localhost:' + str(port)
tika_path  = 'C:\Software\ tika-server-1.23.jar'
tika_run   = 'java -jar' + tika_path + ' --port ' + str(port)
print('Command to start Tika:')
print(tika_run)
print('---')
print('Number of pdf files: ' + str(len(pdf_files)))
print('Number of word files: ' + str(len(wrd_files)))
# Out:
# Command to start Tika:
# java -jarC:\Software\ tika-server-1.23.jar --port 4321
# ---
# Number of pdf files: 779
# Number of word files: 0

# %% [markdown]
# # pdf Metadata

# %%
# process the PDF files, store text in memory
tika.TikaClientOnly = True 

pdf_metadata= [parser.from_file(t, server_str, xmlContent=False)["metadata"] for t in (pdf_files + wrd_files)]

# %%
# save data metadata
pickle.dump(pdf_metadata, open( "C:/Thesis/Data/save/Journal_of_occupational_and_OP/metadata/metadata_all.p", "wb" ) )

# %% [markdown]
# # Text Data
#
# Eliminate title, sections (eg: content between Method and Discussion) and Reference. It is saved as a pre-processed data

# %%
# process the PDF files, store text in memory
tika.TikaClientOnly = True 

#pdf_text = [parser.from_file(t, server_str, xmlContent=False)["content"] for t in (pdf_files + wrd_files)]

# %% [markdown]
# # step-1 Load pdf content

# %%
import pickle
#load the text data
pdf_text = pickle.load(open("C:/Thesis/Data/save/Journal_of_occupational_and_OP/save_alltextData.p", "rb"))

# %% [markdown]
# # step-2 convert it to lowercase

# %%
#Convert each string to lowercase
for i in range(len(pdf_text)):
    pdf_text[i] = pdf_text[i].lower()

# %% [markdown]
# # step-3 remove reference

# %%
# remove references section 
import re
pdf_ref = [re.sub(r"(?is)\nreferences\n.+", "", f) for f in pdf_text]

# %%
pdf_ref[10]
# Out:
# '\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\ndecision inertia: deciding between least worst outcomes in emergency responses to disasters\n\n\njournal of occupational and organizational psychology (2015), 88, 295–321\n\n© 2015 the british psychological society\n\nwww.wileyonlinelibrary.com\n\nspecial section paper\n\ndecision inertia: deciding between least worst\noutcomes in emergency responses to disasters\n\nlaurence alison*, nicola power, claudia van den heuvel,\nmichael humann, marek palasinksi and jonathan crego\ncentre for critical and major incident psychology, university of liverpool, uk\n\nthis study demonstrates how naturalistic decision-making (ndm) can be usefully applied\n\nto study ‘decision inertia’ – namely the cognitive process associated with failures to\nexecute action when a decision-maker struggles to choose between equally perceived\n\naversive outcomes. data assessed the response and recovery from a sudden impact\n\ndisaster during a 2-day immersive simulated emergency response. fourteen agencies\n\n(including police, fire, ambulance, and military) and 194 participants were involved in the\n\nexercise. by assessing the frequency, type, audience, and content of communications, and\n\nby reference to five subject matter experts’ slow time analyses of critical turning points\n\nduring the incident, three barriers were identified as reducing multiagency information\n\nsharing and the macrocognitive understanding of the incident. when the decision\n\nproblem was non-time-bounded, involved multiple agencies, and identification of\n\nsuperordinate goals was lacking, the communication between agencies decreased and\n\nagencies focused on within-agency information sharing. these barriers distracted teams\n\nfrom timely and efficient discussions on decisions and action execution with seeking\n\nredundant information, which resulted in decision inertia. our study illustrates how\n\nnaturalistic environments are conducive to examining relatively understudied concepts of\n\ndecision inertia, failures to act, and shared situational macrocognition in situations\n\ninvolving large distributed teams.\n\npractitioner points\n\n� researchers can use ndm to explore the cognitive processing associated with failures to act/decision\ninertia.\n\n� complexities in the decision-making environment of a multiteam system (e.g., non-time-bounded\nchoice, large team size, and lack of strategic goals) are associated with decision-making failures.\n\n� barriers cause decision inertia as teams focus on redundant intra-agency information seeking rather\nthan cooperative interagency communications.\n\n� strategic direction is especially important for shifting multiteam system communication towards\ninteragency discussions on action execution.\n\nif the behavioural implementation of making a decision is the execution of action\n\n(lipshitz, klein, orasanu, & salas, 2001; yates, 2003), then failing tomake a decision (e.g.,\n\nmaking an executive choice) is when action execution fails. traditional decision-making\n\n*correspondence should be addressed to laurence alison, department of psychological sciences, eleanor rathbone building,\nbedford street south, university of liverpool, liverpool l69 7za, uk (email: l.j.alison@liverpool.ac.uk).\n\ndoi:10.1111/joop.12108\n\n295\n\n\n\nresearch has helped psychologists to understand the conditions under which decisions\n\nare likely to be actioned in a static, closed environment, where decision-makers have the\n\nopportunity to analyse the choice context and select an optimal course of action (e.g.,\n\nexpected utility theory; von neumann & morgenstern, 1947). yet in the ‘real world’,\ndecision-makers rarely have the luxury of having unambiguous information or sufficient\n\ntime to analyse choices, and thus, their rationality is bound by cognitive constraints\n\n(simon, 1956).whilst early research treated bounded rationality asmaladaptive in causing\n\n ...

# %% [markdown]
# # step-4 load metadata

# %%
import pickle
#load the text data
pdf_metadata = pickle.load(open("C:/Thesis/Data/save/Journal_of_occupational_and_OP/metadata/metadata_all.p", "rb"))

# %% [markdown]
# # step-5 get metadata = author, subject, title

# %%
pdf_title = []
pdf_Author = []
pdf_subject = []

for i in pdf_metadata:
    try:
        temp = i['title']
        auth_temp = i['Author']
        subj_temp = i['subject']
      
        pdf_title.append(temp.lower())
        pdf_Author.append(auth_temp.lower()) 
        pdf_subject.append(subj_temp.lower()) 
        
    except:
        #print("An exception occurred" )
        pdf_title.append(temp.lower())
        pdf_Author.append(auth_temp.lower())
        pdf_subject.append(subj_temp.lower())

# %%
pdf_Author
# Out:
# ['ambika',
#  'ambika',
#  'ambika',
#  'ambika',
#  'ambika',
#  'ambika',
#  'ambika',
#  'ambika',
#  '',
#  '',
#  '',
#  'natalie j. allen ; tracy d. hecht',
#  'natalie j. allen ; tracy d. hecht',
#  '',
#  '',
#  '',
#  'neil anderson ; sarah sleap',
#  '',
#  '',
#  'ambika',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'ambika',
#  'ambika',
#  '',
#  '',
#  '',
#  '',
#  'ambika',
#  'ambika',
#  'ambika',
#  'ambika',
#  'ambika',
#  'ambika',
#  'ambika',
#  'ambika',
#  'ambika',
#  'ambika',
#  'ambika',
#  'ambika',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'ambika',
#  'ambika',
#  'ambika',
#  'ambika',
#  'ambika',
#  'ambika',
#  'ambika',
#  'ambika',
#  'ambika',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'nikos bozionelos',
#  'nikos bozionelos',
#  'nikos bozionelos',
#  'nikos bozionelos',
#  'nikos bozionelos',
#  'nikos bozionelos',
#  '',
#  '',
#  '',
#  '',
#  'ambika',
#  'ambika',
#  'ambika',
#  'adam b. butler ; amie skattebo',
#  'adam b. butler ; amie skattebo',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'ambika',
#  'ambika',
#  'ambika',
#  'ambika',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'ambika',
#  'ambika',
#  '',
#  'john cordery',
#  'john cordery',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'kevin daniels ; claire harris ; rob b. briner',
#  'ambika',
#  'ambika',
#  'ambika',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'ambika',
#  'ambika',
#  'ambika',
#  '',
#  '',
#  'ambika',
#  'ambika',
#  'ambika',
#  'ambika',
#  'ambika',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'taru feldt ; mika kivim&auml;ki ; anne rantala ; asko tolvanen',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'ambika',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'donald g. gardner ; linn van dyne ; jon l. pierce',
#  'donald g. gardner ; linn van dyne ; jon l. pierce',
#  'donald g. gardner ; linn van dyne ; jon l. pierce',
#  'donald g. gardner ; linn van dyne ; jon l. pierce',
#  'donald g. gardner ; linn van dyne ; jon l. pierce',
#  'donald g. gardner ; linn van dyne ; jon l. pierce',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'ambika',
#  'ambika',
#  'ambika',
#  'ambika',
#  'ambika',
#  'ambika',
#  'ambika',
#  'ambika',
#  'ambika',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'ambika',
#  'ambika',
#  'ambika',
#  '',
#  'ambika',
#  'ambika',
#  'ambika',
#  'ambika',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'ambika',
#  'ambika',
#  '',
#  'ambika',
#  'ambika',
#  'ambika',
#  'ambika',
#  'ambika',
#  '',
#  '',
#  '',
#  '',
#  'ambika',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'ambika',
#  'ambika',
#  'ambika',
#  'ambika',
#  'ambika',
#  'ambika',
#  'ambika',
#  'ambika',
#  'ambika',
#  'ambika',
#  'ambika',
#  'ambika',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'ambika',
#  'ambika',
#  'ambika',
#  'ambika',
#  'ambika',
#  'ambika',
#  'ambika',
#  'ambika',
#  'ambika',
#  'ambika',
#  'ambika',
#  'ambika',
#  'ambika',
#  'ambika',
#  'ambika',
#  'ambika',
#  'ambika',
#  'ambika',
#  'ambika',
#  'ambika',
#  'ambika',
#  'ambika',
#  'ambika',
#  'ambika',
#  '',
#  '',
#  '',
#  '',
#  'ambika',
#  'ambika',
#  'ambika',
#  'ambika',
#  'ambika',
#  'ambika',
#  'ambika',
#  'ambika',
#  '',
#  '',
#  'ambika',
#  'ambika',
#  'ambika',
#  'ambika',
#  'ambika',
#  'ambika',
#  'ambika',
#  '',
#  '',
#  '',
#  'ambika',
#  'ambika',
#  'ambika',
#  'filip lievens ; frederik anseel',
#  'ambika',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'ambika',
#  'ambika',
#  'ambika',
#  'ambika',
#  'ambika',
#  'ambika',
#  'ambika',
#  'ambika',
#  'ambika',
#  'ambika',
#  'ambika',
#  'ambika',
#  'ambika',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'ambika',
#  'ambika',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'adam w. meade',
#  'adam w. meade',
#  'james r. meindl',
#  'james r. meindl',
#  'james r. meindl',
#  'james r. meindl',
#  'james r. meindl',
#  'james r. meindl',
#  'james r. meindl',
#  'james r. meindl',
#  'james r. meindl',
#  'ambika',
#  'ambika',
#  'ambika',
#  'ambika',
#  'ambika',
#  'ambika',
#  'ambika',
#  'ambika',
#  'ambika',
#  'ambika',
#  'ambika',
#  'ambika',
#  'ambika',
#  'ambika',
#  'ambika',
#  'ambika',
#  'ambika',
#  'ambika',
#  'ambika',
#  'ambika',
#  'ambika',
#  'ambika',
#  'ambika',
#  'ambika',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'ambika',
#  'ambika',
#  'ambika',
#  'ambika',
#  'ambika',
#  'ambika',
#  'ambika',
#  'ambika',
#  'ambika',
#  'ambika',
#  'ambika',
#  'ambika',
#  'ambika',
#  'ambika',
#  'ambika',
#  'ambika',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'ambika',
#  '',
#  '',
#  'ambika',
#  'ambika',
#  'paul b. paulus ; karen van der zee',
#  'paul b. paulus ; karen van der zee',
#  'paul b. paulus ; karen van der zee',
#  'paul b. paulus ; karen van der zee',
#  'ambika',
#  'ambika',
#  '',
#  '',
#  '',
#  '',
#  'ambika',
#  'ambika',
#  'ambika',
#  'ambika',
#  'ambika',
#  'ambika',
#  'ambika',
#  'ambika',
#  'ambika',
#  'ambika',
#  'ambika',
#  'ambika',
#  'ambika',
#  'ambika',
#  'ambika',
#  'ambika',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'ambika',
#  'ambika',
#  '',
#  '',
#  '',
#  '',
#  'charlie l. reeve ; eric d. heggestad',
#  'charlie l. reeve ; eric d. heggestad',
#  'charlie l. reeve ; eric d. heggestad',
#  'charlie l. reeve ; eric d. heggestad',
#  'charlie l. reeve ; eric d. heggestad',
#  'astrid m. richardsen ; monica martinussen',
#  '',
#  '',
#  '',
#  '',
#  'ambika',
#  'ambika',
#  'ambika',
#  'ambika',
#  'ambika',
#  'ambika',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'ambika',
#  'ambika',
#  'ambika',
#  'ambika',
#  '',
#  '',
#  '',
#  'ambika',
#  'ambika',
#  '',
#  '',
#  '',
#  'ambika',
#  'ambika',
#  'ambika',
#  'ambika',
#  'ambika',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'anit somech ; anat drach-zahavy',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'ambika',
#  'ambika',
#  'ambika',
#  'ambika',
#  'ambika',
#  'ambika',
#  'ambika',
#  'ambika',
#  '',
#  '',
#  'gigi sutton ; mark a. griffin',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'ambika',
#  'ambika',
#  'ambika',
#  'ambika',
#  'ambika',
#  'ambika',
#  'ambika',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'ambika',
#  'ambika',
#  '',
#  '',
#  'william h. turnley ; mark c. bolino ; scott w. lester ; james m. bloodgood',
#  'william h. turnley ; mark c. bolino ; scott w. lester ; james m. bloodgood',
#  'william h. turnley ; mark c. bolino ; scott w. lester ; james m. bloodgood',
#  'william h. turnley ; mark c. bolino ; scott w. lester ; james m. bloodgood',
#  'william h. turnley ; mark c. bolino ; scott w. lester ; james m. bloodgood',
#  'william h. turnley ; mark c. bolino ; scott w. lester ; james m. bloodgood',
#  'william h. turnley ; mark c. bolino ; scott w. lester ; james m. bloodgood',
#  'william h. turnley ; mark c. bolino ; scott w. lester ; james m. bloodgood',
#  'william h. turnley ; mark c. bolino ; scott w. lester ; james m. bloodgood',
#  'william h. turnley ; mark c. bolino ; scott w. lester ; james m. bloodgood',
#  'william h. turnley ; mark c. bolino ; scott w. lester ; james m. bloodgood',
#  'william h. turnley ; mark c. bolino ; scott w. lester ; james m. bloodgood',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'joan e. van horn ; toon w. taris ; wilmar b. schaufeli ; paul j.g. schreurs',
#  'joan e. van horn ; toon w. taris ; wilmar b. schaufeli ; paul j.g. schreurs',
#  'joan e. van horn ; toon w. taris ; wilmar b. schaufeli ; paul j.g. schreurs',
#  'joan e. van horn ; toon w. taris ; wilmar b. schaufeli ; paul j.g. schreurs',
#  'joan e. van horn ; toon w. taris ; wilmar b. schaufeli ; paul j.g. schreurs',
#  '',
#  '',
#  '',
#  '',
#  'ambika',
#  'ambika',
#  'ambika',
#  'ambika',
#  'ambika',
#  'ambika',
#  'ambika',
#  'ambika',
#  'ambika',
#  'ambika',
#  'ambika',
#  'ambika',
#  'ambika',
#  'ambika',
#  'fred o. walumbwa ; peng wang ; john j. lawler ; kan shi',
#  'ambika',
#  'ambika',
#  'ambika',
#  'ambika',
#  'ambika',
#  'ambika',
#  'ambika',
#  'ambika',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'michael a. west ; felix c. brodbeck ; andreas w. richter',
#  'michael a. west ; felix c. brodbeck ; andreas w. richter',
#  'michael a. west ; felix c. brodbeck ; andreas w. richter',
#  'michael a. west ; felix c. brodbeck ; andreas w. richter',
#  'michael a. west ; felix c. brodbeck ; andreas w. richter',
#  'michael a. west ; felix c. brodbeck ; andreas w. richter',
#  'michael a. west ; felix c. brodbeck ; andreas w. richter',
#  'michael a. west ; felix c. brodbeck ; andreas w. richter',
#  'mark g. wilson ; david m. dejoy ; robert j. vandenberg ; hettie a. richardson ; allison l. mcgrath',
#  'ambika',
#  'ambika',
#  'ambika',
#  'ambika',
#  'ambika',
#  'ambika',
#  '',
#  'ambika',
#  'ambika',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'ambika',
#  'ambika',
#  'ambika',
#  'ambika',
#  'ambika',
#  'ambika',
#  'ambika',
#  'ambika',
#  'ambika']

# %%
# pre-process author
import re
pdf_auth = []

for j in pdf_Author:
    k = re.sub(' and ', '', str(j))
    k = re.sub('[!;&$]', '', k)
    k = re.sub('[0-9]+', '', k)
    k = re.sub( r'\b\w{1,3}\b', '', k)
    k = re.sub( r'-', ' ', k)
#     pdf_p = [re.sub(' +', ' ', f) for f in pdf_p]
    k = re.sub(' +', ',', k)
    k = k.split(",")
   
    pdf_auth.append(k)

# %%
pdf_auth
# Out:
# [['ambika'],
#  ['ambika'],
#  ['ambika'],
#  ['ambika'],
#  ['ambika'],
#  ['ambika'],
#  ['ambika'],
#  ['ambika'],
#  [''],
#  [''],
#  [''],
#  ['natalie', '.', 'allen', 'tracy', '.', 'hecht'],
#  ['natalie', '.', 'allen', 'tracy', '.', 'hecht'],
#  [''],
#  [''],
#  [''],
#  ['neil', 'anderson', 'sarah', 'sleap'],
#  [''],
#  [''],
#  ['ambika'],
#  [''],
#  [''],
#  [''],
#  [''],
#  [''],
#  [''],
#  ['ambika'],
#  ['ambika'],
#  [''],
#  [''],
#  [''],
#  [''],
#  ['ambika'],
#  ['ambika'],
#  ['ambika'],
#  ['ambika'],
#  ['ambika'],
#  ['ambika'],
#  ['ambika'],
#  ['ambika'],
#  ['ambika'],
#  ['ambika'],
#  ['ambika'],
#  ['ambika'],
#  [''],
#  [''],
#  [''],
#  [''],
#  [''],
#  [''],
#  [''],
#  [''],
#  ['ambika'],
#  ['ambika'],
#  ['ambika'],
#  ['ambika'],
#  ['ambika'],
#  ['ambika'],
#  ['ambika'],
#  ['ambika'],
#  ['ambika'],
#  [''],
#  [''],
#  [''],
#  [''],
#  [''],
#  [''],
#  [''],
#  [''],
#  [''],
#  [''],
#  [''],
#  [''],
#  [''],
#  [''],
#  ['nikos', 'bozionelos'],
#  ['nikos', 'bozionelos'],
#  ['nikos', 'bozionelos'],
#  ['nikos', 'bozionelos'],
#  ['nikos', 'bozionelos'],
#  ['nikos', 'bozionelos'],
#  [''],
#  [''],
#  [''],
#  [''],
#  ['ambika'],
#  ['ambika'],
#  ['ambika'],
#  ['adam', '.', 'butler', 'amie', 'skattebo'],
#  ['adam', '.', 'butler', 'amie', 'skattebo'],
#  [''],
#  [''],
#  [''],
#  [''],
#  [''],
#  [''],
#  [''],
#  [''],
#  [''],
#  [''],
#  [''],
#  [''],
#  [''],
#  ['ambika'],
#  ['ambika'],
#  ['ambika'],
#  ['ambika'],
#  [''],
#  [''],
#  [''],
#  [''],
#  [''],
#  [''],
#  [''],
#  [''],
#  [''],
#  [''],
#  [''],
#  [''],
#  [''],
#  [''],
#  [''],
#  [''],
#  [''],
#  [''],
#  [''],
#  [''],
#  [''],
#  [''],
#  [''],
#  ['ambika'],
#  ['ambika'],
#  [''],
#  ['john', 'cordery'],
#  ['john', 'cordery'],
#  [''],
#  [''],
#  [''],
#  [''],
#  [''],
#  [''],
#  [''],
#  [''],
#  ['kevin', 'daniels', 'claire', 'harris', '.', 'briner'],
#  ['ambika'],
#  ['ambika'],
#  ['ambika'],
#  [''],
#  [''],
#  [''],
#  [''],
#  [''],
#  [''],
#  ['ambika'],
#  ['ambika'],
#  ['ambika'],
#  [''],
#  [''],
#  ['ambika'],
#  ['ambika'],
#  ['ambika'],
#  ['ambika'],
#  ['ambika'],
#  [''],
#  [''],
#  [''],
#  [''],
#  [''],
#  [''],
#  [''],
#  [''],
#  [''],
#  [''],
#  [''],
#  [''],
#  [''],
#  [''],
#  [''],
#  [''],
#  [''],
#  [''],
#  [''],
#  [''],
#  [''],
#  [''],
#  [''],
#  [''],
#  [''],
#  [''],
#  [''],
#  [''],
#  [''],
#  [''],
#  [''],
#  [''],
#  [''],
#  [''],
#  [''],
#  ['taru',
#   'feldt',
#   'mika',
#   'kivimaumlki',
#   'anne',
#   'rantala',
#   'asko',
#   'tolvanen'],
#  [''],
#  [''],
#  [''],
#  [''],
#  [''],
#  [''],
#  [''],
#  [''],
#  [''],
#  [''],
#  [''],
#  ['ambika'],
#  [''],
#  [''],
#  [''],
#  [''],
#  [''],
#  [''],
#  [''],
#  [''],
#  [''],
#  [''],
#  [''],
#  [''],
#  ['donald', '.', 'gardner', 'linn', 'dyne', '.', 'pierce'],
#  ['donald', '.', 'gardner', 'linn', 'dyne', '.', 'pierce'],
#  ['donald', '.', 'gardner', 'linn', 'dyne', '.', 'pierce'],
#  ['donald', '.', 'gardner', 'linn', 'dyne', '.', 'pierce'],
#  ['donald', '.', 'gardner', 'linn', 'dyne', '.', 'pierce'],
#  ['donald', '.', 'gardner', 'linn', 'dyne', '.', 'pierce'],
#  [''],
#  [''],
#  [''],
#  [''],
#  [''],
#  [''],
#  [''],
#  [''],
#  [''],
#  ['ambika'],
#  ['ambika'],
#  ['ambika'],
#  ['ambika'],
#  ['ambika'],
#  ['ambika'],
#  ['ambika'],
#  ['ambika'],
#  ['ambika'],
#  [''],
#  [''],
#  [''],
#  [''],
#  [''],
#  [''],
#  [''],
#  ['ambika'],
#  ['ambika'],
#  ['ambika'],
#  [''],
#  ['ambika'],
#  ['ambika'],
#  ['ambika'],
#  ['ambika'],
#  [''],
#  [''],
#  [''],
#  [''],
#  [''],
#  [''],
#  [''],
#  [''],
#  [''],
#  [''],
#  [''],
#  [''],
#  [''],
#  [''],
#  [''],
#  [''],
#  [''],
#  [''],
#  [''],
#  ['ambika'],
#  ['ambika'],
#  [''],
#  ['ambika'],
#  ['ambika'],
#  ['ambika'],
#  ['ambika'],
#  ['ambika'],
#  [''],
#  [''],
#  [''],
#  [''],
#  ['ambika'],
#  [''],
#  [''],
#  [''],
#  [''],
#  [''],
#  ['ambika'],
#  ['ambika'],
#  ['ambika'],
#  ['ambika'],
#  ['ambika'],
#  ['ambika'],
#  ['ambika'],
#  ['ambika'],
#  ['ambika'],
#  ['ambika'],
#  ['ambika'],
#  ['ambika'],
#  [''],
#  [''],
#  [''],
#  [''],
#  [''],
#  [''],
#  [''],
#  [''],
#  [''],
#  [''],
#  [''],
#  [''],
#  [''],
#  [''],
#  [''],
#  [''],
#  [''],
#  [''],
#  [''],
#  [''],
#  ['ambika'],
#  ['ambika'],
#  ['ambika'],
#  ['ambika'],
#  ['ambika'],
#  ['ambika'],
#  ['ambika'],
#  ['ambika'],
#  ['ambika'],
#  ['ambika'],
#  ['ambika'],
#  ['ambika'],
#  ['ambika'],
#  ['ambika'],
#  ['ambika'],
#  ['ambika'],
#  ['ambika'],
#  ['ambika'],
#  ['ambika'],
#  ['ambika'],
#  ['ambika'],
#  ['ambika'],
#  ['ambika'],
#  ['ambika'],
#  [''],
#  [''],
#  [''],
#  [''],
#  ['ambika'],
#  ['ambika'],
#  ['ambika'],
#  ['ambika'],
#  ['ambika'],
#  ['ambika'],
#  ['ambika'],
#  ['ambika'],
#  [''],
#  [''],
#  ['ambika'],
#  ['ambika'],
#  ['ambika'],
#  ['ambika'],
#  ['ambika'],
#  ['ambika'],
#  ['ambika'],
#  [''],
#  [''],
#  [''],
#  ['ambika'],
#  ['ambika'],
#  ['ambika'],
#  ['filip', 'lievens', 'frederik', 'anseel'],
#  ['ambika'],
#  [''],
#  [''],
#  [''],
#  [''],
#  [''],
#  [''],
#  [''],
#  [''],
#  [''],
#  [''],
#  [''],
#  ['ambika'],
#  ['ambika'],
#  ['ambika'],
#  ['ambika'],
#  ['ambika'],
#  ['ambika'],
#  ['ambika'],
#  ['ambika'],
#  ['ambika'],
#  ['ambika'],
#  ['ambika'],
#  ['ambika'],
#  ['ambika'],
#  [''],
#  [''],
#  [''],
#  [''],
#  [''],
#  [''],
#  [''],
#  [''],
#  [''],
#  [''],
#  [''],
#  [''],
#  [''],
#  [''],
#  [''],
#  [''],
#  [''],
#  [''],
#  [''],
#  ['ambika'],
#  ['ambika'],
#  [''],
#  [''],
#  [''],
#  [''],
#  [''],
#  [''],
#  [''],
#  [''],
#  [''],
#  [''],
#  [''],
#  [''],
#  [''],
#  [''],
#  [''],
#  [''],
#  [''],
#  ['adam', '.', 'meade'],
#  ['adam', '.', 'meade'],
#  ['james', '.', 'meindl'],
#  ['james', '.', 'meindl'],
#  ['james', '.', 'meindl'],
#  ['james', '.', 'meindl'],
#  ['james', '.', 'meindl'],
#  ['james', '.', 'meindl'],
#  ['james', '.', 'meindl'],
#  ['james', '.', 'meindl'],
#  ['james', '.', 'meindl'],
#  ['ambika'],
#  ['ambika'],
#  ['ambika'],
#  ['ambika'],
#  ['ambika'],
#  ['ambika'],
#  ['ambika'],
#  ['ambika'],
#  ['ambika'],
#  ['ambika'],
#  ['ambika'],
#  ['ambika'],
#  ['ambika'],
#  ['ambika'],
#  ['ambika'],
#  ['ambika'],
#  ['ambika'],
#  ['ambika'],
#  ['ambika'],
#  ['ambika'],
#  ['ambika'],
#  ['ambika'],
#  ['ambika'],
#  ['ambika'],
#  [''],
#  [''],
#  [''],
#  [''],
#  [''],
#  [''],
#  [''],
#  ['ambika'],
#  ['ambika'],
#  ['ambika'],
#  ['ambika'],
#  ['ambika'],
#  ['ambika'],
#  ['ambika'],
#  ['ambika'],
#  ['ambika'],
#  ['ambika'],
#  ['ambika'],
#  ['ambika'],
#  ['ambika'],
#  ['ambika'],
#  ['ambika'],
#  ['ambika'],
#  [''],
#  [''],
#  [''],
#  [''],
#  [''],
#  [''],
#  [''],
#  [''],
#  [''],
#  [''],
#  [''],
#  ['ambika'],
#  [''],
#  [''],
#  ['ambika'],
#  ['ambika'],
#  ['paul', '.', 'paulus', 'karen', ''],
#  ['paul', '.', 'paulus', 'karen', ''],
#  ['paul', '.', 'paulus', 'karen', ''],
#  ['paul', '.', 'paulus', 'karen', ''],
#  ['ambika'],
#  ['ambika'],
#  [''],
#  [''],
#  [''],
#  [''],
#  ['ambika'],
#  ['ambika'],
#  ['ambika'],
#  ['ambika'],
#  ['ambika'],
#  ['ambika'],
#  ['ambika'],
#  ['ambika'],
#  ['ambika'],
#  ['ambika'],
#  ['ambika'],
#  ['ambika'],
#  ['ambika'],
#  ['ambika'],
#  ['ambika'],
#  ['ambika'],
#  [''],
#  [''],
#  [''],
#  [''],
#  [''],
#  [''],
#  [''],
#  [''],
#  [''],
#  [''],
#  [''],
#  [''],
#  ['ambika'],
#  ['ambika'],
#  [''],
#  [''],
#  [''],
#  [''],
#  ['charlie', '.', 'reeve', 'eric', '.', 'heggestad'],
#  ['charlie', '.', 'reeve', 'eric', '.', 'heggestad'],
#  ['charlie', '.', 'reeve', 'eric', '.', 'heggestad'],
#  ['charlie', '.', 'reeve', 'eric', '.', 'heggestad'],
#  ['charlie', '.', 'reeve', 'eric', '.', 'heggestad'],
#  ['astrid', '.', 'richardsen', 'monica', 'martinussen'],
#  [''],
#  [''],
#  [''],
#  [''],
#  ['ambika'],
#  ['ambika'],
#  ['ambika'],
#  ['ambika'],
#  ['ambika'],
#  ['ambika'],
#  [''],
#  [''],
#  [''],
#  [''],
#  [''],
#  [''],
#  [''],
#  [''],
#  [''],
#  [''],
#  [''],
#  [''],
#  ['ambika'],
#  ['ambika'],
#  ['ambika'],
#  ['ambika'],
#  [''],
#  [''],
#  [''],
#  ['ambika'],
#  ['ambika'],
#  [''],
#  [''],
#  [''],
#  ['ambika'],
#  ['ambika'],
#  ['ambika'],
#  ['ambika'],
#  ['ambika'],
#  [''],
#  [''],
#  [''],
#  [''],
#  [''],
#  [''],
#  [''],
#  [''],
#  [''],
#  [''],
#  [''],
#  [''],
#  [''],
#  [''],
#  [''],
#  ['anit', 'somech', 'anat', 'drach', 'zahavy'],
#  [''],
#  [''],
#  [''],
#  [''],
#  [''],
#  [''],
#  [''],
#  [''],
#  ['ambika'],
#  ['ambika'],
#  ['ambika'],
#  ['ambika'],
#  ['ambika'],
#  ['ambika'],
#  ['ambika'],
#  ['ambika'],
#  [''],
#  [''],
#  ['gigi', 'sutton', 'mark', '.', 'griffin'],
#  [''],
#  [''],
#  [''],
#  [''],
#  [''],
#  [''],
#  [''],
#  [''],
#  [''],
#  [''],
#  [''],
#  ['ambika'],
#  ['ambika'],
#  ['ambika'],
#  ['ambika'],
#  ['ambika'],
#  ['ambika'],
#  ['ambika'],
#  [''],
#  [''],
#  [''],
#  [''],
#  [''],
#  [''],
#  [''],
#  [''],
#  [''],
#  ['ambika'],
#  ['ambika'],
#  [''],
#  [''],
#  ['william',
#   '.',
#   'turnley',
#   'mark',
#   '.',
#   'bolino',
#   'scott',
#   '.',
#   'lester',
#   'james',
#   '.',
#   'bloodgood'],
#  ['william',
#   '.',
#   'turnley',
#   'mark',
#   '.',
#   'bolino',
#   'scott',
#   '.',
#   'lester',
#   'james',
#   '.',
#   'bloodgood'],
#  ['william',
#   '.',
#   'turnley',
#   'mark',
#   '.',
#   'bolino',
#   'scott',
#   '.',
#   'lester',
#   'james',
#   '.',
#   'bloodgood'],
#  ['william',
#   '.',
#   'turnley',
#   'mark',
#   '.',
#   'bolino',
#   'scott',
#   '.',
#   'lester',
#   'james',
#   '.',
#   'bloodgood'],
#  ['william',
#   '.',
#   'turnley',
#   'mark',
#   '.',
#   'bolino',
#   'scott',
#   '.',
#   'lester',
#   'james',
#   '.',
#   'bloodgood'],
#  ['william',
#   '.',
#   'turnley',
#   'mark',
#   '.',
#   'bolino',
#   'scott',
#   '.',
#   'lester',
#   'james',
#   '.',
#   'bloodgood'],
#  ['william',
#   '.',
#   'turnley',
#   'mark',
#   '.',
#   'bolino',
#   'scott',
#   '.',
#   'lester',
#   'james',
#   '.',
#   'bloodgood'],
#  ['william',
#   '.',
#   'turnley',
#   'mark',
#   '.',
#   'bolino',
#   'scott',
#   '.',
#   'lester',
#   'james',
#   '.',
#   'bloodgood'],
#  ['william',
#   '.',
#   'turnley',
#   'mark',
#   '.',
#   'bolino',
#   'scott',
#   '.',
#   'lester',
#   'james',
#   '.',
#   'bloodgood'],
#  ['william',
#   '.',
#   'turnley',
#   'mark',
#   '.',
#   'bolino',
#   'scott',
#   '.',
#   'lester',
#   'james',
#   '.',
#   'bloodgood'],
#  ['william',
#   '.',
#   'turnley',
#   'mark',
#   '.',
#   'bolino',
#   'scott',
#   '.',
#   'lester',
#   'james',
#   '.',
#   'bloodgood'],
#  ['william',
#   '.',
#   'turnley',
#   'mark',
#   '.',
#   'bolino',
#   'scott',
#   '.',
#   'lester',
#   'james',
#   '.',
#   'bloodgood'],
#  [''],
#  [''],
#  [''],
#  [''],
#  [''],
#  [''],
#  [''],
#  [''],
#  [''],
#  [''],
#  [''],
#  ['joan',
#   '.',
#   'horn',
#   'toon',
#   '.',
#   'taris',
#   'wilmar',
#   '.',
#   'schaufeli',
#   'paul',
#   '..',
#   'schreurs'],
#  ['joan',
#   '.',
#   'horn',
#   'toon',
#   '.',
#   'taris',
#   'wilmar',
#   '.',
#   'schaufeli',
#   'paul',
#   '..',
#   'schreurs'],
#  ['joan',
#   '.',
#   'horn',
#   'toon',
#   '.',
#   'taris',
#   'wilmar',
#   '.',
#   'schaufeli',
#   'paul',
#   '..',
#   'schreurs'],
#  ['joan',
#   '.',
#   'horn',
#   'toon',
#   '.',
#   'taris',
#   'wilmar',
#   '.',
#   'schaufeli',
#   'paul',
#   '..',
#   'schreurs'],
#  ['joan',
#   '.',
#   'horn',
#   'toon',
#   '.',
#   'taris',
#   'wilmar',
#   '.',
#   'schaufeli',
#   'paul',
#   '..',
#   'schreurs'],
#  [''],
#  [''],
#  [''],
#  [''],
#  ['ambika'],
#  ['ambika'],
#  ['ambika'],
#  ['ambika'],
#  ['ambika'],
#  ['ambika'],
#  ['ambika'],
#  ['ambika'],
#  ['ambika'],
#  ['ambika'],
#  ['ambika'],
#  ['ambika'],
#  ['ambika'],
#  ['ambika'],
#  ['fred', '.', 'walumbwa', 'peng', 'wang', 'john', '.', 'lawler', ''],
#  ['ambika'],
#  ['ambika'],
#  ['ambika'],
#  ['ambika'],
#  ['ambika'],
#  ['ambika'],
#  ['ambika'],
#  ['ambika'],
#  [''],
#  [''],
#  [''],
#  [''],
#  [''],
#  [''],
#  [''],
#  [''],
#  [''],
#  [''],
#  ['michael', '.', 'west', 'felix', '.', 'brodbeck', 'andreas', '.', 'richter'],
#  ['michael', '.', 'west', 'felix', '.', 'brodbeck', 'andreas', '.', 'richter'],
#  ['michael', '.', 'west', 'felix', '.', 'brodbeck', 'andreas', '.', 'richter'],
#  ['michael', '.', 'west', 'felix', '.', 'brodbeck', 'andreas', '.', 'richter'],
#  ['michael', '.', 'west', 'felix', '.', 'brodbeck', 'andreas', '.', 'richter'],
#  ['michael', '.', 'west', 'felix', '.', 'brodbeck', 'andreas', '.', 'richter'],
#  ['michael', '.', 'west', 'felix', '.', 'brodbeck', 'andreas', '.', 'richter'],
#  ['michael', '.', 'west', 'felix', '.', 'brodbeck', 'andreas', '.', 'richter'],
#  ['mark',
#   '.',
#   'wilson',
#   'david',
#   '.',
#   'dejoy',
#   'robert',
#   '.',
#   'vandenberg',
#   'hettie',
#   '.',
#   'richardson',
#   'allison',
#   '.',
#   'mcgrath'],
#  ['ambika'],
#  ['ambika'],
#  ['ambika'],
#  ['ambika'],
#  ['ambika'],
#  ['ambika'],
#  [''],
#  ['ambika'],
#  ['ambika'],
#  [''],
#  [''],
#  [''],
#  [''],
#  [''],
#  [''],
#  [''],
#  [''],
#  [''],
#  [''],
#  [''],
#  [''],
#  ['ambika'],
#  ['ambika'],
#  ['ambika'],
#  ['ambika'],
#  ['ambika'],
#  ['ambika'],
#  ['ambika'],
#  ['ambika'],
#  ['ambika']]

# %%
pdf_text_title= []

for i in pdf_ref:
    line = i
    # for author
    for j in pdf_title:
        #print(j)
                  #print(k)
        line = re.sub(j, '', line)
        
    pdf_text_title.append(line)

# %%
import re
# step-1 preprocess subject
pdf_sub = []

  # pre-processing for subject
for i in pdf_subject:
    # remove special character
    t = (re.sub(r'[?\-|.|:|!]','',i))
    # remove digits
    t = (re.sub("\d+", "", t))
    # remove end whitespace
    t = re.sub(r"\s+$","",t)
    # append to the list
    pdf_sub.append(t)

# %%
pdf_text_subject = [] 

for i in pdf_text_title:
    line = i
    # for author
    for j in pdf_sub:
        line = re.sub(j, '', line)
        
    pdf_text_subject.append(line)

# %%
pdf_text_subject[0]
# Out:
# '\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n221\n\n (2012), 85, 221–224\nc© 2012 the british psychological society\n\nthe\nbritish\npsychological\nsociety\n\nwww.wileyonlinelibrary.com\n\neditorial acknowledgement\n\nthe editor and associate editors would like to warmly thank the following colleagues\nwho kindly acted as reviewers of one or more manuscripts between 1 october 2010 and\n30 september 2011. their professionalism and support for both authors and the editorial\nboard are much appreciated.\n\naguinis, herman\nallen, david\nallen, natalie j.\nambrose, maureen\namiot, catherine elizabeth\nanderson, neil r.\nanseel, frederik\narnold, john\narnold, kara a.\narthur, winfred\naryee, samuel\nashforth, blake e.\nashkanasy, neal m.\naube, caroline\navery, derek\navey, james b.\naxelrod, robert\naxtell, carolyn\nayman, roya\nbachrach, daniel g.\nbaillien, elfi\nbaker, david p.\nbakker, arnold\nbal, matthijs\nbamberg, sebastian\nbarclay, laurie j.\nbardes, mary\nbauer, jack\nbauer, talya\nbecker, thomas\nbeehr, terry a.\nbelschak, frank\n\nbennett, rebecca\nbentein, kathleen\nbernhard-oettel, claudia\nberntson, erik\nberry, christopher\nbezuijen, xander m.\nbhave, devasheesh\nbipp, tanja\nblair, clancy\nblau, gary j.\nbledow, ronald\nbliese, paul d.\nblonk, roland\nbodner, todd\nboies, kathleen\nbonn, ingrid\nbooth, jonathan e.\nbordia, prashant\nbosak, janine\nboswell, wendy r.\nbourdage, joshua\nbowling, nathan andrew\nboyar, scott\nbravo, jesus\nbreaugh, j.\nbriner, rob b.\nbrotheridge, celeste\nbrouer, robyn\nbrough, paula\nbrouwers, andre\nbrown, doug\nbrown, graham\n\nbruk-lee, valentina\nbudhwar, pawan\nburke, shawn\nburke, warner\nbutler, adam b.\nbyrne, zinta\ncable, dan\ncardon, melissa\ncarless, sally\ncarley, kathleen m.\ncarmeli, abraham\ncasper, wendy j.\ncassell, catherine\nchandola, tarani\nchang, chu-hsiang\nchapman, derek\nchen, zhen xiong\nchen, ziguang\ncheng, b. s.\nchernychenko, sasha\nchi, nai-wen\nchiaburu, dan\ncho, jeewon\nchrist, oliver\nchristian, michael\nchristiansen, neil\nchuang, aichia\ncicero, lavinia\nclark, malissa\nclinton, mike\ncoates, david\ncohen, aaron\n\n\n\n222 editorial acknowledgement\n\ncohen, michael d.\ncohen-charash, yochi\ncolbert, amy\ncollins, catherine grace\ncollinson, david\nconrey, frederica\nconway, edel\nconway, neil\ncooke, richard\ncooper-thomas, helena\ncordano, mark\ncordery, john\ncordes, cynthia\ncortina, lilia\ncoyle-shapiro, jackie\ncroon, marcel\ncropley, mark\ncrossley, craig\ncurhan, jared r.\ndahling, jason james\ndalal, reeshad\ndaniels, kevin\ndaus, cathy\ndavis, mark alan\nde bloom, jessica\nde cooman, rein\nde cuyper, nele\nde dreu, carsten k.w.\nde gilder, dick\nde hoogh, annebel h. b.\nde jonge, jan\nde lange, annet\nde vos, ans\nde witte, hans\ndeery, stephen\ndejoy, david\ndemerouti, eva\ndemiray, burcu\nden hartog, deanne n.\nderous, eva\ndeshon, richard p.\ndevogli, roberto\ndiefendorff, james m.\ndierdorff, erich c.\ndietz, graham\ndineen, brian r.\ndormann, christian\ndunlop, patrick damien\ndutton, jane\n\neby, lillian t.\nehrhart, mark\neinarsen, stale\nelfenbein, hillary anger\nelicker, joelle\nellemers, naomi\nellington, kemp\nellis, robert\nelsbach, kimberly\nfarrell, sara\nfassina, neil\nfeldman, daniel c.\nfelfe, joerg\nferris, lance\nfinkelstein, lisa\nfisher, cynthia\nflaxman, paul\nflood, patrick\nfolger, robert\nford, deborah\nfox, suzy\nfreund, alexandra\nfrick, kaj\nfritsche, immo\nfritz, charlotte\nfullagar, clive\ngardner, william\ngelade, garry a.\ngellatly, ian r.\ngifford, robert\nglomb, theresa\ngong, yaping\ngooty, janaki\ngorman, c. allen\ngracia, francisco\ngrandey, alicia\ngreenbaum, rebecca\ngreenhalgh, len\ngreenhaus, jeffrey h.\ngroth, markus\ngrzywacz, joseph g.\nguest, david\ngutscher, heinz\nhakanen, jari juhani\nhalbesleben, jonathon\nhammer, leslie\nhancock, julie\nhardeman, wendy\nharold, crystal m\n\nharris, kenneth j.\nharrison, j. richard ...

# %%
# not required
def eliminate_method_result(method, discussion):
    
    import re    
    start = method
    end = discussion
    #start of pattern, followed by any number of times 'any character OR a newline' and terminated by the end pattern.
    pattern = start + '.*'+'(.|\n)*'+end
    pdf_method_dis = [re.sub(pattern, '', f) for f in pdf_text]

    return pdf_method_dis

# %%
# not required
def eliminate_method_result_ref(method, dis, ref):
    
    import re

    start = method
    end = dis
    
    #start of pattern, followed by any number of times 'any character OR a newline' and terminated by the end pattern.
    pattern = start + '.*'+'(.|\n)*'+end
    pdf_method_dis = [re.sub(pattern, '', f) for f in pdf_text]
    
    start_ref = ref
    pattern_ref = start_ref +'(.|\n)*$'

    pdf_ref= [re.sub(pattern_ref, '', f) for f in pdf_method_dis]
    
    return pdf_ref

# %% [markdown]
# # Pre-processing
# Regular expression is used to clean up the pre-processed data and saved as a Master data

# %%
import re
pdf_p = [re.sub("/http:\/\/(?:www\.)?([a-z0-9\-]+)(?:\.[a-z\.]+[\/]?).*/i","", f) for f in pdf_text_subject]
pdf_p= [re.sub("www.wileyonlinelibrary.com", "", t)for t in pdf_p ]
pdf_p= [re.sub(r"-\n(\n)*", "", t)for t in pdf_p ]

pdf_p= [re.sub(r"\n(\n)*", "\n", t)for t in pdf_p]

pdf_p= [re.sub(r"\n", " ", t)for t in pdf_p]
# remove text with [] eg citation
pdf_p = [re.sub(r"\[[^)]*\]", "", t)for t in pdf_p]
#Remove numbers
pdf_p = [re.sub('[0-9]+', '', f) for f in pdf_p]
#pdf_p = [re.sub("r[\S]+\.(net|com|org|info|edu|gov|uk|de|ca|jp|fr|au|us|ru|ch|it|nel|se|no|es|mil)[\S]*\s?", " ", t)for t in pdf_p]
pdf_p = [re.sub('[!@/%“”‘:#©β<>+=δχ*&$]', ' ', f) for f in pdf_p]
pdf_p = [re.sub('’s','', f) for f in pdf_p]
pdf_p = [re.sub('’re','', f) for f in pdf_p]
pdf_p = [re.sub('’t','', f) for f in pdf_p]
pdf_p = [re.sub('’ve','', f) for f in pdf_p]
pdf_p = [re.sub('’ll','', f) for f in pdf_p]
pdf_p = [re.sub('’m','', f) for f in pdf_p]

pdf_p = [re.sub('[:()-]', ' ', f) for f in pdf_p]
pdf_p = [re.sub('[\.!?]+ ', 'XYZXYZ', t) for t in pdf_p]
# \w will match alphanumeric characters and underscores
# [^\w] will match anything that's not alphanumeric or underscore
pdf_p = [re.sub(r'[^\w]', ' ', f) for f in pdf_p]
pdf_p = [re.sub('XYZXYZ', '.', f) for f in pdf_p]
pdf_p = [re.sub(' +', ' ', f) for f in pdf_p]
# Replace multiple dots with one dot
pdf_p = [re.sub('\.\.+',".", f) for f in pdf_p]
pdf_p = [re.sub(r'\b\w{1,3}\b',"", f) for f in pdf_p]
pdf_p = [re.sub(' +', ' ', f) for f in pdf_p]

pdf_p = [re.sub("^\s+","", f) for f in pdf_p]# remove the front space
pdf_p = [re.sub("\s+\Z","", f) for f in pdf_p]#remove the back space

# %%
pdf_p[0]
# Out:
# 'british psychological society british psychological society editorial acknowledgement editor associate editors would like warmly thank following colleagues kindly acted reviewers more manuscripts between october september .their professionalism support both authors editorial board much appreciated.aguinis herman allen david allen natalie .ambrose maureen amiot catherine elizabeth anderson neil .anseel frederik arnold john arnold kara .arthur winfred aryee samuel ashforth blake .ashkanasy neal .aube caroline avery derek avey james .axelrod robert axtell carolyn ayman roya bachrach daniel .baillien elfi baker david .bakker arnold matthijs bamberg sebastian barclay laurie .bardes mary bauer jack bauer talya becker thomas beehr terry .belschak frank bennett rebecca bentein kathleen bernhard oettel claudia berntson erik berry christopher bezuijen xander .bhave devasheesh bipp tanja blair clancy blau gary .bledow ronald bliese paul .blonk roland bodner todd boies kathleen bonn ingrid booth jonathan .bordia prashant bosak janine boswell wendy .bourdage joshua bowling nathan andrew boyar scott bravo jesus breaugh .briner .brotheridge celeste brouer robyn brough paula brouwers andre brown doug brown graham bruk valentina budhwar pawan burke shawn burke warner butler adam .byrne zinta cable cardon melissa carless sally carley kathleen .carmeli abraham casper wendy .cassell catherine chandola tarani chang hsiang chapman derek chen zhen xiong chen ziguang cheng ..chernychenko sasha chiaburu jeewon christ oliver christian michael christiansen neil chuang aichia cicero lavinia clark malissa clinton mike coates david cohen aaron editorial acknowledgement cohen michael .cohen charash yochi colbert collins catherine grace collinson david conrey frederica conway edel conway neil cooke richard cooper thomas helena cordano mark cordery john cordes cynthia cortina lilia coyle shapiro jackie croon marcel cropley mark crossley craig curhan jared .dahling jason james dalal reeshad daniels kevin daus cathy davis mark alan bloom jessica cooman rein cuyper nele dreu carsten . gilder dick hoogh annebel .. jonge lange annet witte hans deery stephen dejoy david demerouti demiray burcu hartog deanne .derous deshon richard .devogli roberto diefendorff james .dierdorff erich .dietz graham dineen brian .dormann christian dunlop patrick damien dutton jane lillian .ehrhart mark einarsen stale elfenbein hillary anger elicker joelle ellemers naomi ellington kemp ellis robert elsbach kimberly farrell sara fassina neil feldman daniel .felfe joerg ferris lance finkelstein lisa fisher cynthia flaxman paul flood patrick folger robert ford deborah suzy freund alexandra frick fritsche immo fritz charlotte fullagar clive gardner william gelade garry .gellatly .gifford robert glomb theresa gong yaping gooty janaki gorman .allen gracia francisco grandey alicia greenbaum rebecca greenhalgh greenhaus jeffrey .groth markus grzywacz joseph .guest david gutscher heinz hakanen jari juhani halbesleben jonathon hammer leslie hancock julie hardeman wendy harold crystal harris kenneth .harrison .richard harter james harvey jaron harvey paul haslam .alexander hasle peter hausknecht john hecht tracy heilman madeline hershcovis sandy hetland hilde highhouse scott hochwarter wayne hodgkinson gerard .hoffman brian hogg michael .hogh annie holland carol holman david holtom brooks holtz brian .hoobler jenny .howell jane .hoyt crystal huang huffcutt allen . lsheger .innstrand tone isabella lynn .janssen onne jawahar ..jelley .blake jimmieson nerina .johns gary johnson michael .johnson stefanie .joireman jeffrey .jokisaari markku jones david allen kaiser florian .kanar adam .kandola binna kanfer ruth kearney eric kellar kenny etlyn .kerschreiter rudolf brian editorial acknowledgement yeol king eden kinicki angelo kinnunen ulla kirkman bradley kivima mika klumb petra .kompier michiel kooij dorien koslowsky meni kreiner glen labianca lajunen timo wing lambert alysa landsbergis paul .lapierre l ...

# %%
# Extracted from metadata
author_list = ['ambika', 'ambika', 'natalie', 'allen', 'tracy', 'hecht', 'neil', 'anderson', 'sarah', 'sleap', 'nikos']
author_list += ['bozionelos', 'adam', 'butler', 'amie', 'skattebo', 'john', 'cordery', 'kevin', 'daniels', 'claire', 'harris']
author_list += ['briner', 'taru', 'feldt', 'mika', 'kivimaumlki', 'anne', 'rantala', 'asko', 'tolvanen', 'donald', 'gardner']
author_list += ['linn', 'dyne', 'pierce', 'filip', 'lievens', 'frederik', 'anseel', 'adam', 'meade', 'james', 'meindl']
author_list += ['paul', 'paulus', 'karen', 'charlie', 'reeve', 'eric', 'heggestad', 'astrid', 'richardsen','zhao','zhou','jing']
author_list += ['monica', 'martinussen', 'anit', 'somech', 'anat', 'drach', 'zahavy', 'gigi', 'sutton', 'mark', 'griffin']
author_list += ['william', 'turnley', 'mark', 'bolino', 'scott', 'lester', 'james', 'bloodgood', 'joan', 'horn', 'toon', 'taris']
author_list += ['wilmar', 'schaufeli', 'paul', 'schreurs', 'fred', 'walumbwa', 'peng', 'wang', 'john', 'lawler']
author_list += ['michael', 'west', 'felix', 'brodbeck', 'andreas', 'richter', 'mark', 'wilson', 'david', 'dejoy']
author_list += ['robert', 'vandenberg', 'hettie', 'richardson', 'allison', 'mcgrath', 'ambika','david','micheal']
author_list += ['elena','belogolovsky','peter','bamberger','karlene','roberts','chris','bingham','campbell','seung','hwan','jeong','scott','graffin']

author_list += ['robert','messen','andrew','carton','brice','roberts','dattée','oliver','alexy','erkko','autio','sreedhari','desai','patricio']

author_list += ['duran','nadine','kammerlander','marc','essen','thomas','zellweger','john','joseph','wshong','gokhan','ertug','tamar','yogev']


author_list += ['yonghoon','lee','peter','hedström','kibler','ewald','markus','perkmann','brenda','flannery','douglas','michael','florin','lubatkin']


author_list += ['william','schulze','raghu','garud','sanjay','jain','arun','kumaraswamy','gerard','george','christopher','corbishley','jane','khayesi']


author_list += ['martine','haas','laszlo','tihanyi','wakenshaw','gibbons','deborah','brian','gunia','joo','hun','han','saehee','kang']



author_list += ['rebecca','kehoe','david','lepak','hausknecht','nathan','hiller','robert','vance','hitt','tina','dacin','edward','levita']



author_list += ['jean','arregle','luc','anca','borza','fmurray','philippe','jacquart','antonakis','jason','jay','fuller','elfenbeinh','cynthia']

author_list += ['kim','jensen','lorraine','crystal','hkpu','margaret','luciano','amy','bartels','lauren','innocenzo','travis','maynard','mathieu']


author_list += ['hardy','smagui','johanna','mair','ignasi','marti','marc','ventresca','dellring','jcarson','mmcardle','erez','mia','mathieu']


author_list += ['monin','niels','noorderhaven','eero','vaara','kroon','jeroen','neckebrouck','gina','dokko','lisa','hisae','nishii','sonja']


author_list += ['opper','donde','ashmos','plowman','lakami','baker','tammy','beck','mukta','kulkarni','stephanie','solansky','deandra','villarreal']

author_list += ['ridge','ingram','aaron','hill','bloy','drew','harry','dwight','lemke','richard','dino','staf','guillaume','soenen']

author_list += ['tessa','melkonian','maureen','ambrose','evans','bennett','tepper','nikolaos','dimotakis','schurer','lambert','joel','koopman','fadel']


author_list += ['matta','hee','man','park','wongun','goo','tepper','varkey','titus','owen','parker','francesca','gino','bass']


author_list += ['erin','charlie','trevor','home','computer','martins','martín','esmt','european','varkey','gmbh','cwbauman','school','francesca','gino','bass']

# %%
# Function to filter out the stopwords and authors names
def filterWords(msg, words):
    m = msg.split(' ')
    words_end = [w + '.' for w in words]
    filtered_words = list(filter(lambda word: word not in words, m))
    filtered_words = [(w if w not in words_end else '.') for w in filtered_words]
    result = ' '.join(filtered_words)
    return(result)

# %%
data_proc_auth = [filterWords(f, author_list) for f in pdf_p] #running

# %%
data_proc_auth[0]
# Out:
# 'british psychological society british psychological society editorial acknowledgement editor associate editors would like warmly thank following colleagues kindly acted reviewers more manuscripts between october september .their professionalism support both authors editorial board much appreciated.aguinis herman .ambrose amiot catherine elizabeth .anseel arnold arnold kara .arthur winfred aryee samuel ashforth blake .ashkanasy neal .aube caroline avery derek avey .axelrod axtell carolyn ayman roya bachrach daniel .baillien elfi .bakker arnold matthijs bamberg sebastian barclay laurie .bardes mary bauer jack bauer talya becker beehr terry .belschak frank bentein kathleen bernhard oettel claudia berntson erik berry bezuijen xander .bhave devasheesh bipp tanja blair clancy blau gary .bledow ronald bliese .blonk roland bodner todd boies kathleen bonn ingrid booth jonathan .bordia prashant bosak janine boswell wendy .bourdage joshua bowling boyar bravo jesus breaugh .briner .brotheridge celeste brouer robyn brough paula brouwers andre brown doug brown graham bruk valentina budhwar pawan burke shawn burke warner .byrne zinta cable cardon melissa carless sally carley kathleen .carmeli abraham casper wendy .cassell catherine chandola tarani chang hsiang chapman derek chen zhen xiong chen ziguang cheng ..chernychenko sasha chiaburu jeewon christ christian christiansen chuang aichia cicero lavinia clark malissa clinton mike coates cohen editorial acknowledgement cohen .cohen charash yochi colbert collins catherine grace collinson conrey frederica conway edel conway cooke cooper helena cordano cordes cortina lilia coyle shapiro jackie croon marcel cropley crossley craig curhan jared .dahling dalal reeshad daus cathy davis alan bloom jessica cooman rein cuyper nele dreu carsten . gilder dick hoogh annebel .. jonge lange annet witte hans deery stephen demerouti demiray burcu hartog deanne .derous deshon .devogli roberto diefendorff .dierdorff erich .dietz graham dineen .dormann christian dunlop patrick damien dutton lillian .ehrhart einarsen stale elfenbein hillary anger elicker joelle ellemers naomi ellington kemp ellis elsbach kimberly farrell sara fassina feldman daniel .felfe joerg ferris lance finkelstein fisher flaxman flood patrick folger ford suzy freund alexandra frick fritsche immo fritz charlotte fullagar clive gelade garry .gellatly .gifford glomb theresa gong yaping gooty janaki gorman .allen gracia francisco grandey alicia greenbaum greenhalgh greenhaus jeffrey .groth grzywacz .guest gutscher heinz hakanen jari juhani halbesleben jonathon hammer leslie hancock julie hardeman wendy harold kenneth .harrison .richard harter harvey jaron harvey haslam .alexander hasle heilman madeline hershcovis sandy hetland hilde highhouse hochwarter wayne hodgkinson .hoffman hogg .hogh annie holland carol holman holtom brooks holtz .hoobler jenny .howell .hoyt huang huffcutt . lsheger .innstrand tone isabella lynn .janssen onne jawahar ..jelley .blake jimmieson nerina .johns gary johnson .johnson stefanie .joireman jeffrey .jokisaari markku jones kaiser florian .kanar .kandola binna kanfer ruth kearney kellar kenny etlyn .kerschreiter rudolf editorial acknowledgement yeol king eden kinicki angelo kinnunen ulla kirkman bradley kivima klumb petra .kompier michiel kooij dorien koslowsky meni kreiner glen labianca lajunen timo wing alysa landsbergis .lapierre laurent manuel laschinger heather . kenneth .lawrence blanc pascale lebreton gregory raymond .leiter lepine jeffrey levine ning liao liden lilius jacoba lipponen jukka little laura . llorens susana lopez shane .ludtke luzzo darrell curtain mackay colin madjar nora maitlis sally marcus bernd marler laura mathisen ellen mauno saija mcallister daniel .mcdaniel mcdonald seonaidh mellor joelle meyer mignonac karim mikkelsen aslaug miller susan mitchell marie . stefan .montes samantha moorman .morgeson frederick .morrison laing morrison elizabeth wolfe munyon murphy susan naswall katharina nelson  ...

# %%
stopwords = ['a', 'about', 'above', 'across', 'after', 'afterwards']
stopwords += ['again', 'against', 'all', 'almost', 'alone', 'along']
stopwords += ['already', 'also', 'although', 'always', 'am', 'among']
stopwords += ['amongst', 'amoungst', 'amount', 'an', 'and', 'another']
stopwords += ['any', 'anyhow', 'anyone', 'anything', 'anyway', 'anywhere']
stopwords += ['are', 'around', 'as', 'at', 'back', 'be', 'became']
stopwords += ['because', 'become', 'becomes', 'becoming', 'been']
stopwords += ['before', 'beforehand', 'behind', 'being', 'below']
stopwords += ['beside', 'besides', 'between', 'beyond', 'bill', 'both']
stopwords += ['bottom', 'but', 'by', 'call', 'can', 'cannot', 'cant']
stopwords += ['co', 'computer', 'con', 'could', 'couldnt', 'cry', 'de']
stopwords += ['describe', 'detail', 'did', 'do', 'done', 'down', 'due']
stopwords += ['during', 'each', 'eg', 'eight', 'either', 'eleven', 'else']
stopwords += ['elsewhere', 'empty', 'enough', 'etc', 'even', 'ever']
stopwords += ['every', 'everyone', 'everything', 'everywhere', 'except']
stopwords += ['few', 'fifteen', 'fifty', 'fill', 'find', 'fire', 'first']
stopwords += ['five', 'for', 'former', 'formerly', 'forty', 'found']
stopwords += ['four', 'from', 'front', 'full', 'further', 'get', 'give']
stopwords += ['go', 'had', 'has', 'hasnt', 'have', 'he', 'hence', 'her']
stopwords += ['here', 'hereafter', 'hereby', 'herein', 'hereupon', 'hers']
stopwords += ['herself', 'him', 'himself', 'his', 'how', 'however']
stopwords += ['hundred', 'i', 'ie', 'if', 'in', 'inc', 'indeed']
stopwords += ['interest', 'into', 'is', 'it', 'its', 'itself', 'keep']
stopwords += ['last', 'latter', 'latterly', 'least', 'less', 'ltd', 'made']
stopwords += ['many', 'may', 'me', 'meanwhile', 'might', 'mill', 'mine']
stopwords += ['more', 'moreover', 'most', 'mostly', 'move', 'much']
stopwords += ['must', 'my', 'myself', 'name', 'namely', 'neither', 'never']
stopwords += ['nevertheless', 'next', 'nine', 'no', 'nobody', 'none']
stopwords += ['noone', 'nor', 'not', 'nothing', 'now', 'nowhere', 'of']
stopwords += ['off', 'often', 'on','once', 'one', 'only', 'onto', 'or']
stopwords += ['other', 'others', 'otherwise', 'our', 'ours', 'ourselves']
stopwords += ['out', 'over', 'own', 'part', 'per', 'perhaps', 'please']
stopwords += ['put', 'rather', 're', 's', 'same', 'see', 'seem', 'seemed']
stopwords += ['seeming', 'seems', 'serious', 'several', 'she', 'should']
stopwords += ['show', 'side', 'since', 'sincere', 'six', 'sixty', 'so']
stopwords += ['some', 'somehow', 'someone', 'something', 'sometime']
stopwords += ['sometimes', 'somewhere', 'still', 'such', 'system', 'take']
stopwords += ['ten', 'than', 'that', 'the', 'their', 'them', 'themselves']
stopwords += ['then', 'thence', 'there', 'thereafter', 'thereby']
stopwords += ['therefore', 'therein', 'thereupon', 'these', 'they']
stopwords += ['thick', 'thin', 'third', 'this', 'those', 'though', 'three']
stopwords += ['three', 'through', 'throughout', 'thru', 'thus', 'to']
stopwords += ['together', 'too', 'top', 'toward', 'towards', 'twelve']
stopwords += ['twenty', 'two', 'un', 'under', 'until', 'up', 'upon']
stopwords += ['us', 'very', 'via', 'was', 'we', 'well', 'were', 'what']
stopwords += ['whatever', 'when', 'whence', 'whenever', 'where']
stopwords += ['whereafter', 'whereas', 'whereby', 'wherein', 'whereupon']
stopwords += ['wherever', 'whether', 'which', 'while', 'whither', 'who']
stopwords += ['whoever', 'whole', 'whom', 'whose', 'why', 'will', 'with']
stopwords += ['within', 'without', 'would', 'yet', 'you', 'your']
stopwords += ['yours', 'yourself', 'yourselves']
stopwords += ['january', 'february', 'march', 'february', 'march', 'april', 'may', 'june', 'july', 'august', 'september', 'october', 'november', 'december']
# metadata- subject
stopwords += ['business administration', 'economics and finance']
# author name to remove
stopwords +=['karina nielsen','kevin daniels','elaine', 'jaewan yang','andrew O herdman','amanda', 'sabine','kerstin','kertin','sagepub','journalspermissions','catheine','chidiebere ogbonnaya','john wiley','sons ltd','martin','jeffrey B arthur']

# %%
data_proc = [filterWords(f, stopwords) for f in data_proc_auth]

# %% [markdown]
# # Get country name

# %%
import pycountry

country_list = []
for country in pycountry.countries:
    a = (country.name).lower()
    country_list.append(a)

# %%
data_proc_country =[]
for j in data_proc:
    line = j
    for k in country_list:
        line = re.sub(k, '', line)
        
    data_proc_country.append(line)

# %%
# save removed title
pickle.dump(data_proc_country, open( "C:/Thesis/Data/save/Journal_of_occupational_and_OP/metadata/removed_country/metadata_all.p", "wb" ) )

# %%
# Authors names are saved already (code is available at author name folder-get name list notebook)
#load authors names
import pickle
author_nam = pickle.load(open("C:/Thesis/Data/save/Master_Data/auth_ref_filter_num_char/auth_Journal_of_occupational_and_OP.p", "rb"))

# %%
# GET REFERENCE LISTS OF STOPWORDS, I.E. WORDS THAT ARE ESSENTIALLY MEANINGLESS
# Get all the list of authors names

from nltk.corpus import stopwords

sw = stopwords.words('english') + author_nam 

#print(sw)

# %%
# GET RID OF THE STOPWORDS IN TEXTS running
data_proc_1 = [filterWords(f, sw) for f in data_proc_country]

# %%
data_proc_1[11]
# Out:
# 'response thoughts rce teams reaction commentaries .allen .hecht ontario  molson business concordia  paper rce teams understanding psychological underpinnings implications offered psychological explanation puzzling situation apparent mismatch faith effectiveness evidence regarding effectiveness.needless commentaries considerable appreciated ideas offered authors.although space permit respond pleased opportunity provide thoughts.first like restate position regarding value teams. stated goal rally opposition teams suggest avoided . . certainly agree situations require individuals common goal compelled tell station commander teams based rtic misunderstandings . .nonetheless believe judicious teams.like argue need consider context organization operates. advice recommend teams regardless situation borrowing .analogy tantamount concluding antibiotics effective bacterial infections effective bruised toes. position diagnose disease prescribing treatment.evidence effectiveness imbalance evidence beliefs noted correspondence addressed faculty sciences ontario ontario  mail nallen . british psychological appeared generally agreed commentaries.west quite different view. comments accused selective misrepresentative review experimental . like respond accusations.first .criticized omitting experimental examining process gains pointed studies deemed relevant.although dispute gains occur reading literature synergy rare agree regarding interpretation review.moreover fail relevance specific question posed studies compared groups capable member compared teams members trained trained .west .also accused reliance settings focused narrow tasks . ironically sort laboratory discussion process gains. note experimental studies reviewed included numerous tasks brainstorming decision making judgment concept mastery recall memory.with respect brainstorming particular .were concerned exclusion described demonstration brainstorming potent contributor organizational performance . .sutton claim positive consequences brainstorming enhanced organizational memory noted causal direction relations unclear organization culture overemphasize impact sessions ideo . . interesting increases organizational income hardest outcome obtained inefficiency brainstorming increased billable hours.sutton noted brainstorming rarely challenged institutional theory suggests technically efficient generate ideas legitimacy supported widely promulgated accepted rational myths . .surely scholars advocate increasing organizational performance manner .point noting employees ideo knew anticipate future contact brainstorming usually temporary groups disbanded session . .although problem drawing inferences teams chose exclude review conclusions threatened lack comparison idea generation method .regardless interpretation reiterate belief laboratory provide critical insights basic processes.taking note considerable evidence results laboratory studies parallel settings .west .also took exception review . example refer seven studies showing teams reduce costs studies showing teams reduce errors improve . shocked overlooked carefully reviewed . disappointed financial data.eggert reported multi faceted approach involving .allen .hecht interdisciplinary teams continuity assessors smaller caseloads visits familiarity neighbourhood resources decreased costs increased nursing ambulatory costs risk elderly patients.compared control resulted marginally significant cost savings.hughes . compared treatment terminally patients using based hbhc interdisciplinary giver customary control .costs significantly higher hbhc costs institutional significantly higher control group.this resulted significant cost savings hbhc program.sommers compared utilization services chronically seniors treated caregivers physician nurse worker receiving physician . singular mention costs estimated average savings year . dismayed second papers. studies examined settings existing teams examined influence introducing teams compared  ...

# %%
data_proc_2 = [re.sub(' \.+', ' ', f) for f in data_proc_1]
data_proc_2 = [re.sub(' +', ' ', f) for f in data_proc_2]
data_proc_2 = [re.sub('http', '', f) for f in data_proc_2]
data_proc_2 = [re.sub('www', '', f) for f in data_proc_2]
data_proc_2 = [re.sub('iweb', '', f) for f in data_proc_2]
data_proc_2 = [re.sub(' +', ' ', f) for f in data_proc_2]

# %%
data_proc_2[11]
# Out:
# 'response thoughts rce teams reaction commentaries allen hecht ontario molson business concordia paper rce teams understanding psychological underpinnings implications offered psychological explanation puzzling situation apparent mismatch faith effectiveness evidence regarding effectiveness.needless commentaries considerable appreciated ideas offered authors.although space permit respond pleased opportunity provide thoughts.first like restate position regarding value teams. stated goal rally opposition teams suggest avoided certainly agree situations require individuals common goal compelled tell station commander teams based rtic misunderstandings nonetheless believe judicious teams.like argue need consider context organization operates. advice recommend teams regardless situation borrowing analogy tantamount concluding antibiotics effective bacterial infections effective bruised toes. position diagnose disease prescribing treatment.evidence effectiveness imbalance evidence beliefs noted correspondence addressed faculty sciences ontario ontario mail nallen british psychological appeared generally agreed commentaries.west quite different view. comments accused selective misrepresentative review experimental like respond accusations.first criticized omitting experimental examining process gains pointed studies deemed relevant.although dispute gains occur reading literature synergy rare agree regarding interpretation review.moreover fail relevance specific question posed studies compared groups capable member compared teams members trained trained west also accused reliance settings focused narrow tasks ironically sort laboratory discussion process gains. note experimental studies reviewed included numerous tasks brainstorming decision making judgment concept mastery recall memory.with respect brainstorming particular were concerned exclusion described demonstration brainstorming potent contributor organizational performance sutton claim positive consequences brainstorming enhanced organizational memory noted causal direction relations unclear organization culture overemphasize impact sessions ideo interesting increases organizational income hardest outcome obtained inefficiency brainstorming increased billable hours.sutton noted brainstorming rarely challenged institutional theory suggests technically efficient generate ideas legitimacy supported widely promulgated accepted rational myths surely scholars advocate increasing organizational performance manner point noting employees ideo knew anticipate future contact brainstorming usually temporary groups disbanded session although problem drawing inferences teams chose exclude review conclusions threatened lack comparison idea generation method regardless interpretation reiterate belief laboratory provide critical insights basic processes.taking note considerable evidence results laboratory studies parallel settings west also took exception review example refer seven studies showing teams reduce costs studies showing teams reduce errors improve shocked overlooked carefully reviewed disappointed financial data.eggert reported multi faceted approach involving allen hecht interdisciplinary teams continuity assessors smaller caseloads visits familiarity neighbourhood resources decreased costs increased nursing ambulatory costs risk elderly patients.compared control resulted marginally significant cost savings.hughes compared treatment terminally patients using based hbhc interdisciplinary giver customary control costs significantly higher hbhc costs institutional significantly higher control group.this resulted significant cost savings hbhc program.sommers compared utilization services chronically seniors treated caregivers physician nurse worker receiving physician singular mention costs estimated average savings year dismayed second papers. studies examined settings existing teams examined influence introducing teams compared based designs.adorian explored objectives vehicle impro ...

# %%
# save data
pickle.dump(data_proc_2, open( "C:/Thesis/Data/save/Master_Data/MD_4/data_proc_latest/J_of_O_OP_data_proc.p", "wb" ) )

# %%
#import io
with open("C:/Thesis/Data/save/Master_Data/MD_4/data_proc_latest/J_of_O_OP_data_proc_txt.txt", "w",encoding="utf-8") as outfile:
    for i in range(len(data_proc_2)):
        outstring = ""
        outstring += str(data_proc_2[i])
        outfile.write(outstring)
