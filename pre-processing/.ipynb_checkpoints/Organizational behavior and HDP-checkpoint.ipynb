# %%
import os
import re
import pandas as pd
import urllib
from nltk import SnowballStemmer
from gensim.models import Word2Vec
#import langdetect
import tika
import time
from tika import parser
import pickle

# %% [markdown]
# # Raw Articles pdf Data
# Convert pdf to text using Tika apache server

# %%
# specify the target data folder
target_dir = 'C:/Thesis/Data/Organizational_behavior_and_HDP'

# %%
# prep pdf extraction
pdf_files = []
wrd_files = []

for f in os.listdir(target_dir):
    if f.endswith(".pdf") | f.endswith(".PDF"):
        thispdf = os.path.join(target_dir, f)
        pdf_files = pdf_files + [thispdf]
    if f.endswith(".doc") | f.endswith(".docx") | f.endswith(".DOC") | f.endswith(".DOCX"):
        thiswrd = os.path.join(target_dir, f)
        wrd_files = wrd_files + [thiswrd]

# %%
port = 4321 # port to use for Tika server (chosen arbitrarily)
server_str = 'http://localhost:' + str(port)
tika_path  = 'C:\Software\ tika-server-1.23.jar'
tika_run   = 'java -jar' + tika_path + ' --port ' + str(port)
print('Command to start Tika:')
print(tika_run)
print('---')
print('Number of pdf files: ' + str(len(pdf_files)))
print('Number of word files: ' + str(len(wrd_files)))
# Out:
# Command to start Tika:
# java -jarC:\Software\ tika-server-1.23.jar --port 4321
# ---
# Number of pdf files: 793
# Number of word files: 0

# %%
# process the PDF files, store text in memory
tika.TikaClientOnly = True 

pdf_metadata = [parser.from_file(t, server_str, xmlContent=False)["metadata"] for t in (pdf_files + wrd_files)]

# %%
# save data metadata
pickle.dump(pdf_metadata, open( "C:/Thesis/Data/save/Organizational_behavior_and_HDP/metadata/metadata_all.p", "wb" ) )

# %% [markdown]
# # Text Data
#
# Eliminate title, sections (eg: content between Method and Discussion) and Reference. It is saved as a pre-processed data

# %%
# process the PDF files, store text in memory
tika.TikaClientOnly = True 

#pdf_text = [parser.from_file(t, server_str, xmlContent=False)["content"] for t in (pdf_files + wrd_files)]

# %% [markdown]
# # step-1 Load pdf content

# %%
import pickle
#load the text data
pdf_text = pickle.load(open("C:/Thesis/Data/save/Organizational_behavior_and_HDP/save_alltextData.p", "rb"))

# %% [markdown]
# # step-2 convert it to lowercase

# %%
#Convert each string to lowercase
for i in range(len(pdf_text)):
    pdf_text[i] = pdf_text[i].lower()

# %%
# step-3 remove reference

# %%
# remove references section 
import re
pdf_ref = [re.sub(r"(?is)\nreferences\n.+", "", f) for f in pdf_text]

# %%
pdf_ref[0]
# Out:
# '\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\ninterest (mis)alignments in representative negotiations: do pro-social agents fuel or reduce inter-group conflict?\n\n\norganizational behavior and human decision processes 120 (2013) 240–250\ncontents lists available at sciverse sciencedirect\n\norganizational behavior and human decision processes\n\njournal homepage: www.elsevier .com/ locate /obhdp\ninterest (mis)alignments in representative negotiations: do pro-social agents fuel\nor reduce inter-group conflict?\n\nhillie aaldering ⇑, lindred l. greer, gerben a. van kleef, carsten k.w. de dreu\ndepartment of psychology, university of amsterdam, the netherlands\n\na r t i c l e i n f o\narticle history:\nreceived 23 december 2011\naccepted 4 june 2012\n\nkeywords:\npersonality\ncooperation\ncompetition\naltruism\nprincipal agent theory\nsocial value orientation\n0749-5978/$ - see front matter � 2012 elsevier inc. a\nhttp://dx.doi.org/10.1016/j.obhdp.2012.06.001\n\n⇑ corresponding author. address: university of\npsychology, weesperplein 4, 1018 xa amsterdam, th\n\ne-mail address: h.aaldering@uva.nl (h. aaldering)\na b s t r a c t\n\nin representative negotiations, interests of the representative and the represented constituency are not\nalways aligned. we investigated how interest (mis)alignment and representative’s social value orienta-\ntion influence representative negotiations. past theory and research on the principal–agent problem,\nsocial value orientation, and cooperation in social dilemmas offer different perspectives, which we exam-\nined in two experiments. experiment 1 revealed that both representatives with a pro-social and a pro-self\nvalue orientation were reluctant to accommodate the negotiation adversary at a cost to themselves and\ntheir constituency, while pro-social representatives were more willing to sacrifice self-interest to benefit\nconstituency and adversary combined. experiment 2 replicated this finding, and clarified that pro-social\nrepresentatives were more willing to self-sacrifice when this served their constituency only than when it\nindirectly served the adversary too. such parochial altruism demonstrates the discriminatory nature of\npro-socials’ cooperation and reveals the potential dark side of a pro-social orientation in constructive\nintergroup negotiations.\n\n� 2012 elsevier inc. all rights reserved.\nintroduction\n\nto reduce inter-group tension, to facilitate dispute resolution,\nor to strike mutually beneficial deals, competing groups often en-\ngage representatives who negotiate on their behalf. these repre-\nsentatives may be core members of the group, but can also be\nexternal agents with specific skills, knowledge or expertise in the\nrelevant negotiation domain. a potential problem arises when\nthe interests of the representative are not unequivocally aligned\nwith the interests of the represented party. such a conflict of inter-\nest exists, for example, among investment bankers representing\nbidding firms during merger negotiations: they receive compensa-\ntion based on the premium paid for target firms. while it is in the\ntarget firms’ interest to reach a maximum possible premium, the\nbidding firm strives for a premium as low as possible, potentially\nresulting in lower compensation for the investment banker (kes-\nner, shapiro, & sharma, 1994).\n\nthe problem of interest (mis)alignment is often referred to as\nthe principal–agent problem, in which the agent (representative)\nhas other preferences than the principal (represented group or\norganization) (allcock & filatotchev, 2010; eisenhardt, 1989; jen-\nsen & meckling, 1976) and may even have personal preferences\nmore aligned with the opposing group. this may lead the represen-\ntative to negotiate agreements that benefit him- or herself at the\nll rights reserved.\n\namsterdam, department of\ne netherlands.\n.\n\nexpense of the group ...

# %%
# step-4 load metadata

# %%
import pickle
#load the text data
pdf_metadata = pickle.load(open("C:/Thesis/Data/save/Organizational_behavior_and_HDP/metadata/metadata_all.p", "rb"))

# %% [markdown]
# # step-5 get metadata = author, subject, title

# %%
pdf_title = []
pdf_Author = []
pdf_subject = []

for i in pdf_metadata:
    temp = ""
    auth_temp =""
    subj_temp =""
    try:
        temp = i['title']
        auth_temp = i['Author']
        subj_temp = i['subject']
      
        pdf_title.append(temp.lower())# it is filtered out
        pdf_Author.append(auth_temp) # included in stopwords list
#         pdf_subject.append(subj_temp.lower()) 
        
    except:
        #print("An exception occurred" )
        pdf_title.append(temp.lower())
        pdf_Author.append(auth_temp)
#         pdf_subject.append(subj_temp.lower())

# %%
pdf_Author
# Out:
# [['Hillie Aaldering',
#   'Lindred L. Greer',
#   'Gerben A. Van Kleef',
#   'Carsten K.W. De Dreu'],
#  '',
#  ['Susanne Abele', 'Garold Stasser', 'Christopher Chartier'],
#  ['Hajo Adam', 'Otilia Obodaru', 'Adam D. Galinsky'],
#  'Hajo Adam',
#  ['Gabrielle S. Adams', 'Xi Zou', 'M. Ena Inesi', 'Madan M. Pillutla'],
#  ['Ishani Aggarwal', 'Anita Williams Woolley'],
#  ['Nidhi Agrawal', 'DaHee Han', 'Adam Duhachek'],
#  '',
#  '',
#  '',
#  '',
#  ['Emily T. Amanatullah', 'Catherine H. Tinsley'],
#  '',
#  '',
#  '',
#  ['Maureen L. Ambrose', 'Marshall J. Schminke', 'Scott J. Reynolds'],
#  ['Daniel R. Ames', 'Elke U. Weber', 'Xi Zou'],
#  ['Adi Amit', 'Lilach Sagiv'],
#  '',
#  'Eduardo B. Andrade',
#  '"Eduardo B. Andrade; Dan Ariely"',
#  '"Frederik Anseel; Filip Lievens; Eveline Schollaert"',
#  '',
#  'Ayala Arad',
#  ['Nicholas P. Aramovich', 'James R. Larson'],
#  ['Linda Argote', 'Erin Fahrenkopf'],
#  'Argote, L. et.al',
#  '',
#  'Arkes, H. R. et al',
#  '',
#  '"Hal R. Arkes; David Hirshleifer; Danling Jiang; Sonya S. Lim"',
#  ['Rachel D. Arnett', 'Jim Sidanius'],
#  '',
#  ['Laurence Ashworth', 'Peter R. Darke', 'Lindsay McShane', 'Tiffany Vu'],
#  '',
#  ['Giuseppe Attanasi',
#   'Aurora García-Gallego',
#   'Nikolaos Georgantzís',
#   'Aldo Montesano'],
#  '',
#  ['Evelyn W.M. Au', 'Xin Qin', 'Zhi-Xue Zhang'],
#  ['Brandy Aven', 'Lily Morse', 'Alessandro Iorio'],
#  'Derek R. Avery',
#  ['Shahar Ayal', 'Jérémy Celse', 'Guy Hochman'],
#  '',
#  ['Markus Baer', 'Graham Brown'],
#  ['Feng Bai', 'Grace Ching Chi Ho', 'Wu Liu'],
#  ['Daniel Balliet', 'D.Lance Ferris'],
#  ['Gary A. Ballinger', 'David W. Lehman', 'F. David Schoorman'],
#  'Baltes, B. B. et.al ',
#  'Baltes, B. B. et al',
#  '',
#  ['Alixandra Barasch', 'Emma E. Levine', 'Maurice E. Schweitzer'],
#  '',
#  '',
#  ['Christopher M. Barnes', 'John Schaubroeck', 'Megan Huth', 'Sonia Ghumman'],
#  ['Andrew J. Barnes',
#   'Michael Karpman',
#   'Sharon K. Long',
#   'Yaniv Hanoch',
#   'Thomas Rice'],
#  '',
#  '',
#  '',
#  '',
#  '',
#  ['Shankha Basu', 'Krishna Savani'],
#  '',
#  ['Christopher W. Bauman', 'Leigh Plunkett Tost', 'Madeline Ong'],
#  '',
#  ['Max H. Bazerman', 'Ovul Sezer'],
#  '',
#  ['James W. Beck', 'Aaron M. Schmidt'],
#  'Beersma, B. et al',
#  '"Bianca Beersma; John R. Hollenbeck; Donald E. Conlon; Stephen E. Humphrey; Henry Moon; Daniel R. Ilgen"',
#  ['Bianca Beersma',
#   'Astrid C. Homan',
#   'Gerben A. Van Kleef',
#   'Carsten K.W. De Dreu'],
#  ['Peter Belmi', 'Margaret Neale'],
#  'Benbasat, I. et.al',
#  '',
#  '',
#  'Justin M. Berg',
#  'Justin M. Berg',
#  ['Peter Bergman', 'Jessica Lasky-Fink', 'Todd Rogers'],
#  ['Jonathan Z. Berman',
#   'Amit Bhattacharjee',
#   'Deborah A. Small',
#   'Gal Zauberman'],
#  ['John Beshears', 'James J. Choi', 'David Laibson', 'Brigitte C. Madrian'],
#  'Tilmann Betsch, Susanne Haberstroh, Andreas Glo¨ ckner,\rThomas Haar, and Klaus Fiedler',
#  '',
#  '"Constant D. Beugré"',
#  'Syon P. Bhanot',
#  'Rajesh Bhargave',
#  ['Nazlı Bhatia', 'Brian C. Gunia'],
#  ['Emily C. Bianchi', 'Joel Brockner'],
#  '',
#  '"Guido Biele; Jörg Rieskamp; Uwe Czienskowski"',
#  'Baler Bilgin',
#  ['Baler Bilgin', 'Lyle Brenner'],
#  ['Mark N. Bing',
#   'Don Kluemper',
#   'H. Kristl Davison',
#   'Shannon Taylor',
#   'Milorad Novicevic'],
#  '',
#  '',
#  '',
#  ['Dipayan Biswas', 'Cornelia Pechmann'],
#  'T. Bradford Bitterly',
#  ['Steven L. Blader',
#   'Batia M. Wiesenfeld',
#   'Marion Fortin',
#   'Sara L. Wheeler-Smith'],
#  'Sean Blair',
#  ['Allen D. Blay', 'Kathryn Kadous', 'Kimberly Sawers'],
#  'Blount, S et.al',
#  ['Hayley Blunden',
#   'Jennifer M. Logg',
#   'Alison Wood Brooks',
#   'Leslie K. John',
#   'Francesca Gino'],
#  'Boehne, D. M. et.al ',
#  ['Wai Fong Boh', 'Sze-Sze Wong'],
#  'Vanessa K. Bohns',
#  'Boles, T. L.  et.al',
#  ['Mark C. Bolino', 'Jaron Harvey', 'Daniel G. Bachrach'],
#  '',
#  '',
#  ['Bryan L. Bonner', 'Alexander R. Bolinger'],
#  '',
#  '',
#  '"Simona Botti; Christopher K. Hsee"',
#  '',
#  '',
#  '',
#  ['Susanne Braun', 'Claudia Peus', 'Dieter Frey'],
#  '',
#  ['Lyle Brenner', 'Baler Bilgin'],
#  '',
#  ['Jeanne Brett', 'Leigh Thompson'],
#  'Brief, A. P. ',
#  'Brief, A. P.  et.al',
#  ['Sebastien Brion', 'Cameron Anderson'],
#  'Brockner, J. et al',
#  'Joel Brockner',
#  'Brockner, J. et al',
#  '',
#  '',
#  'Brodt, S. E. et.al',
#  ['Alison Wood Brooks', 'Maurice E. Schweitzer'],
#  'Alison Wood Brooks',
#  ['Graham Brown', 'Markus Baer'],
#  '',
#  '',
#  '',
#  '',
#  '',
#  ['Patrick F. Bruning', 'Bradley J. Alge', 'Hsin-Chen Lin'],
#  '',
#  '',
#  '',
#  '',
#  '',
#  '"Roger Buehler; Johanna Peetz; Dale Griffin"',
#  ['Roger Buehler', 'Dale Griffin', 'Kent C.H. Lam', 'Jennifer Deslauriers'],
#  ['Katherine A. Burson', 'David Faro', 'Yuval Rottenstreich'],
#  ['Marcus M. Butts',
#   'Devin C. Lunt',
#   'Traci L. Freling',
#   'Allison S. Gabriel'],
#  '',
#  ['Adrian R. Camilleri', 'Ben R. Newell'],
#  ['Kurt A. Carlson', 'Abhijit Guha'],
#  '',
#  '',
#  ['Kurt A. Carlson',
#   'Robin J. Tanner',
#   'Margaret G. Meloy',
#   'J. Edward Russo'],
#  ['Joel B. Carnevale', 'Lei Huang', 'Peter D. Harms'],
#  ['Lisa A. Cavanaugh', 'Francesca Gino', 'Gavan J. Fitzsimons'],
#  ['Brianna Barker Caza', 'Larissa Tiedens', 'Fiona Lee'],
#  '',
#  ['Jin Wook Chang', 'Rosalind M. Chow', 'Anita W. Woolley'],
#  ['Christopher R. Chartier', 'Susanne Abele'],
#  '',
#  '"Jennifer A. Chatman; Alicia D. Boisnier; Sandra E. Spataro; Cameron Anderson; Jennifer L. Berdahl"',
#  ['Anne-Sophie Chaxel', 'Catherine Wiggins', 'Jieru Xie'],
#  'Xiao-Ping Chen',
#  'Xiao-Ping Chen',
#  'Xiao-Ping Chen',
#  '',
#  ['Xiao Chen', 'Gary P. Latham'],
#  '',
#  ['Xiao-Ping Chen', 'Dan Morgan'],
#  '',
#  '"Gilad Chen; Ruth Kanfer; Richard P. DeShon; John E. Mathieu; Steve W.J. Kozlowski"',
#  ['Chao C. Chen', 'Ray Friedman', 'Daniel J. McAllister'],
#  ['Tingting Chen', 'Fuli Li', 'Xiao-Ping Chen', 'Zhanying Ou'],
#  '',
#  ['Arik Cheshin', 'Anat Rafaeli', 'Nathan Bos'],
#  'Arik Cheshin',
#  ['Arik Cheshin', 'Adi Amit', 'Gerben A. van Kleef'],
#  ['Siu Yin Cheung', 'Emily G. Huang', 'Song Chang', 'Liqun Wei'],
#  ['Nai-Wen Chi', 'Huo-Tsan Chang', 'Hsien-Lier Huang'],
#  '',
#  'Cho, Y. H. et.al',
#  '',
#  '',
#  '',
#  ['SinHui Chong',
#   'You Jin Kim',
#   'Hun Whee Lee',
#   'Russell E. Johnson',
#   'Szu-Han (Joanna) Lin'],
#  ['Jessica Siegel Christian',
#   'Michael S. Christian',
#   'Matthew J. Pearsall',
#   'Erin C. Long'],
#  'Chu, P. C. et al',
#  '',
#  ['Roy Y.J. Chua', 'Michael W. Morris', 'Shira Mor'],
#  ['Jinseok S. Chun', 'Joel Brockner', 'David De Cremer'],
#  '',
#  'Corinne Coen',
#  'Cohen-Charash, Y. et al',
#  '',
#  ['Irina Cojuharenco', 'Natalia Karelaia'],
#  ['Irina Cojuharenco', 'David Patient', 'Michael R. Bashshur'],
#  '',
#  '',
#  ['Jason A. Colquitt', 'Kate P. Zipay', 'John W. Lynch', 'Ryan Outlaw'],
#  ['Donald E. Conlon',
#   'Catherine H. Tinsley',
#   'Samuel J. Birk',
#   'Stephen E. Humphrey',
#   'Aleksander P.J. Ellis'],
#  '',
#  ['Benjamin A. Converse', 'Patrick J. Dennis'],
#  'Copeland, P. V. et al',
#  ['Yann Cornil', 'David J. Hardisty', 'Yakov Bart'],
#  'Coughlan, R. et al',
#  '',
#  '',
#  '"William L. Cron; Mary C. Gilly; John L. Graham; John W. Slocum"',
#  '"Matthew A. Cronin; Cleotilde Gonzalez; John D. Sterman"',
#  '',
#  '"Craig D. Crossley"',
#  ['Cynthia E. Cryder', 'George Loewenstein', 'Richard Scheines'],
#  '"Jared R. Curhan; Margaret A. Neale; Lee Ross; Jesse Rosencranz-Engelmann"',
#  'Shawn P. Curley and Glenn J. Browne',
#  ['Serge P. da Motta Veiga', 'Daniel B. Turban'],
#  ['Jason J. Dahling', 'Shaun Wiley', 'Zachary A. Fishman', 'Amber Loihle'],
#  'Hengchen Dai',
#  ['Xianchi Dai', 'Ayelet Fishbach'],
#  '"Reeshad S. Dalal; Silvia Bonaccio"',
#  '',
#  ['David P. Daniels', 'Julian J. Zlatev'],
#  'David P. Daniels',
#  'Darr, E. D. et.al',
#  ['Tina Davidson', 'Linn Van Dyne', 'Bilian Lin'],
#  '"Mark A. Davis"',
#  '',
#  'de Bruin, W. B. et.al',
#  '"David De Cremer; Eric van Dijk"',
#  '',
#  '',
#  '',
#  ['Erik W. de Kwaadsteniet', 'Sanne A.M. Rijkhoff', 'Eric van Dijk'],
#  ['Frank R.C. de Wit', 'Karen A. Jehn', 'Daan Scheepers'],
#  '"Michael L. DeKay; Dalia Patiño-Echeverri; Paul S. Fischbeck"',
#  ['Michael L. DeKay', 'Seth A. Miller', 'Dan R. Schley', 'Breann M. Erford'],
#  '"Rellie Derfler-Rozin; Madan Pillutla; Stefan Thau"',
#  ['Sreedhari D. Desai', 'Maryam Kouchaki'],
#  'Sreedhari D. Desai',
#  ['Pieter T.M. Desmet', 'David De Cremer', 'Eric van Dijk'],
#  '',
#  '',
#  '',
#  '',
#  ['Kurt T. Dirks', 'Peter H. Kim', 'Donald L. Ferrin', 'Cecily D. Cooper'],
#  ['Jeremy Douthit', 'Melanie Millar', 'Roger M. White'],
#  '',
#  'Ning Du',
#  ['Ning Du', 'David V. Budescu', 'Marjorie K. Shelly', 'Thomas C. Omer'],
#  '',
#  'Michelle Duguid',
#  '"James H. Dulebohn; Donald E. Conlon; Issidoros Sarinopoulos; Robert B. Davison; Gerry McNamara"',
#  '',
#  ['Jennifer Dunn', 'Nicole E. Ruedy', 'Maurice E. Schweitzer'],
#  ['Sunasir Dutta', 'Hayagreeva Rao'],
#  'Charlotte  Mayne',
#  '"Jane E.J. Ebert"',
#  ['Mahdi Ebrahimi', 'Maryam Kouchaki', 'Vanessa M. Patrick'],
#  'None',
#  'Emir Efendić',
#  ['Daniel A. Effron', 'Dale T. Miller'],
#  ['Daniel A. Effron', 'Brian J. Lucas', 'Kieran O’Connor'],
#  ['Casey M. Eggleston', 'Timothy D. Wilson', 'Minha Lee', 'Daniel T. Gilbert'],
#  '',
#  '',
#  '',
#  'Kyle J. Emich',
#  ['Kyle J. Emich', 'Lynne C. Vincent'],
#  '',
#  ['Kimmo Eriksson', 'Pontus Strimling', 'Julie C. Coultas'],
#  'Arvid Erlandsson',
#  ['Lauren Eskreis-Winkler', 'Ayelet Fishbach'],
#  ['Nathanael J. Fast',
#   'Niro Sivanathan',
#   'Nicole D. Mayer',
#   'Adam D. Galinsky'],
#  ['Sean Fath', 'Aaron C. Kay'],
#  ['Alberto Feduzi', 'Jochen Runde'],
#  ['Sanne Feenstra', 'Jennifer Jordan', 'Frank Walter', 'Janka I. Stoker'],
#  ['Ryan Fehr', 'Michele J. Gelfand'],
#  ['Ryan Fehr', 'Kai Chi Yam', 'Wei He', 'Jack Ting-Ju Chiang', 'Wu Wei'],
#  ['Ryan Fehr',
#   'David Welsh',
#   'Kai Chi Yam',
#   'Michael Baer',
#   'Wu Wei',
#   'Manuel Vaulont'],
#  ['Philip M. Fernbach', 'York Hagmayer', 'Steven A. Sloman'],
#  '"Donald L. Ferrin; Michelle C. Bligh; Jeffrey C. Kohles"',
#  '"D. Lance Ferris; Douglas J. Brown; Daniel Heller"',
#  '"Florian Fessel; Kai Epstude; Neal J. Roese"',
#  '',
#  'Fiedler, K. et al',
#  ['Klaus Fiedler', 'Franz Wöllert', 'Benjamin Tauber', 'Philipp Hess'],
#  ['Susann Fiedler',
#   'Andreas Glöckner',
#   'Andreas Nicklisch',
#   'Stephan Dickert'],
#  '',
#  ['Peter Fischer',
#   'Stephen Lea',
#   'Andreas Kastenmüller',
#   'Tobias Greitemeyer',
#   'Julia Fischer',
#   'Dieter Frey'],
#  ['Ayelet Fishbach', 'Jinhee Choi'],
#  'Colin M. Fisher',
#  '',
#  '',
#  'Forgas, J. P. et al',
#  'Fox, C. R. et.al',
#  'None',
#  'Fox, C. R. et al',
#  '',
#  '"Alison R. Fragale; Benson Rosen; Carol Xu; Iryna Merideth"',
#  '',
#  ['Douglas H. Frank', 'Klaus Wertenbroch', 'William W. Maddux'],
#  ['P. Fraser-Mackenzie', 'M. Sung', 'J.E.V. Johnson'],
#  ['Traci H. Freling', 'Leslie H. Vincent', 'David H. Henard'],
#  '',
#  ['Jane M.Y. Fung', 'Wing-tung Au'],
#  '',
#  '',
#  ['Deshani B. Ganegoda', 'Robert Folger'],
#  'Ganzach, Y. ',
#  '',
#  ['Stephen M. Garcia', 'Hyunjin Song', 'Abraham Tesser'],
#  ['Varun Gauri', 'Julian C. Jamison', 'Nina Mazar', 'Owen Ozier'],
#  'Phillip Gee',
#  ['Jennifer M. George', 'Erik Dane'],
#  '"Robert C. Giambatista; Anita D. Bhappu"',
#  'Gibson, F. P. et.al',
#  ['Kerry Roberts Gibson', 'Dana Harari', 'Jennifer Carson Marr'],
#  '',
#  '',
#  'Gilbert, D. T. et al',
#  '"Francesca Gino"',
#  ['Francesca Gino', 'Adam D. Galinsky'],
#  ['Francesca Gino', 'Joshua D. Margolis'],
#  '"Francesca Gino; Lamar Pierce"',
#  '"Francesca Gino; Jen Shang; Rachel Croson"',
#  '"Francesca Gino; Linda Argote; Ella Miron-Spektor; Gergana Todorova"',
#  '"Francesca Gino; Lisa L. Shu; Max H. Bazerman"',
#  ['Francesca Gino', 'Zachariah Sharek', 'Don A. Moore'],
#  ['Francesca Gino', 'Maurice E. Schweitzer', 'Nicole L. Mead', 'Dan Ariely'],
#  ['Francesca Gino', 'Ovul Sezer', 'Laura Huang'],
#  ['Eric Gladstone', 'Kathleen M. O’Connor'],
#  '',
#  '',
#  '"Jack A. Goncalo; Michelle M. Duguid"',
#  ['Jack A. Goncalo', 'Michelle M. Duguid'],
#  '',
#  ['Jack A. Goncalo', 'Evan Polman', 'Christina Maslach'],
#  '',
#  '',
#  '',
#  'Helena V. GonzÃ¡lez-GÃ³mez',
#  'Gonza´lez-Vallejo, C. et al',
#  '',
#  ['Claudia GonzÃ¡lez-Vallejo',
#   'Jason L. Harman',
#   'Etienne Mullet',
#   'Maria T. Muñoz Sastre'],
#  ['Claudia GonzÃ¡lez-Vallejo',
#   'Jason L. Harman',
#   'Etienne Mullet',
#   'Maria T. Muñoz Sastre'],
#  '',
#  '',
#  '',
#  ['Jodi S. Goodman', 'Robert E. Wood', 'Zheng Chen'],
#  '',
#  ['James A. Grand', 'Juliya Golubovich', 'Ann Marie Ryan', 'Neal Schmitt'],
#  '',
#  ['Adam M. Grant', 'David A. Hofmann'],
#  '"Adam M. Grant; Sabine Sonnentag"',
#  '',
#  ['Adam M. Grant', 'Samir Nurmohamed', 'Susan J. Ashford', 'Kathryn Dekas'],
#  '',
#  '',
#  '',
#  ['Lindred L. Greer', 'Heather M. Caruso', 'Karen A. Jehn'],
#  'Gruenfeld, D. H. et.al ',
#  ['Cristiano L. Guarana', 'Christopher M. Barnes'],
#  ['Brian C. Gunia', 'Emma E. Levine'],
#  '',
#  '',
#  'Guyse, J. L. et al',
#  ['Philip Gylfe', 'Henrika Franck', 'Eero Vaara'],
#  ['Andrew C. Hafenbrack', 'Kathleen D. Vohs'],
#  ['Andrew C. Hafenbrack',
#   'Lindsey D. Cameron',
#   'Gretchen M. Spreitzer',
#   'Chen Zhang',
#   'Laura J. Noval',
#   'Samah Shaffakat'],
#  'Lydia Paine Hagtvedt',
#  '"Jeffrey Hales"',
#  '',
#  '',
#  '"Rebecca W. Hamilton; Stefano Puntoni; Nader T. Tavassoli"',
#  ['Ryan Hamilton', 'Kathleen D. Vohs', 'Anne-Laure Sellier', 'Tom Meyvis'],
#  '',
#  '',
#  '',
#  ['Sean T. Hannah', 'Bruce J. Avolio', 'Fred O. Walumbwa', 'Adrian Chan'],
#  ['Sean T. Hannah',
#   'Peter L. Jennings',
#   'Dustin Bluhm',
#   'Ann Chunyan Peng',
#   'John M. Schaubroeck'],
#  'Uriel Haran',
#  'Andrew M. Hardin',
#  ['Jay H. Hardy III',
#   'Eric Anthony Day',
#   'Michael G. Hughes',
#   'Xiaoqian Wang',
#   'Matthew J. Schuelke'],
#  'Harinck, F. et.al',
#  ['Einav Hart', 'Maurice E. Schweitzer'],
#  'Harvey, N. et.al',
#  ['Neil M.A. Hauenstein',
#   'Kevin M. Bradley',
#   'Patrick Gavan O’Shea',
#   'Yashna J. Shah',
#   'Douglas P. Magill'],
#  '',
#  '',
#  ['Madeline E. Heilman', 'Francesca Manzi', 'Suzette Caleo'],
#  '',
#  'Henry, R. A. et al',
#  ['M. Sandy Hershcovis',
#   'Lukas Neville',
#   'Tara C. Reich',
#   'Amy M. Christie',
#   'Lilia M. Cortina',
#   'J. Valerie Shan'],
#  ['Hal E. Hershfield', 'Taya R. Cohen', 'Leigh Thompson'],
#  ['Ivona Hideg', 'D. Lance Ferris'],
#  ['Ivona Hideg', 'Anne E. Wilson'],
#  '',
#  ['E. Tory Higgins', 'James F.M. Cornwell'],
#  '',
#  ['John Angus D. Hildreth', 'Francesca Gino', 'Max Bazerman'],
#  '"N. Sharon Hill; Kathryn M. Bartol; Paul E. Tesluk; Gosia A. Langa"',
#  'Hinds, P. J. et.al ',
#  ['Violet T. Ho', 'Dejun Tony Kong'],
#  '',
#  '',
#  ['John R. Hollenbeck',
#   'Aleksander P.J. Ellis',
#   'Stephen E. Humphrey',
#   'Adela S. Garza',
#   'Daniel R. Ilgen'],
#  '',
#  ['Peter W. Hom', 'Zhixing Xiao'],
#  'Horvath, M. et.al',
#  ['Lawrence Houston', 'Alicia A. Grandey', 'Katina Sawyer'],
#  ['Christopher K. Hsee',
#   'Luxi Shen',
#   'Shirley Zhang',
#   'Jingqiu Chen',
#   'Li Zhang'],
#  ['Christopher K. Hsee', 'Yang Yang', 'Xilin Li'],
#  ['Jia Hu', 'Kaifeng Jiang', 'Shenjiang Mo', 'Honghui Chen', 'Junqi Shi'],
#  ['Yanliu Huang', 'J. Wesley Hutchinson'],
#  '"Li Huang; J. Keith Murnighan"',
#  'Li Huang',
#  ['Li Huang', 'Francesca Gino', 'Adam D. Galinsky'],
#  ['Lei Huang', 'Dina V. Krasikova', 'Dong Liu'],
#  ['Szu-chi Huang', 'Liyin Jin', 'Ying Zhang'],
#  'Huber, J. et al',
#  '',
#  ['Michaela Huber',
#   'Leaf Van Boven',
#   'A. Peter McGraw',
#   'Laura Johnson-Graham'],
#  ['Hilde M. Huizenga',
#   'Ruud Wetzels',
#   'Don van Ravenzwaaij',
#   'Eric-Jan Wagenmakers'],
#  '',
#  ['Stephen E. Humphrey',
#   'Federico Aime',
#   'Lily Cushenbery',
#   'Aaron D. Hill',
#   'Joshua Fairchild'],
#  '',
#  'Daniel R. Ilgen',
#  '',
#  ['Remus Ilies', 'Jessica Keeney', 'Brent A. Scott'],
#  '"Lynn Imai; Michele J. Gelfand"',
#  '"M. Ena Inesi"',
#  ['Chester A. Insko', 'Tim Wildschut', 'Taya R. Cohen'],
#  'Julie R. Irwin and Jonathan Baron',
#  ['Jon M. Jachimowicz',
#   'Christopher To',
#   'Shira Agasi',
#   'Stéphane Côté',
#   'Adam D. Galinsky'],
#  ['H. Jack Walker',
#   'Hubert S. Feild',
#   'William F. Giles',
#   'Jeremy B. Bernerth',
#   'Jeremy C. Short'],
#  '',
#  '"Karen A. Jehn; Katerina Bezrukova"',
#  '"Lars-Olof Johansson; Henrik Svedsäter"',
#  ['Leslie K. John', 'George Loewenstein', 'Scott I. Rick'],
#  ['Leslie K. John',
#   'George Loewenstein',
#   'Alessandro Acquisti',
#   'Joachim Vosgerau'],
#  ['Leslie K. John', 'Martha Jeong', 'Francesca Gino', 'Laura Huang'],
#  'Johnson, J. E. V. et al',
#  '',
#  '',
#  '',
#  ['Michael D. Johnson',
#   'John R. Hollenbeck',
#   'D. Scott DeRue',
#   'Christopher M. Barnes',
#   'Dustin Jundt'],
#  ['Stefanie K. Johnson', 'Traci Sitzmann', 'Anh Thuy Nguyen'],
#  ['Russell E. Johnson',
#   'Danielle D. King',
#   'Szu-Han (Joanna) Lin',
#   'Brent A. Scott',
#   'Erin M. Jackson Walker',
#   'Mo Wang'],
#  '',
#  ['Eric E. Jones', 'Janice R. Kelly'],
#  ['Dong Ju',
#   'Mingpeng Huang',
#   'Dong Liu',
#   'Xin Qin',
#   'Qiongjing Hu',
#   'Chen Chen'],
#  ['Marie Juanchich', 'Miroslav Sirota', 'Christina Lea Butler'],
#  'Judge, T. A. et al',
#  ['Timothy A. Judge', 'Remus Ilies', 'Zhen Zhang'],
#  ['Eun Jin Jung', 'Sujin Lee'],
#  '',
#  'Ion Juvina',
#  ['Ariel Kalil', 'Susan E. Mayer', 'Sebastian Gallegos'],
#  '',
#  ['Ruth Kanfer', 'Gilad Chen'],
#  ['Dana Kanze', 'Mark A. Conley', 'E. Tory Higgins'],
#  ['Gokhan Karagonlar', 'David M. Kuhlman'],
#  '',
#  'Natalia Karelaia',
#  ['Yoshihisa Kashima',
#   'Simon M. Laham',
#   'Jennifer Dix',
#   'Bianca Levis',
#   'Darlene Wong',
#   'Melissa Wheeler'],
#  ['Edgar E. Kausel', 'Jerel E. Slaughter'],
#  ['Edgar E. Kausel',
#   'Satoris S. Culbertson',
#   'Pedro I. Leiva',
#   'Jerel E. Slaughter',
#   'Alexander T. Jackson'],
#  ['Edgar E. Kausel', 'Satoris S. Culbertson', 'Hector P. Madrid'],
#  '',
#  ['Eric Kearney', 'Meir Shemla', 'Daan van Knippenberg', 'Florian A. Scholz'],
#  'Steffen Keck',
#  'Kelly, J. R. et al',
#  ['Jessica A. Kennedy', 'Cameron Anderson'],
#  ['Jessica A. Kennedy', 'Maurice E. Schweitzer'],
#  ['Jessica A. Kennedy', 'Cameron Anderson', 'Don A. Moore'],
#  ['Jessica A. Kennedy', 'Laura J. Kray', 'Gillian Ku'],
#  '',
#  '',
#  '',
#  ['Yeun Joon Kim', 'Chen-Bo Zhong'],
#  '',
#  '',
#  ['Peter H. Kim', 'Cecily D. Cooper', 'Kurt T. Dirks', 'Donald L. Ferrin'],
#  ['You-Jin Kim', 'Linn Van Dyne', 'Dishan Kamdar', 'Russell E. Johnson'],
#  ['Hakkyun Kim', 'Kyoungmi Lee', 'Kiwan Park'],
#  ['Zoe Kinias', 'Heejung S. Kim', 'Andrew C. Hafenbrack', 'Jina J. Lee'],
#  'Nadav Klein',
#  'Klein, H. J. et al',
#  ['Katherine J. Klein',
#   'Andrew P. Knight',
#   'Jonathan C. Ziegert',
#   'Beng Chong Lim',
#   'Jessica L. Saltz'],
#  '',
#  ['Jesse Kluver', 'Rebecca Frazier', 'Jonathan Haidt'],
#  'Knez, M. et.al',
#  '',
#  '',
#  'Tehila Kogut',
#  '',
#  '',
#  ['Michail D. Kokkoris', 'Roy F. Baumeister', 'Ulrich Kühnen'],
#  ['Lukas Koning', 'Wolfgang Steinel', 'Ilja van Beest', 'Eric van Dijk'],
#  ['Joel Koopman', 'Fadel K. Matta', 'Brent A. Scott', 'Donald E. Conlon'],
#  '"Shirli Kopelman"',
#  '',
#  '',
#  'Maryam Kouchaki',
#  ['Maryam Kouchaki', 'Kristin Smith-Crowe', 'Arthur P. Brief', 'Carlos Sousa'],
#  'Kozlowski, S. W. J.  et al',
#  ['Thomas Kramer', 'Lauren G. Block'],
#  ['Thomas Kramer', 'Ozge Yucel-Aybat', 'Loraine Lau-Gesk'],
#  ['Thomas Kramer', 'Michal Maimaran', 'Itamar Simonson'],
#  ['Florian Kraus', 'Michael Ahearne', 'Son K. Lam', 'Jan Wieseke'],
#  'Kray, L. J.',
#  '',
#  '',
#  'Kray, L. J. et al',
#  ['Laura J. Kray', 'Jessica A. Kennedy', 'Alex B. Van Zant'],
#  'Krishnamurthy, P. et al',
#  'Krishnamurthy, P. et al',
#  '',
#  '"Justin Kruger; Kenneth Savitsky"',
#  '',
#  '',
#  ['Tamar Kugler', 'Gary Bornstein'],
#  '',
#  '',
#  'Daniella Kupor',
#  '',
#  '',
#  ['Letty Y.-Y. Kwan', 'Suhui Yap', 'Chi-yue Chiu'],
#  'Kwong, J. Y. Y. et al',
#  'Ku¨hberger, A. et al',
#  '',
#  '',
#  ['Chak Fu Lam', 'D. Scott DeRue', 'Elizabeth P. Karam', 'John R. Hollenbeck'],
#  '',
#  'Klodiana Lanaj',
#  'Lance, C. E. et.al',
#  ['D. Lance Ferris',
#   'Shereen Fatimah',
#   'Ming Yan',
#   'Lindie H. Liang',
#   'Huiwen Lian',
#   'Douglas J. Brown'],
#  '',
#  ['Bart de Langhe', 'Stijn M.J. van Osselaer', 'Berend Wierenga'],
#  ['Andrea Larney', 'Amanda Rotella', 'Pat Barclay'],
#  '',
#  '',
#  'Kristin Laurin',
#  '',
#  '"Huy Le; Frank L. Schmidt; James K. Harter; Kristy J. Lauver"',
#  'R. David Lebel',
#  '"Robyn A. LeBoeuf; Eldar Shafir; Julia Belyavsky Bayuk"',
#  ['Alice J. Lee', 'Daniel R. Ames'],
#  'Jooa Julia Lee',
#  'Fiona Lee and Larissa Z. Tiedens',
#  ['Sunyoung Lee', 'Marko Pitesa', 'Madan Pillutla', 'Stefan Thau'],
#  ['Hun Whee Lee', 'Jin Nam Choi', 'Seongsu Kim'],
#  ['Alice J. Lee',
#   'David D. Loschelder',
#   'Martin Schweinsberg',
#   'Malia F. Mason',
#   'Adam D. Galinsky'],
#  ['TomÃ¡s Lejarraga', 'Cleotilde Gonzalez'],
#  ['Geoffrey J. Leonardelli',
#   'Jun Gu',
#   'Geordie McRuer',
#   'Victoria Husted Medvec',
#   'Adam D. Galinsky'],
#  'LePine, J. A. et al',
#  '"Sophie Leroy"',
#  ['Sophie Leroy', 'Aaron M. Schmidt'],
#  '"Lisa M. Leslie; Michele J. Gelfand"',
#  'Levin, I. P. et.al',
#  'Levin, I. P. et al',
#  ['Emma E. Levine', 'Maurice E. Schweitzer'],
#  ['Emma E. Levine', 'Maurice E. Schweitzer'],
#  ['Emma E. Levine', 'Kristina A. Wald'],
#  'Levine, J. M. et.al ',
#  '',
#  '',
#  '',
#  ['Meng Li', 'Gretchen B. Chapman'],
#  ['Xilin Li', 'Christopher K. Hsee'],
#  ['Xilin Li', 'Christopher K. Hsee'],
#  ['Andrew Li',
#   'Joel Evans',
#   'Michael S. Christian',
#   'Stephen W. Gilliland',
#   'Edgar E. Kausel',
#   'Jordan H. Stein'],
#  ['Shaobo (Kevin) Li', 'Michail D. Kokkoris', 'Krishna Savani'],
#  ['Huiwen Lian', 'D. Lance Ferris', 'Douglas J. Brown'],
#  '',
#  '',
#  ['Alicea Lieberman', 'Kristen E. Duke', 'On Amir'],
#  '"Michael J. Liersch; Craig R.M. McKenzie"',
#  ['Katrina Jia Lin', 'Remus Ilies', 'Helen Pluut', 'Su-Ying Pan'],
#  ['Fern Lin-Healy', 'Deborah A. Small'],
#  'Lind, E. A. et al',
#  ['Wu Liu', 'Ray Friedman', 'Ying-Yi Hong'],
#  ['Peggy J. Liu',
#   'Troy H. Campbell',
#   'Gavan J. Fitzsimons',
#   'Gráinne M. Fitzsimons'],
#  ['Dong Liu',
#   'Kaifeng Jiang',
#   'Christina E. Shalley',
#   'Sejin Keem',
#   'Jing Zhou'],
#  ['Zhi Liu',
#   'Xiao-xiao Liu',
#   'Ying-yi Hong',
#   'Joel Brockner',
#   'Kim-pong Tam',
#   'Yan-mei Li'],
#  ['Yi Liu', 'Evan Polman', 'Yongfang Liu', 'Jiangli Jiao'],
#  ['Stefano Livi',
#   'Arie W. Kruglanski',
#   'Antonio Pierro',
#   'Lucia Mannetti',
#   'David A. Kenny'],
#  '',
#  ['Jennifer M. Logg', 'Julia A. Minson', 'Don A. Moore'],
#  ['Robert G. Lord', 'Paola Gatti', 'Susanna L.M. Chui'],
#  '',
#  'Robert B. Lount Jr.',
#  ['Robert B. Lount Jr.', 'Nathan C. Pettit', 'Sarah P. Doyle'],
#  '',
#  ['Jingyi Lu', 'Xiaofei Xie'],
#  ['Jackson G. Lu', 'Modupe Akinola', 'Malia F. Mason'],
#  ['Shenghua Luan', 'Jochen Reb'],
#  'Luce, M. F. et.al ',
#  ['Matthew J. Lupoli', 'Emma E. Levine', 'Adam Eric Greenberg'],
#  '"Nicholas H. Lurie; Jayashankar M. Swaminathan"',
#  ['Brent J. Lyons', 'Brent A. Scott'],
#  'Anyi Ma',
#  ['Anyi Ma', 'Yu Yang', 'Krishna Savani'],
#  'Macchi, L',
#  'Robert J. MacCoun',
#  ['Boris Maciejovsky', 'David V. Budescu'],
#  '"Carl P. Maertz; Ahmad Hassan; Peter Magnusson"',
#  ['Vincent Mak', 'Amnon Rapoport'],
#  ['Vincent Mak', 'Amnon Rapoport', 'Darryl A. Seale'],
#  ['Vincent Mak', 'Rami Zwick', 'Akshay R. Rao', 'Jake A. Pattaratanakun'],
#  '',
#  '"Deepak Malhotra"',
#  ['Selin A. Malkoc', 'Gal Zauberman', 'James R. Bettman'],
#  'Mandel, D. R. ',
#  '',
#  '',
#  ['Shannon L. Marlow',
#   'Christina N. Lacerenza',
#   'Jensine Paoletti',
#   'C. Shawn Burke',
#   'Eduardo Salas'],
#  ['Jennifer Carson Marr', 'Stefan Thau', 'Karl Aquino', 'Laurie J. Barclay'],
#  ['Ashley E. Martin', 'Katherine W. Phillips'],
#  ['Sean R. Martin', 'Julia J. Lee', 'Bidhan Lalit Parmar'],
#  ['Elena Martinescu', 'Onne Janssen', 'Bernard A. Nijstad'],
#  '',
#  '"Malia F. Mason; Rebecca Dyer; Michael I. Norton"',
#  ['Pragya Mathur',
#   'Shailendra Pratap Jain',
#   'Meng-Hua Hsieh',
#   'Charles D. Lindsey',
#   'Durairaj Maheswaran'],
#  'Matsumoto, D. et.al',
#  '"David M. Mayer; Maribeth Kuenzi; Rebecca Greenbaum; Mary Bardes; Rommel (Bombie) Salvador"',
#  ['David M. Mayer',
#   'Stefan Thau',
#   'Kristina M. Workman',
#   'Marius Van Dijke',
#   'David De Cremer'],
#  ['David M. Mayer',
#   'Samir Nurmohamed',
#   'Linda Klebe Treviño',
#   'Debra L. Shapiro',
#   'Marshall Schminke'],
#  'Ketti Mazzocco',
#  '',
#  '"Matthew W. McCarter; Kevin W. Rockmann; Gregory B. Northcraft"',
#  ['Matthew W. McCarter', 'David V. Budescu', 'Jürgen Scheffran'],
#  ['Julie M. McCarthy',
#   'Talya N. Bauer',
#   'Donald M. Truxillo',
#   'Michael C. Campion',
#   'Chad H. Van Iddekinge',
#   'Michael A. Campion'],
#  ['James C. McElroy', 'James K. Summers', 'Kelly Moore'],
#  '',
#  ['A. Peter McGraw', 'Alexander Todorov', 'Howard Kunreuther'],
#  'McKenzie, C. R. M. et al',
#  '"Craig R.M. McKenzie; Michael J. Liersch; Ilan Yaniv"',
#  '',
#  '',
#  '"Geeta Menon; Ellie J. Kyung; Nidhi Agrawal"',
#  ['Tanya Menon',
#   'Jessica Sim',
#   'Jeanne Ho-Ying Fu',
#   'Chi-yue Chiu',
#   'Ying-yi Hong'],
#  ['Christoph Merkle', 'Martin Weber'],
#  ['Jessica R. Mesmer-Magnus',
#   'Leslie A. DeChurch',
#   'Miliani Jimenez-Rodriguez',
#   'Jessica Wildman',
#   'Marissa Shuffler'],
#  '"Kerry F. Milch; Elke U. Weber; Kirstin C. Appelt; Michel J.J. Handgraaf; David H. Krantz"',
#  ['Edward W. Miles', 'Elizabeth F. Clenney'],
#  'Katherine L. Milkman',
#  ['Katherine L. Milkman',
#   'Mary Carol Mazza',
#   'Lisa L. Shu',
#   'Chia-Jung Tsay',
#   'Max H. Bazerman'],
#  ['Kobe Millet', 'Lien Lamey', 'Bram Van den Bergh'],
#  '"Andrew G. Miner; Theresa M. Glomb"',
#  ['Julia A. Minson',
#   'Eric M. VanEpps',
#   'Jeremy A. Yip',
#   'Maurice E. Schweitzer'],
#  ['Ella Miron-Spektor', 'Gerard Beenen'],
#  ['Ella Miron-Spektor', 'Francesca Gino', 'Linda Argote'],
#  ['Dorothee Mischkowski', 'Andreas Glöckner', 'Peter Lewisch'],
#  ['Himanshu Mishra', 'Arul Mishra', 'Jessica Rixom', 'Promothesh Chatterjee'],
#  'Alexandra A. Mislin',
#  '',
#  ['Daniel Mochon', 'Shane Frederick'],
#  ['Susan Mohammed', 'David A. Harrison'],
#  'Mohammed, S. et al',
#  ['Welmer E. Molenmaker', 'Erik W. de Kwaadsteniet', 'Eric van Dijk'],
#  ['Welmer E. Molenmaker', 'Erik W. de Kwaadsteniet', 'Eric van Dijk'],
#  ['Andrew L. Molinsky', 'Adam M. Grant', 'Joshua D. Margolis'],
#  '',
#  'Marlon Mooijman',
#  '',
#  '',
#  '',
#  '',
#  '',
#  ['Celia Moore', 'Ann E. Tenbrunsel'],
#  ['Sarah G. Moore', 'David T. Neal', 'Gavan J. Fitzsimons', 'Baba Shiv'],
#  'Don A. Moore',
#  'Moreland, R. L. et.al ',
#  'Morgan, P. M. et al',
#  ['Michael W. Morris', 'Ying-yi Hong', 'Chi-yue Chiu', 'Zhi Liu'],
#  'Jennifer S. Mueller',
#  ['Laetitia B. Mulder', 'Karl Aquino'],
#  ['Laetitia B. Mulder', 'Jennifer Jordan', 'Floor Rink'],
#  ['J. Keith Murnighan', 'Long Wang'],
#  'Brian R. Murtha',
#  '',
#  'Mussweiler, T. et al',
#  '"Jennifer D. Nahrgang; Frederick P. Morgeson; Remus Ilies"',
#  ['Jennifer D. Nahrgang',
#   'D. Scott DeRue',
#   'John R. Hollenbeck',
#   'Matthias Spitzmuller',
#   'Dustin K. Jundt',
#   'Daniel R. Ilgen'],
#  ['Inbal Nahum-Shani', 'Peter A. Bamberger'],
#  ['Nathaniel A. Nakashima', 'David P. Daniels', 'Kristin Laurin'],
#  '',
#  '',
#  '',
#  ['Jayanth Narayanan', 'Kenneth Tai', 'Zoe Kinias'],
#  ['Anne Nederveen Pieterse', 'Daan van Knippenberg', 'Wendy P. van Ginkel'],
#  'Nelson, M. W. et al',
#  'Daniel A. Newark',
#  ['Daniel A. Newark', 'Vanessa K. Bohns', 'Francis J. Flynn'],
#  '',
#  'K. Yee Ng and Linn Van Dyne',
#  ['Kok-Yee Ng', 'Linn Van Dyne', 'Soon Ang'],
#  ['Jessica M. Nicklin',
#   'Rebecca Greenbaum',
#   'Laurel A. McNall',
#   'Robert Folger',
#   'Kevin J. Williams'],
#  '"Nicos Nicolaou; Scott Shane; Lynn Cherkas; Tim D. Spector"',
#  ['Michael I. Norton', 'Elizabeth W. Dunn', 'Dana R. Carney', 'Dan Ariely'],
#  'Laura J. Noval',
#  ['Laura J. Noval', 'Andrew Molinsky', 'Günter K. Stahl'],
#  '',
#  'Kathleen M. O’Connor and Josh A. Arnold',
#  ['Burak Oc',
#   'Michael A. Daniels',
#   'James M. Diefendorff',
#   'Michael R. Bashshur',
#   'Gary J. Greguras'],
#  'Ofir, C.',
#  '',
#  ['Greg R. Oldham', 'Yitzhak Fried'],
#  '',
#  'Madeline Ong',
#  'Ordo´ n˜ ez, L. D. et. al',
#  '',
#  '"Jennifer R. Overbeck; Margaret A. Neale; Cassandra L. Govan"',
#  '"Shweta S. Oza; Joydeep Srivastava; Nevena T. Koukova"',
#  '"Neeru Paharia; Karim S. Kassam; Joshua D. Greene; Max H. Bazerman"',
#  ['Neeru Paharia', 'Kathleen D. Vohs', 'Rohit Deshpandé'],
#  'Mauricio Palmeira',
#  '',
#  'Mauricio Palmeira',
#  ['Karthik Panchanathan', 'Willem E. Frankenhuis', 'Joan B. Silk'],
#  ['Guihyun Park', 'Richard P. DeShon'],
#  ['Tae-Youn Park', 'Seongsu Kim', 'Li-Kuo Sung'],
#  ['Shefali V. Patil', 'R. David Lebel'],
#  'Paulus, P. B. et.al ',
#  ['Craig L. Pearce',
#   'Christina L. Wassenaar',
#   'Yair Berson',
#   'Rivka Tuval-Mashiach'],
#  '"Matthew J. Pearsall; Aleksander P.J. Ellis; Jordan H. Stein"',
#  'Ann C. Peng',
#  '',
#  'Pettibone, J. C. et.al',
#  ['Nathan C. Pettit',
#   'Sarah P. Doyle',
#   'Robert B. Lount Jr.',
#   'Christopher To'],
#  '"Michel Tuan Pham; Tamar Avnet"',
#  ['Michel Tuan Pham', 'Ali Faraji-Rad', 'Olivier Toubia', 'Leonard Lee'],
#  'Jean M. Phillips',
#  '',
#  '',
#  '',
#  '"M. David Piercey"',
#  '',
#  '',
#  ['Nashita Pillay', 'Guihyun Park', 'Ye Kang Kim', 'Sujin Lee'],
#  ['Robin L. Pinkley',
#   'Donald E. Conlon',
#   'John E. Sawyer',
#   'Dustin J. Sleesman',
#   'Don Vandewalle',
#   'Maribeth Kuenzi'],
#  ['Marko Pitesa', 'Stefan Thau', 'Madan M. Pillutla'],
#  ['Timothy J. Pleskac',
#   'Jessica Keeney',
#   'Stephanie M. Merritt',
#   'Neal Schmitt',
#   'Frederick L. Oswald'],
#  ['Helen Pluut', 'Remus Ilies', 'Petru L. Curşeu', 'Yukun Liu'],
#  '',
#  'Evan Polman',
#  ['Evan Polman', 'J. Edward Russo'],
#  '',
#  '"Christine L. Porath; Amir Erez"',
#  ['Steven S. Posavac', 'Frank R. Kardes', 'J. Joško Brakus'],
#  '',
#  'Kenneth H. Price, Thomas W. Hall, Kees van den Bos, James E. Hunton, Steve Lovett, Mark J. Tippett',
#  '',
#  ['Devon Proudfoot', 'Aaron C. Kay', 'Heather Mann'],
#  ['Christina A. Rader', 'Jack B. Soll', 'Richard P. Larrick'],
#  '"Joseph R. Radzevick; Don A. Moore"',
#  ['Joseph R. Radzevick', 'Don A. Moore'],
#  '',
#  ['Tage S. Rai', 'Daniel Diermeier'],
#  '',
#  'Rapoport, A. et al',
#  '',
#  'I.T. Services',
#  'Rettinger, D. A. et al',
#  'Anine Riege',
#  '',
#  ['Claudia A. Sacramento', 'Doris Fay', 'Michael A. West'],
#  ['Sunita Sah', 'Don A. Moore', 'Robert J. MacCoun'],
#  '',
#  'Daniel.Schwartz, Elizabeth.A.Keenan, Alex.Imas, Ayelet.Gneezy',
#  '',
#  'Robert Sneddon and R. Duncan Luce',
#  ['Antonios Stamatogiannakis',
#   'Amitava Chattopadhyay',
#   'Dipankar Chakravarti'],
#  'Stone, E. R.  et.al',
#  'Unknown',
#  'Gabriel Szulanski',
#  'Francesca Gino',
#  ['Christian TrÃ¶ster', 'Ajay Mehra', 'Daan van Knippenberg'],
#  'Chia-Jung Tsay',
#  'Michel Tuan Pham, Tom Meyvis and Rongrong Zhou',
#  '',
#  'Venkatesh, V. et.al',
#  'Weiss-Cohen, L, Konstantinidis, E, Speekenbrink, M and Harvey, N',
#  '',
#  'Windschitl, P. D. ',
#  'Windschitl, P. D. et al',
#  '',
#  'Yaniv, I. et.al',
#  '',
#  '',
#  '',
#  'Zeelenberg, M. et.al',
#  '']

# %%
# pre-process author
import re
pdf_auth = []

for j in pdf_Author:
    k = re.sub(' and ', '', str(j))
    k = re.sub('[!;&$]', '', k)
    k = re.sub('[0-9]+', '', k)
    k = re.sub( r'\b\w{1,3}\b', '', k)
    k = re.sub( r'-', ' ', k)
#     pdf_p = [re.sub(' +', ' ', f) for f in pdf_p]
    k = re.sub(' +', ',', k)
    k = k.split(",")
   
    pdf_auth.append(k)

# %%
pdf_auth
# Out:
# [["['Hillie",
#   "Aaldering'",
#   '',
#   "'Lindred",
#   '.',
#   "Greer'",
#   '',
#   "'Gerben",
#   '.',
#   "Kleef'",
#   '',
#   "'Carsten",
#   '..',
#   "Dreu']"],
#  [''],
#  ["['Susanne",
#   "Abele'",
#   '',
#   "'Garold",
#   "Stasser'",
#   '',
#   "'Christopher",
#   "Chartier']"],
#  ["['Hajo",
#   "Adam'",
#   '',
#   "'Otilia",
#   "Obodaru'",
#   '',
#   "'Adam",
#   '.',
#   "Galinsky']"],
#  ['Hajo', 'Adam'],
#  ["['Gabrielle",
#   '.',
#   "Adams'",
#   '',
#   "'",
#   "'",
#   '',
#   "'.",
#   "Inesi'",
#   '',
#   "'Madan",
#   '.',
#   "Pillutla']"],
#  ["['Ishani", "Aggarwal'", '', "'Anita", 'Williams', "Woolley']"],
#  ["['Nidhi", "Agrawal'", '', "'DaHee", "'", '', "'Adam", "Duhachek']"],
#  [''],
#  [''],
#  [''],
#  [''],
#  ["['Emily", '.', "Amanatullah'", '', "'Catherine", '.', "Tinsley']"],
#  [''],
#  [''],
#  [''],
#  ["['Maureen",
#   '.',
#   "Ambrose'",
#   '',
#   "'Marshall",
#   '.',
#   "Schminke'",
#   '',
#   "'Scott",
#   '.',
#   "Reynolds']"],
#  ["['Daniel", '.', "Ames'", '', "'Elke", '.', "Weber'", '', "'", "']"],
#  ["['", "Amit'", '', "'Lilach", "Sagiv']"],
#  [''],
#  ['Eduardo', '.', 'Andrade'],
#  ['"Eduardo', '.', 'Andrade', 'Ariely"'],
#  ['"Frederik', 'Anseel', 'Filip', 'Lievens', 'Eveline', 'Schollaert"'],
#  [''],
#  ['Ayala', 'Arad'],
#  ["['Nicholas", '.', "Aramovich'", '', "'James", '.', "Larson']"],
#  ["['Linda", "Argote'", '', "'Erin", "Fahrenkopf']"],
#  ['Argote', '', '.', '.'],
#  [''],
#  ['Arkes', '', '.', '.', ''],
#  [''],
#  ['"',
#   '.',
#   'Arkes',
#   'David',
#   'Hirshleifer',
#   'Danling',
#   'Jiang',
#   'Sonya',
#   '.',
#   '"'],
#  ["['Rachel", '.', "Arnett'", '', "'", "Sidanius']"],
#  [''],
#  ["['Laurence",
#   "Ashworth'",
#   '',
#   "'Peter",
#   '.',
#   "Darke'",
#   '',
#   "'Lindsay",
#   "McShane'",
#   '',
#   "'Tiffany",
#   "']"],
#  [''],
#  ["['Giuseppe",
#   "Attanasi'",
#   '',
#   "'Aurora",
#   'García',
#   "Gallego'",
#   '',
#   "'Nikolaos",
#   "Georgantzís'",
#   '',
#   "'Aldo",
#   "Montesano']"],
#  [''],
#  ["['Evelyn", '..', "'", '', "'", "'", '', "'", "Zhang']"],
#  ["['Brandy", "Aven'", '', "'Lily", "Morse'", '', "'Alessandro", "Iorio']"],
#  ['Derek', '.', 'Avery'],
#  ["['Shahar", "Ayal'", '', "'Jérémy", "Celse'", '', "'", "Hochman']"],
#  [''],
#  ["['Markus", "Baer'", '', "'Graham", "Brown']"],
#  ["['Feng", "'", '', "'Grace", 'Ching', "'", '', "'", "']"],
#  ["['Daniel", "Balliet'", '', "'.Lance", "Ferris']"],
#  ["['Gary",
#   '.',
#   "Ballinger'",
#   '',
#   "'David",
#   '.',
#   "Lehman'",
#   '',
#   "'.",
#   'David',
#   "Schoorman']"],
#  ['Baltes', '', '.', '.', '.', ''],
#  ['Baltes', '', '.', '.', ''],
#  [''],
#  ["['Alixandra",
#   "Barasch'",
#   '',
#   "'Emma",
#   '.',
#   "Levine'",
#   '',
#   "'Maurice",
#   '.',
#   "Schweitzer']"],
#  [''],
#  [''],
#  ["['Christopher",
#   '.',
#   "Barnes'",
#   '',
#   "'John",
#   "Schaubroeck'",
#   '',
#   "'Megan",
#   "Huth'",
#   '',
#   "'Sonia",
#   "Ghumman']"],
#  ["['Andrew",
#   '.',
#   "Barnes'",
#   '',
#   "'Michael",
#   "Karpman'",
#   '',
#   "'Sharon",
#   '.',
#   "Long'",
#   '',
#   "'Yaniv",
#   "Hanoch'",
#   '',
#   "'Thomas",
#   "Rice']"],
#  [''],
#  [''],
#  [''],
#  [''],
#  [''],
#  ["['Shankha", "Basu'", '', "'Krishna", "Savani']"],
#  [''],
#  ["['Christopher",
#   '.',
#   "Bauman'",
#   '',
#   "'Leigh",
#   'Plunkett',
#   "Tost'",
#   '',
#   "'Madeline",
#   "']"],
#  [''],
#  ["['", '.', "Bazerman'", '', "'Ovul", "Sezer']"],
#  [''],
#  ["['James", '.', "Beck'", '', "'Aaron", '.', "Schmidt']"],
#  ['Beersma', '', '.', ''],
#  ['"Bianca',
#   'Beersma',
#   'John',
#   '.',
#   'Hollenbeck',
#   'Donald',
#   '.',
#   'Conlon',
#   'Stephen',
#   '.',
#   'Humphrey',
#   'Henry',
#   'Moon',
#   'Daniel',
#   '.',
#   'Ilgen"'],
#  ["['Bianca",
#   "Beersma'",
#   '',
#   "'Astrid",
#   '.',
#   "Homan'",
#   '',
#   "'Gerben",
#   '.',
#   "Kleef'",
#   '',
#   "'Carsten",
#   '..',
#   "Dreu']"],
#  ["['Peter", "Belmi'", '', "'Margaret", "Neale']"],
#  ['Benbasat', '', '.', '.'],
#  [''],
#  [''],
#  ['Justin', '.', 'Berg'],
#  ['Justin', '.', 'Berg'],
#  ["['Peter",
#   "Bergman'",
#   '',
#   "'Jessica",
#   'Lasky',
#   "Fink'",
#   '',
#   "'Todd",
#   "Rogers']"],
#  ["['Jonathan",
#   '.',
#   "Berman'",
#   '',
#   "'Amit",
#   "Bhattacharjee'",
#   '',
#   "'Deborah",
#   '.',
#   "Small'",
#   '',
#   "'",
#   "Zauberman']"],
#  ["['John",
#   "Beshears'",
#   '',
#   "'James",
#   '.',
#   "Choi'",
#   '',
#   "'David",
#   "Laibson'",
#   '',
#   "'Brigitte",
#   '.',
#   "Madrian']"],
#  ['Tilmann',
#   'Betsch',
#   '',
#   'Susanne',
#   'Haberstroh',
#   '',
#   'Andreas',
#   '¨',
#   'ckner',
#   '\rThomas',
#   'Haar',
#   'Klaus',
#   'Fiedler'],
#  [''],
#  ['"Constant', '.', 'Beugré"'],
#  ['Syon', '.', 'Bhanot'],
#  ['Rajesh', 'Bhargave'],
#  ["['Nazlı", "Bhatia'", '', "'Brian", '.', "Gunia']"],
#  ["['Emily", '.', "Bianchi'", '', "'Joel", "Brockner']"],
#  [''],
#  ['"Guido', 'Biele', 'Jörg', 'Rieskamp', 'Czienskowski"'],
#  ['Baler', 'Bilgin'],
#  ["['Baler", "Bilgin'", '', "'Lyle", "Brenner']"],
#  ["['Mark",
#   '.',
#   "Bing'",
#   '',
#   "'",
#   "Kluemper'",
#   '',
#   "'.",
#   'Kristl',
#   "Davison'",
#   '',
#   "'Shannon",
#   "Taylor'",
#   '',
#   "'Milorad",
#   "Novicevic']"],
#  [''],
#  [''],
#  [''],
#  ["['Dipayan", "Biswas'", '', "'Cornelia", "Pechmann']"],
#  ['.', 'Bradford', 'Bitterly'],
#  ["['Steven",
#   '.',
#   "Blader'",
#   '',
#   "'Batia",
#   '.',
#   "Wiesenfeld'",
#   '',
#   "'Marion",
#   "Fortin'",
#   '',
#   "'Sara",
#   '.',
#   'Wheeler',
#   "Smith']"],
#  ['Sean', 'Blair'],
#  ["['Allen",
#   '.',
#   "Blay'",
#   '',
#   "'Kathryn",
#   "Kadous'",
#   '',
#   "'Kimberly",
#   "Sawers']"],
#  ['Blount', '', '.'],
#  ["['Hayley",
#   "Blunden'",
#   '',
#   "'Jennifer",
#   '.',
#   "Logg'",
#   '',
#   "'Alison",
#   'Wood',
#   "Brooks'",
#   '',
#   "'Leslie",
#   '.',
#   "John'",
#   '',
#   "'Francesca",
#   "Gino']"],
#  ['Boehne', '', '.', '.', '.', ''],
#  ["['", 'Fong', "'", '', "'", "Wong']"],
#  ['Vanessa', '.', 'Bohns'],
#  ['Boles', '', '.', '.', '.'],
#  ["['Mark",
#   '.',
#   "Bolino'",
#   '',
#   "'Jaron",
#   "Harvey'",
#   '',
#   "'Daniel",
#   '.',
#   "Bachrach']"],
#  [''],
#  [''],
#  ["['Bryan", '.', "Bonner'", '', "'Alexander", '.', "Bolinger']"],
#  [''],
#  [''],
#  ['"Simona', 'Botti', 'Christopher', '.', 'Hsee"'],
#  [''],
#  [''],
#  [''],
#  ["['Susanne", "Braun'", '', "'Claudia", "Peus'", '', "'Dieter", "Frey']"],
#  [''],
#  ["['Lyle", "Brenner'", '', "'Baler", "Bilgin']"],
#  [''],
#  ["['Jeanne", "Brett'", '', "'Leigh", "Thompson']"],
#  ['Brief', '', '.', '.', ''],
#  ['Brief', '', '.', '.', '.'],
#  ["['Sebastien", "Brion'", '', "'Cameron", "Anderson']"],
#  ['Brockner', '', '.', ''],
#  ['Joel', 'Brockner'],
#  ['Brockner', '', '.', ''],
#  [''],
#  [''],
#  ['Brodt', '', '.', '.', '.'],
#  ["['Alison", 'Wood', "Brooks'", '', "'Maurice", '.', "Schweitzer']"],
#  ['Alison', 'Wood', 'Brooks'],
#  ["['Graham", "Brown'", '', "'Markus", "Baer']"],
#  [''],
#  [''],
#  [''],
#  [''],
#  [''],
#  ["['Patrick",
#   '.',
#   "Bruning'",
#   '',
#   "'Bradley",
#   '.',
#   "Alge'",
#   '',
#   "'Hsin",
#   'Chen',
#   "']"],
#  [''],
#  [''],
#  [''],
#  [''],
#  [''],
#  ['"Roger', 'Buehler', 'Johanna', 'Peetz', 'Dale', 'Griffin"'],
#  ["['Roger",
#   "Buehler'",
#   '',
#   "'Dale",
#   "Griffin'",
#   '',
#   "'Kent",
#   '..',
#   "'",
#   '',
#   "'Jennifer",
#   "Deslauriers']"],
#  ["['Katherine",
#   '.',
#   "Burson'",
#   '',
#   "'David",
#   "Faro'",
#   '',
#   "'Yuval",
#   "Rottenstreich']"],
#  ["['Marcus",
#   '.',
#   "Butts'",
#   '',
#   "'Devin",
#   '.',
#   "Lunt'",
#   '',
#   "'Traci",
#   '.',
#   "Freling'",
#   '',
#   "'Allison",
#   '.',
#   "Gabriel']"],
#  [''],
#  ["['Adrian", '.', "Camilleri'", '', "'", '.', "Newell']"],
#  ["['Kurt", '.', "Carlson'", '', "'Abhijit", "Guha']"],
#  [''],
#  [''],
#  ["['Kurt",
#   '.',
#   "Carlson'",
#   '',
#   "'Robin",
#   '.',
#   "Tanner'",
#   '',
#   "'Margaret",
#   '.',
#   "Meloy'",
#   '',
#   "'.",
#   'Edward',
#   "Russo']"],
#  ["['Joel",
#   '.',
#   "Carnevale'",
#   '',
#   "'",
#   "Huang'",
#   '',
#   "'Peter",
#   '.',
#   "Harms']"],
#  ["['Lisa",
#   '.',
#   "Cavanaugh'",
#   '',
#   "'Francesca",
#   "Gino'",
#   '',
#   "'Gavan",
#   '.',
#   "Fitzsimons']"],
#  ["['Brianna",
#   'Barker',
#   "Caza'",
#   '',
#   "'Larissa",
#   "Tiedens'",
#   '',
#   "'Fiona",
#   "']"],
#  [''],
#  ["['",
#   'Wook',
#   "Chang'",
#   '',
#   "'Rosalind",
#   '.',
#   "Chow'",
#   '',
#   "'Anita",
#   '.',
#   "Woolley']"],
#  ["['Christopher", '.', "Chartier'", '', "'Susanne", "Abele']"],
#  [''],
#  ['"Jennifer',
#   '.',
#   'Chatman',
#   'Alicia',
#   '.',
#   'Boisnier',
#   'Sandra',
#   '.',
#   'Spataro',
#   'Cameron',
#   'Anderson',
#   'Jennifer',
#   '.',
#   'Berdahl"'],
#  ["['Anne",
#   'Sophie',
#   "Chaxel'",
#   '',
#   "'Catherine",
#   "Wiggins'",
#   '',
#   "'Jieru",
#   "']"],
#  ['Xiao', 'Ping', 'Chen'],
#  ['Xiao', 'Ping', 'Chen'],
#  ['Xiao', 'Ping', 'Chen'],
#  [''],
#  ["['Xiao", "Chen'", '', "'Gary", '.', "Latham']"],
#  [''],
#  ["['Xiao", 'Ping', "Chen'", '', "'", "Morgan']"],
#  [''],
#  ['"Gilad',
#   'Chen',
#   'Ruth',
#   'Kanfer',
#   'Richard',
#   '.',
#   'DeShon',
#   'John',
#   '.',
#   'Mathieu',
#   'Steve',
#   '..',
#   'Kozlowski"'],
#  ["['Chao",
#   '.',
#   "Chen'",
#   '',
#   "'",
#   "Friedman'",
#   '',
#   "'Daniel",
#   '.',
#   "McAllister']"],
#  ["['Tingting",
#   "Chen'",
#   '',
#   "'Fuli",
#   "'",
#   '',
#   "'Xiao",
#   'Ping',
#   "Chen'",
#   '',
#   "'Zhanying",
#   "']"],
#  [''],
#  ["['Arik", "Cheshin'", '', "'Anat", "Rafaeli'", '', "'Nathan", "']"],
#  ['Arik', 'Cheshin'],
#  ["['Arik", "Cheshin'", '', "'", "Amit'", '', "'Gerben", '.', "Kleef']"],
#  ["['",
#   "Cheung'",
#   '',
#   "'Emily",
#   '.',
#   "Huang'",
#   '',
#   "'Song",
#   "Chang'",
#   '',
#   "'Liqun",
#   "']"],
#  ["['", "'", '', "'", 'Tsan', "Chang'", '', "'Hsien", 'Lier', "Huang']"],
#  [''],
#  ['', '', '.', '.', '.'],
#  [''],
#  [''],
#  [''],
#  ["['SinHui",
#   "Chong'",
#   '',
#   "'",
#   "'",
#   '',
#   "'",
#   'Whee',
#   "'",
#   '',
#   "'Russell",
#   '.',
#   "Johnson'",
#   '',
#   "'",
#   '(Joanna)',
#   "']"],
#  ["['Jessica",
#   'Siegel',
#   "Christian'",
#   '',
#   "'Michael",
#   '.',
#   "Christian'",
#   '',
#   "'Matthew",
#   '.',
#   "Pearsall'",
#   '',
#   "'Erin",
#   '.',
#   "Long']"],
#  ['', '', '.', '.', ''],
#  [''],
#  ["['", '..', "Chua'", '', "'Michael", '.', "Morris'", '', "'Shira", "']"],
#  ["['Jinseok",
#   '.',
#   "Chun'",
#   '',
#   "'Joel",
#   "Brockner'",
#   '',
#   "'David",
#   "Cremer']"],
#  [''],
#  ['Corinne', 'Coen'],
#  ['Cohen', 'Charash', '', '.', ''],
#  [''],
#  ["['Irina", "Cojuharenco'", '', "'Natalia", "Karelaia']"],
#  ["['Irina",
#   "Cojuharenco'",
#   '',
#   "'David",
#   "Patient'",
#   '',
#   "'Michael",
#   '.',
#   "Bashshur']"],
#  [''],
#  [''],
#  ["['Jason",
#   '.',
#   "Colquitt'",
#   '',
#   "'Kate",
#   '.',
#   "Zipay'",
#   '',
#   "'John",
#   '.',
#   "Lynch'",
#   '',
#   "'Ryan",
#   "Outlaw']"],
#  ["['Donald",
#   '.',
#   "Conlon'",
#   '',
#   "'Catherine",
#   '.',
#   "Tinsley'",
#   '',
#   "'Samuel",
#   '.',
#   "Birk'",
#   '',
#   "'Stephen",
#   '.',
#   "Humphrey'",
#   '',
#   "'Aleksander",
#   '..',
#   "Ellis']"],
#  [''],
#  ["['Benjamin", '.', "Converse'", '', "'Patrick", '.', "Dennis']"],
#  ['Copeland', '', '.', '.', ''],
#  ["['Yann", "Cornil'", '', "'David", '.', "Hardisty'", '', "'Yakov", "Bart']"],
#  ['Coughlan', '', '.', ''],
#  [''],
#  [''],
#  ['"William',
#   '.',
#   'Cron',
#   'Mary',
#   '.',
#   'Gilly',
#   'John',
#   '.',
#   'Graham',
#   'John',
#   '.',
#   'Slocum"'],
#  ['"Matthew', '.', 'Cronin', 'Cleotilde', 'Gonzalez', 'John', '.', 'Sterman"'],
#  [''],
#  ['"Craig', '.', 'Crossley"'],
#  ["['Cynthia",
#   '.',
#   "Cryder'",
#   '',
#   "'George",
#   "Loewenstein'",
#   '',
#   "'Richard",
#   "Scheines']"],
#  ['"Jared',
#   '.',
#   'Curhan',
#   'Margaret',
#   '.',
#   'Neale',
#   'Ross',
#   'Jesse',
#   'Rosencranz',
#   'Engelmann"'],
#  ['Shawn', '.', 'CurleyGlenn', '.', 'Browne'],
#  ["['Serge", '.', 'Motta', "Veiga'", '', "'Daniel", '.', "Turban']"],
#  ["['Jason",
#   '.',
#   "Dahling'",
#   '',
#   "'Shaun",
#   "Wiley'",
#   '',
#   "'Zachary",
#   '.',
#   "Fishman'",
#   '',
#   "'Amber",
#   "Loihle']"],
#  ['Hengchen', ''],
#  ["['Xianchi", "'", '', "'Ayelet", "Fishbach']"],
#  ['"Reeshad', '.', 'Dalal', 'Silvia', 'Bonaccio"'],
#  [''],
#  ["['David", '.', "Daniels'", '', "'Julian", '.', "Zlatev']"],
#  ['David', '.', 'Daniels'],
#  ['Darr', '', '.', '.', '.'],
#  ["['Tina", "Davidson'", '', "'Linn", "Dyne'", '', "'Bilian", "']"],
#  ['"Mark', '.', 'Davis"'],
#  [''],
#  ['', 'Bruin', '', '.', '.', '.'],
#  ['"David', 'Cremer', 'Eric', 'Dijk"'],
#  [''],
#  [''],
#  [''],
#  ["['Erik",
#   '.',
#   "Kwaadsteniet'",
#   '',
#   "'Sanne",
#   '..',
#   "Rijkhoff'",
#   '',
#   "'Eric",
#   "Dijk']"],
#  ["['Frank",
#   '..',
#   "'",
#   '',
#   "'Karen",
#   '.',
#   "Jehn'",
#   '',
#   "'Daan",
#   "Scheepers']"],
#  ['"Michael',
#   '.',
#   'DeKay',
#   'Dalia',
#   'Patiño',
#   'Echeverri',
#   'Paul',
#   '.',
#   'Fischbeck"'],
#  ["['Michael",
#   '.',
#   "DeKay'",
#   '',
#   "'Seth",
#   '.',
#   "Miller'",
#   '',
#   "'",
#   '.',
#   "Schley'",
#   '',
#   "'Breann",
#   '.',
#   "Erford']"],
#  ['"Rellie', 'Derfler', 'Rozin', 'Madan', 'Pillutla', 'Stefan', 'Thau"'],
#  ["['Sreedhari", '.', "Desai'", '', "'Maryam", "Kouchaki']"],
#  ['Sreedhari', '.', 'Desai'],
#  ["['Pieter", '..', "Desmet'", '', "'David", "Cremer'", '', "'Eric", "Dijk']"],
#  [''],
#  [''],
#  [''],
#  [''],
#  ["['Kurt",
#   '.',
#   "Dirks'",
#   '',
#   "'Peter",
#   '.',
#   "'",
#   '',
#   "'Donald",
#   '.',
#   "Ferrin'",
#   '',
#   "'Cecily",
#   '.',
#   "Cooper']"],
#  ["['Jeremy",
#   "Douthit'",
#   '',
#   "'Melanie",
#   "Millar'",
#   '',
#   "'Roger",
#   '.',
#   "White']"],
#  [''],
#  ['Ning', ''],
#  ["['Ning",
#   "'",
#   '',
#   "'David",
#   '.',
#   "Budescu'",
#   '',
#   "'Marjorie",
#   '.',
#   "Shelly'",
#   '',
#   "'Thomas",
#   '.',
#   "Omer']"],
#  [''],
#  ['Michelle', 'Duguid'],
#  ['"James',
#   '.',
#   'Dulebohn',
#   'Donald',
#   '.',
#   'Conlon',
#   'Issidoros',
#   'Sarinopoulos',
#   'Robert',
#   '.',
#   'Davison',
#   'Gerry',
#   'McNamara"'],
#  [''],
#  ["['Jennifer",
#   "Dunn'",
#   '',
#   "'Nicole",
#   '.',
#   "Ruedy'",
#   '',
#   "'Maurice",
#   '.',
#   "Schweitzer']"],
#  ["['Sunasir", "Dutta'", '', "'Hayagreeva", "']"],
#  ['Charlotte', 'Mayne'],
#  ['"Jane', '..', 'Ebert"'],
#  ["['Mahdi",
#   "Ebrahimi'",
#   '',
#   "'Maryam",
#   "Kouchaki'",
#   '',
#   "'Vanessa",
#   '.',
#   "Patrick']"],
#  ['None'],
#  ['Emir', 'Efendić'],
#  ["['Daniel", '.', "Effron'", '', "'Dale", '.', "Miller']"],
#  ["['Daniel",
#   '.',
#   "Effron'",
#   '',
#   "'Brian",
#   '.',
#   "Lucas'",
#   '',
#   "'Kieran",
#   "’Connor']"],
#  ["['Casey",
#   '.',
#   "Eggleston'",
#   '',
#   "'Timothy",
#   '.',
#   "Wilson'",
#   '',
#   "'Minha",
#   "'",
#   '',
#   "'Daniel",
#   '.',
#   "Gilbert']"],
#  [''],
#  [''],
#  [''],
#  ['Kyle', '.', 'Emich'],
#  ["['Kyle", '.', "Emich'", '', "'Lynne", '.', "Vincent']"],
#  [''],
#  ["['Kimmo",
#   "Eriksson'",
#   '',
#   "'Pontus",
#   "Strimling'",
#   '',
#   "'Julie",
#   '.',
#   "Coultas']"],
#  ['Arvid', 'Erlandsson'],
#  ["['Lauren", 'Eskreis', "Winkler'", '', "'Ayelet", "Fishbach']"],
#  ["['Nathanael",
#   '.',
#   "Fast'",
#   '',
#   "'Niro",
#   "Sivanathan'",
#   '',
#   "'Nicole",
#   '.',
#   "Mayer'",
#   '',
#   "'Adam",
#   '.',
#   "Galinsky']"],
#  ["['Sean", "Fath'", '', "'Aaron", '.', "']"],
#  ["['Alberto", "Feduzi'", '', "'Jochen", "Runde']"],
#  ["['Sanne",
#   "Feenstra'",
#   '',
#   "'Jennifer",
#   "Jordan'",
#   '',
#   "'Frank",
#   "Walter'",
#   '',
#   "'Janka",
#   '.',
#   "Stoker']"],
#  ["['Ryan", "Fehr'", '', "'Michele", '.', "Gelfand']"],
#  ["['Ryan",
#   "Fehr'",
#   '',
#   "'",
#   "'",
#   '',
#   "'",
#   "'",
#   '',
#   "'Jack",
#   'Ting',
#   "Chiang'",
#   '',
#   "'",
#   "']"],
#  ["['Ryan",
#   "Fehr'",
#   '',
#   "'David",
#   "Welsh'",
#   '',
#   "'",
#   "'",
#   '',
#   "'Michael",
#   "Baer'",
#   '',
#   "'",
#   "'",
#   '',
#   "'Manuel",
#   "Vaulont']"],
#  ["['Philip",
#   '.',
#   "Fernbach'",
#   '',
#   "'York",
#   "Hagmayer'",
#   '',
#   "'Steven",
#   '.',
#   "Sloman']"],
#  ['"Donald',
#   '.',
#   'Ferrin',
#   'Michelle',
#   '.',
#   'Bligh',
#   'Jeffrey',
#   '.',
#   'Kohles"'],
#  ['".', 'Lance', 'Ferris', 'Douglas', '.', 'Brown', 'Daniel', 'Heller"'],
#  ['"Florian', 'Fessel', 'Epstude', 'Neal', '.', 'Roese"'],
#  [''],
#  ['Fiedler', '', '.', ''],
#  ["['Klaus",
#   "Fiedler'",
#   '',
#   "'Franz",
#   "Wöllert'",
#   '',
#   "'Benjamin",
#   "Tauber'",
#   '',
#   "'Philipp",
#   "Hess']"],
#  ["['Susann",
#   "Fiedler'",
#   '',
#   "'Andreas",
#   "Glöckner'",
#   '',
#   "'Andreas",
#   "Nicklisch'",
#   '',
#   "'Stephan",
#   "Dickert']"],
#  [''],
#  ["['Peter",
#   "Fischer'",
#   '',
#   "'Stephen",
#   "'",
#   '',
#   "'Andreas",
#   "Kastenmüller'",
#   '',
#   "'Tobias",
#   "Greitemeyer'",
#   '',
#   "'Julia",
#   "Fischer'",
#   '',
#   "'Dieter",
#   "Frey']"],
#  ["['Ayelet", "Fishbach'", '', "'Jinhee", "Choi']"],
#  ['Colin', '.', 'Fisher'],
#  [''],
#  [''],
#  ['Forgas', '', '.', '.', ''],
#  ['', '', '.', '.', '.'],
#  ['None'],
#  ['', '', '.', '.', ''],
#  [''],
#  ['"Alison', '.', 'Fragale', 'Benson', 'Rosen', 'Carol', 'Iryna', 'Merideth"'],
#  [''],
#  ["['Douglas",
#   '.',
#   "Frank'",
#   '',
#   "'Klaus",
#   "Wertenbroch'",
#   '',
#   "'William",
#   '.',
#   "Maddux']"],
#  ["['.", 'Fraser', "Mackenzie'", '', "'.", "Sung'", '', "'...", "Johnson']"],
#  ["['Traci",
#   '.',
#   "Freling'",
#   '',
#   "'Leslie",
#   '.',
#   "Vincent'",
#   '',
#   "'David",
#   '.',
#   "Henard']"],
#  [''],
#  ["['Jane", '..', "Fung'", '', "'Wing", 'tung', "']"],
#  [''],
#  [''],
#  ["['Deshani", '.', "Ganegoda'", '', "'Robert", "Folger']"],
#  ['Ganzach', '', '.', ''],
#  [''],
#  ["['Stephen",
#   '.',
#   "Garcia'",
#   '',
#   "'Hyunjin",
#   "Song'",
#   '',
#   "'Abraham",
#   "Tesser']"],
#  ["['Varun",
#   "Gauri'",
#   '',
#   "'Julian",
#   '.',
#   "Jamison'",
#   '',
#   "'Nina",
#   "Mazar'",
#   '',
#   "'Owen",
#   "Ozier']"],
#  ['Phillip', ''],
#  ["['Jennifer", '.', "George'", '', "'Erik", "Dane']"],
#  ['"Robert', '.', 'Giambatista', 'Anita', '.', 'Bhappu"'],
#  ['Gibson', '', '.', '.', '.'],
#  ["['Kerry",
#   'Roberts',
#   "Gibson'",
#   '',
#   "'Dana",
#   "Harari'",
#   '',
#   "'Jennifer",
#   'Carson',
#   "Marr']"],
#  [''],
#  [''],
#  ['Gilbert', '', '.', '.', ''],
#  ['"Francesca', 'Gino"'],
#  ["['Francesca", "Gino'", '', "'Adam", '.', "Galinsky']"],
#  ["['Francesca", "Gino'", '', "'Joshua", '.', "Margolis']"],
#  ['"Francesca', 'Gino', 'Lamar', 'Pierce"'],
#  ['"Francesca', 'Gino', 'Shang', 'Rachel', 'Croson"'],
#  ['"Francesca',
#   'Gino',
#   'Linda',
#   'Argote',
#   'Ella',
#   'Miron',
#   'Spektor',
#   'Gergana',
#   'Todorova"'],
#  ['"Francesca', 'Gino', 'Lisa', '.', '.', 'Bazerman"'],
#  ["['Francesca",
#   "Gino'",
#   '',
#   "'Zachariah",
#   "Sharek'",
#   '',
#   "'",
#   '.',
#   "Moore']"],
#  ["['Francesca",
#   "Gino'",
#   '',
#   "'Maurice",
#   '.',
#   "Schweitzer'",
#   '',
#   "'Nicole",
#   '.',
#   "Mead'",
#   '',
#   "'",
#   "Ariely']"],
#  ["['Francesca", "Gino'", '', "'Ovul", "Sezer'", '', "'Laura", "Huang']"],
#  ["['Eric", "Gladstone'", '', "'Kathleen", '.', "’Connor']"],
#  [''],
#  [''],
#  ['"Jack', '.', 'Goncalo', 'Michelle', '.', 'Duguid"'],
#  ["['Jack", '.', "Goncalo'", '', "'Michelle", '.', "Duguid']"],
#  [''],
#  ["['Jack",
#   '.',
#   "Goncalo'",
#   '',
#   "'Evan",
#   "Polman'",
#   '',
#   "'Christina",
#   "Maslach']"],
#  [''],
#  [''],
#  [''],
#  ['Helena', '.', 'GonzÃ¡', 'GÃ³mez'],
#  ['Gonza´', 'Vallejo', '', '.', ''],
#  [''],
#  ["['Claudia",
#   'GonzÃ¡',
#   "Vallejo'",
#   '',
#   "'Jason",
#   '.',
#   "Harman'",
#   '',
#   "'Etienne",
#   "Mullet'",
#   '',
#   "'Maria",
#   '.',
#   'Muñoz',
#   "Sastre']"],
#  ["['Claudia",
#   'GonzÃ¡',
#   "Vallejo'",
#   '',
#   "'Jason",
#   '.',
#   "Harman'",
#   '',
#   "'Etienne",
#   "Mullet'",
#   '',
#   "'Maria",
#   '.',
#   'Muñoz',
#   "Sastre']"],
#  [''],
#  [''],
#  [''],
#  ["['Jodi",
#   '.',
#   "Goodman'",
#   '',
#   "'Robert",
#   '.',
#   "Wood'",
#   '',
#   "'Zheng",
#   "Chen']"],
#  [''],
#  ["['James",
#   '.',
#   "Grand'",
#   '',
#   "'Juliya",
#   "Golubovich'",
#   '',
#   "'",
#   'Marie',
#   "Ryan'",
#   '',
#   "'Neal",
#   "Schmitt']"],
#  [''],
#  ["['Adam", '.', "Grant'", '', "'David", '.', "Hofmann']"],
#  ['"Adam', '.', 'Grant', 'Sabine', 'Sonnentag"'],
#  [''],
#  ["['Adam",
#   '.',
#   "Grant'",
#   '',
#   "'Samir",
#   "Nurmohamed'",
#   '',
#   "'Susan",
#   '.',
#   "Ashford'",
#   '',
#   "'Kathryn",
#   "Dekas']"],
#  [''],
#  [''],
#  [''],
#  ["['Lindred",
#   '.',
#   "Greer'",
#   '',
#   "'Heather",
#   '.',
#   "Caruso'",
#   '',
#   "'Karen",
#   '.',
#   "Jehn']"],
#  ['Gruenfeld', '', '.', '.', '.', ''],
#  ["['Cristiano", '.', "Guarana'", '', "'Christopher", '.', "Barnes']"],
#  ["['Brian", '.', "Gunia'", '', "'Emma", '.', "Levine']"],
#  [''],
#  [''],
#  ['Guyse', '', '.', '.', ''],
#  ["['Philip", "Gylfe'", '', "'Henrika", "Franck'", '', "'Eero", "Vaara']"],
#  ["['Andrew", '.', "Hafenbrack'", '', "'Kathleen", '.', "Vohs']"],
#  ["['Andrew",
#   '.',
#   "Hafenbrack'",
#   '',
#   "'Lindsey",
#   '.',
#   "Cameron'",
#   '',
#   "'Gretchen",
#   '.',
#   "Spreitzer'",
#   '',
#   "'Chen",
#   "Zhang'",
#   '',
#   "'Laura",
#   '.',
#   "Noval'",
#   '',
#   "'Samah",
#   "Shaffakat']"],
#  ['Lydia', 'Paine', 'Hagtvedt'],
#  ['"Jeffrey', 'Hales"'],
#  [''],
#  [''],
#  ['"Rebecca',
#   '.',
#   'Hamilton',
#   'Stefano',
#   'Puntoni',
#   'Nader',
#   '.',
#   'Tavassoli"'],
#  ["['Ryan",
#   "Hamilton'",
#   '',
#   "'Kathleen",
#   '.',
#   "Vohs'",
#   '',
#   "'Anne",
#   'Laure',
#   "Sellier'",
#   '',
#   "'",
#   "Meyvis']"],
#  [''],
#  [''],
#  [''],
#  ["['Sean",
#   '.',
#   "Hannah'",
#   '',
#   "'Bruce",
#   '.',
#   "Avolio'",
#   '',
#   "'Fred",
#   '.',
#   "Walumbwa'",
#   '',
#   "'Adrian",
#   "Chan']"],
#  ["['Sean",
#   '.',
#   "Hannah'",
#   '',
#   "'Peter",
#   '.',
#   "Jennings'",
#   '',
#   "'Dustin",
#   "Bluhm'",
#   '',
#   "'",
#   'Chunyan',
#   "Peng'",
#   '',
#   "'John",
#   '.',
#   "Schaubroeck']"],
#  ['Uriel', 'Haran'],
#  ['Andrew', '.', 'Hardin'],
#  ["['",
#   '.',
#   'Hardy',
#   "'",
#   '',
#   "'Eric",
#   'Anthony',
#   "'",
#   '',
#   "'Michael",
#   '.',
#   "Hughes'",
#   '',
#   "'Xiaoqian",
#   "Wang'",
#   '',
#   "'Matthew",
#   '.',
#   "Schuelke']"],
#  ['Harinck', '', '.', '.'],
#  ["['Einav", "Hart'", '', "'Maurice", '.', "Schweitzer']"],
#  ['Harvey', '', '.', '.'],
#  ["['Neil",
#   '..',
#   "Hauenstein'",
#   '',
#   "'Kevin",
#   '.',
#   "Bradley'",
#   '',
#   "'Patrick",
#   'Gavan',
#   "’Shea'",
#   '',
#   "'Yashna",
#   '.',
#   "Shah'",
#   '',
#   "'Douglas",
#   '.',
#   "Magill']"],
#  [''],
#  [''],
#  ["['Madeline",
#   '.',
#   "Heilman'",
#   '',
#   "'Francesca",
#   "Manzi'",
#   '',
#   "'Suzette",
#   "Caleo']"],
#  [''],
#  ['Henry', '', '.', '.', ''],
#  ["['.",
#   'Sandy',
#   "Hershcovis'",
#   '',
#   "'Lukas",
#   "Neville'",
#   '',
#   "'Tara",
#   '.',
#   "Reich'",
#   '',
#   "'",
#   '.',
#   "Christie'",
#   '',
#   "'Lilia",
#   '.',
#   "Cortina'",
#   '',
#   "'.",
#   'Valerie',
#   "Shan']"],
#  ["['",
#   '.',
#   "Hershfield'",
#   '',
#   "'Taya",
#   '.',
#   "Cohen'",
#   '',
#   "'Leigh",
#   "Thompson']"],
#  ["['Ivona", "Hideg'", '', "'.", 'Lance', "Ferris']"],
#  ["['Ivona", "Hideg'", '', "'Anne", '.', "Wilson']"],
#  [''],
#  ["['.", 'Tory', "Higgins'", '', "'James", '..', "Cornwell']"],
#  [''],
#  ["['John",
#   'Angus',
#   '.',
#   "Hildreth'",
#   '',
#   "'Francesca",
#   "Gino'",
#   '',
#   "'",
#   "Bazerman']"],
#  ['".',
#   'Sharon',
#   'Hill',
#   'Kathryn',
#   '.',
#   'Bartol',
#   'Paul',
#   '.',
#   'Tesluk',
#   'Gosia',
#   '.',
#   'Langa"'],
#  ['Hinds', '', '.', '.', '.', ''],
#  ["['Violet", '.', "'", '', "'Dejun", 'Tony', "Kong']"],
#  [''],
#  [''],
#  ["['John",
#   '.',
#   "Hollenbeck'",
#   '',
#   "'Aleksander",
#   '..',
#   "Ellis'",
#   '',
#   "'Stephen",
#   '.',
#   "Humphrey'",
#   '',
#   "'Adela",
#   '.',
#   "Garza'",
#   '',
#   "'Daniel",
#   '.',
#   "Ilgen']"],
#  [''],
#  ["['Peter", '.', "'", '', "'Zhixing", "Xiao']"],
#  ['Horvath', '', '.', '.'],
#  ["['Lawrence",
#   "Houston'",
#   '',
#   "'Alicia",
#   '.',
#   "Grandey'",
#   '',
#   "'Katina",
#   "Sawyer']"],
#  ["['Christopher",
#   '.',
#   "Hsee'",
#   '',
#   "'Luxi",
#   "Shen'",
#   '',
#   "'Shirley",
#   "Zhang'",
#   '',
#   "'Jingqiu",
#   "Chen'",
#   '',
#   "'",
#   "Zhang']"],
#  ["['Christopher", '.', "Hsee'", '', "'Yang", "Yang'", '', "'Xilin", "']"],
#  ["['",
#   "'",
#   '',
#   "'Kaifeng",
#   "Jiang'",
#   '',
#   "'Shenjiang",
#   "'",
#   '',
#   "'Honghui",
#   "Chen'",
#   '',
#   "'Junqi",
#   "']"],
#  ["['Yanliu", "Huang'", '', "'.", 'Wesley', "Hutchinson']"],
#  ['"', 'Huang', '.', 'Keith', 'Murnighan"'],
#  ['', 'Huang'],
#  ["['", "Huang'", '', "'Francesca", "Gino'", '', "'Adam", '.', "Galinsky']"],
#  ["['", "Huang'", '', "'Dina", '.', "Krasikova'", '', "'Dong", "']"],
#  ["['", "Huang'", '', "'Liyin", "'", '', "'Ying", "Zhang']"],
#  ['Huber', '', '.', ''],
#  [''],
#  ["['Michaela",
#   "Huber'",
#   '',
#   "'Leaf",
#   "Boven'",
#   '',
#   "'.",
#   'Peter',
#   "McGraw'",
#   '',
#   "'Laura",
#   'Johnson',
#   "Graham']"],
#  ["['Hilde",
#   '.',
#   "Huizenga'",
#   '',
#   "'Ruud",
#   "Wetzels'",
#   '',
#   "'",
#   "Ravenzwaaij'",
#   '',
#   "'Eric",
#   "Wagenmakers']"],
#  [''],
#  ["['Stephen",
#   '.',
#   "Humphrey'",
#   '',
#   "'Federico",
#   "Aime'",
#   '',
#   "'Lily",
#   "Cushenbery'",
#   '',
#   "'Aaron",
#   '.',
#   "Hill'",
#   '',
#   "'Joshua",
#   "Fairchild']"],
#  [''],
#  ['Daniel', '.', 'Ilgen'],
#  [''],
#  ["['Remus",
#   "Ilies'",
#   '',
#   "'Jessica",
#   "Keeney'",
#   '',
#   "'Brent",
#   '.',
#   "Scott']"],
#  ['"Lynn', 'Imai', 'Michele', '.', 'Gelfand"'],
#  ['".', 'Inesi"'],
#  ["['Chester",
#   '.',
#   "Insko'",
#   '',
#   "'",
#   "Wildschut'",
#   '',
#   "'Taya",
#   '.',
#   "Cohen']"],
#  ['Julie', '.', 'IrwinJonathan', 'Baron'],
#  ["['",
#   '.',
#   "Jachimowicz'",
#   '',
#   "'Christopher",
#   "'",
#   '',
#   "'Shira",
#   "Agasi'",
#   '',
#   "'Stéphane",
#   "Côté'",
#   '',
#   "'Adam",
#   '.',
#   "Galinsky']"],
#  ["['.",
#   'Jack',
#   "Walker'",
#   '',
#   "'Hubert",
#   '.',
#   "Feild'",
#   '',
#   "'William",
#   '.',
#   "Giles'",
#   '',
#   "'Jeremy",
#   '.',
#   "Bernerth'",
#   '',
#   "'Jeremy",
#   '.',
#   "Short']"],
#  [''],
#  ['"Karen', '.', 'Jehn', 'Katerina', 'Bezrukova"'],
#  ['"Lars', 'Olof', 'Johansson', 'Henrik', 'Svedsäter"'],
#  ["['Leslie",
#   '.',
#   "John'",
#   '',
#   "'George",
#   "Loewenstein'",
#   '',
#   "'Scott",
#   '.',
#   "Rick']"],
#  ["['Leslie",
#   '.',
#   "John'",
#   '',
#   "'George",
#   "Loewenstein'",
#   '',
#   "'Alessandro",
#   "Acquisti'",
#   '',
#   "'Joachim",
#   "Vosgerau']"],
#  ["['Leslie",
#   '.',
#   "John'",
#   '',
#   "'Martha",
#   "Jeong'",
#   '',
#   "'Francesca",
#   "Gino'",
#   '',
#   "'Laura",
#   "Huang']"],
#  ['Johnson', '', '.', '.', '.', ''],
#  [''],
#  [''],
#  [''],
#  ["['Michael",
#   '.',
#   "Johnson'",
#   '',
#   "'John",
#   '.',
#   "Hollenbeck'",
#   '',
#   "'.",
#   'Scott',
#   "DeRue'",
#   '',
#   "'Christopher",
#   '.',
#   "Barnes'",
#   '',
#   "'Dustin",
#   "Jundt']"],
#  ["['Stefanie",
#   '.',
#   "Johnson'",
#   '',
#   "'Traci",
#   "Sitzmann'",
#   '',
#   "'",
#   'Thuy',
#   "Nguyen']"],
#  ["['Russell",
#   '.',
#   "Johnson'",
#   '',
#   "'Danielle",
#   '.',
#   "King'",
#   '',
#   "'",
#   '(Joanna)',
#   "'",
#   '',
#   "'Brent",
#   '.',
#   "Scott'",
#   '',
#   "'Erin",
#   '.',
#   'Jackson',
#   "Walker'",
#   '',
#   "'",
#   "Wang']"],
#  [''],
#  ["['Eric", '.', "Jones'", '', "'Janice", '.', "Kelly']"],
#  ["['Dong",
#   "'",
#   '',
#   "'Mingpeng",
#   "Huang'",
#   '',
#   "'Dong",
#   "'",
#   '',
#   "'",
#   "'",
#   '',
#   "'Qiongjing",
#   "'",
#   '',
#   "'Chen",
#   "Chen']"],
#  ["['Marie",
#   "Juanchich'",
#   '',
#   "'Miroslav",
#   "Sirota'",
#   '',
#   "'Christina",
#   "Butler']"],
#  ['Judge', '', '.', '.', ''],
#  ["['Timothy", '.', "Judge'", '', "'Remus", "Ilies'", '', "'Zhen", "Zhang']"],
#  ["['", "Jung'", '', "'Sujin", "']"],
#  [''],
#  ['', 'Juvina'],
#  ["['Ariel",
#   "Kalil'",
#   '',
#   "'Susan",
#   '.',
#   "Mayer'",
#   '',
#   "'Sebastian",
#   "Gallegos']"],
#  [''],
#  ["['Ruth", "Kanfer'", '', "'Gilad", "Chen']"],
#  ["['Dana",
#   "Kanze'",
#   '',
#   "'Mark",
#   '.',
#   "Conley'",
#   '',
#   "'.",
#   'Tory',
#   "Higgins']"],
#  ["['Gokhan", "Karagonlar'", '', "'David", '.', "Kuhlman']"],
#  [''],
#  ['Natalia', 'Karelaia'],
#  ["['Yoshihisa",
#   "Kashima'",
#   '',
#   "'Simon",
#   '.',
#   "Laham'",
#   '',
#   "'Jennifer",
#   "'",
#   '',
#   "'Bianca",
#   "Levis'",
#   '',
#   "'Darlene",
#   "Wong'",
#   '',
#   "'Melissa",
#   "Wheeler']"],
#  ["['Edgar", '.', "Kausel'", '', "'Jerel", '.', "Slaughter']"],
#  ["['Edgar",
#   '.',
#   "Kausel'",
#   '',
#   "'Satoris",
#   '.',
#   "Culbertson'",
#   '',
#   "'Pedro",
#   '.',
#   "Leiva'",
#   '',
#   "'Jerel",
#   '.',
#   "Slaughter'",
#   '',
#   "'Alexander",
#   '.',
#   "Jackson']"],
#  ["['Edgar",
#   '.',
#   "Kausel'",
#   '',
#   "'Satoris",
#   '.',
#   "Culbertson'",
#   '',
#   "'Hector",
#   '.',
#   "Madrid']"],
#  [''],
#  ["['Eric",
#   "Kearney'",
#   '',
#   "'Meir",
#   "Shemla'",
#   '',
#   "'Daan",
#   "Knippenberg'",
#   '',
#   "'Florian",
#   '.',
#   "Scholz']"],
#  ['Steffen', 'Keck'],
#  ['Kelly', '', '.', '.', ''],
#  ["['Jessica", '.', "Kennedy'", '', "'Cameron", "Anderson']"],
#  ["['Jessica", '.', "Kennedy'", '', "'Maurice", '.', "Schweitzer']"],
#  ["['Jessica",
#   '.',
#   "Kennedy'",
#   '',
#   "'Cameron",
#   "Anderson'",
#   '',
#   "'",
#   '.',
#   "Moore']"],
#  ["['Jessica",
#   '.',
#   "Kennedy'",
#   '',
#   "'Laura",
#   '.',
#   "Kray'",
#   '',
#   "'Gillian",
#   "']"],
#  [''],
#  [''],
#  [''],
#  ["['Yeun", 'Joon', "'", '', "'Chen", "Zhong']"],
#  [''],
#  [''],
#  ["['Peter",
#   '.',
#   "'",
#   '',
#   "'Cecily",
#   '.',
#   "Cooper'",
#   '',
#   "'Kurt",
#   '.',
#   "Dirks'",
#   '',
#   "'Donald",
#   '.',
#   "Ferrin']"],
#  ["['",
#   "'",
#   '',
#   "'Linn",
#   "Dyne'",
#   '',
#   "'Dishan",
#   "Kamdar'",
#   '',
#   "'Russell",
#   '.',
#   "Johnson']"],
#  ["['Hakkyun", "'", '', "'Kyoungmi", "'", '', "'Kiwan", "Park']"],
#  ["['",
#   "Kinias'",
#   '',
#   "'Heejung",
#   '.',
#   "'",
#   '',
#   "'Andrew",
#   '.',
#   "Hafenbrack'",
#   '',
#   "'Jina",
#   '.',
#   "']"],
#  ['Nadav', 'Klein'],
#  ['Klein', '', '.', '.', ''],
#  ["['Katherine",
#   '.',
#   "Klein'",
#   '',
#   "'Andrew",
#   '.',
#   "Knight'",
#   '',
#   "'Jonathan",
#   '.',
#   "Ziegert'",
#   '',
#   "'Beng",
#   'Chong',
#   "'",
#   '',
#   "'Jessica",
#   '.',
#   "Saltz']"],
#  [''],
#  ["['Jesse",
#   "Kluver'",
#   '',
#   "'Rebecca",
#   "Frazier'",
#   '',
#   "'Jonathan",
#   "Haidt']"],
#  ['Knez', '', '.', '.'],
#  [''],
#  [''],
#  ['Tehila', 'Kogut'],
#  [''],
#  [''],
#  ["['Michail",
#   '.',
#   "Kokkoris'",
#   '',
#   "'",
#   '.',
#   "Baumeister'",
#   '',
#   "'Ulrich",
#   "Kühnen']"],
#  ["['Lukas",
#   "Koning'",
#   '',
#   "'Wolfgang",
#   "Steinel'",
#   '',
#   "'Ilja",
#   "Beest'",
#   '',
#   "'Eric",
#   "Dijk']"],
#  ["['Joel",
#   "Koopman'",
#   '',
#   "'Fadel",
#   '.',
#   "Matta'",
#   '',
#   "'Brent",
#   '.',
#   "Scott'",
#   '',
#   "'Donald",
#   '.',
#   "Conlon']"],
#  ['"Shirli', 'Kopelman"'],
#  [''],
#  [''],
#  ['Maryam', 'Kouchaki'],
#  ["['Maryam",
#   "Kouchaki'",
#   '',
#   "'Kristin",
#   'Smith',
#   "Crowe'",
#   '',
#   "'Arthur",
#   '.',
#   "Brief'",
#   '',
#   "'Carlos",
#   "Sousa']"],
#  ['Kozlowski', '', '.', '.', '.', ''],
#  ["['Thomas", "Kramer'", '', "'Lauren", '.', "Block']"],
#  ["['Thomas",
#   "Kramer'",
#   '',
#   "'Ozge",
#   'Yucel',
#   "Aybat'",
#   '',
#   "'Loraine",
#   "Gesk']"],
#  ["['Thomas",
#   "Kramer'",
#   '',
#   "'Michal",
#   "Maimaran'",
#   '',
#   "'Itamar",
#   "Simonson']"],
#  ["['Florian",
#   "Kraus'",
#   '',
#   "'Michael",
#   "Ahearne'",
#   '',
#   "'",
#   '.',
#   "'",
#   '',
#   "'",
#   "Wieseke']"],
#  ['Kray', '', '.', '.'],
#  [''],
#  [''],
#  ['Kray', '', '.', '.', ''],
#  ["['Laura",
#   '.',
#   "Kray'",
#   '',
#   "'Jessica",
#   '.',
#   "Kennedy'",
#   '',
#   "'Alex",
#   '.',
#   "Zant']"],
#  ['Krishnamurthy', '', '.', ''],
#  ['Krishnamurthy', '', '.', ''],
#  [''],
#  ['"Justin', 'Kruger', 'Kenneth', 'Savitsky"'],
#  [''],
#  [''],
#  ["['Tamar", "Kugler'", '', "'Gary", "Bornstein']"],
#  [''],
#  [''],
#  ['Daniella', 'Kupor'],
#  [''],
#  [''],
#  ["['Letty", '.', '.', "Kwan'", '', "'Suhui", "'", '', "'", "Chiu']"],
#  ['Kwong', '', '.', '.', '.', ''],
#  ['¨hberger', '', '.', ''],
#  [''],
#  [''],
#  ["['Chak",
#   "'",
#   '',
#   "'.",
#   'Scott',
#   "DeRue'",
#   '',
#   "'Elizabeth",
#   '.',
#   "Karam'",
#   '',
#   "'John",
#   '.',
#   "Hollenbeck']"],
#  [''],
#  ['Klodiana', 'Lanaj'],
#  ['Lance', '', '.', '.', '.'],
#  ["['.",
#   'Lance',
#   "Ferris'",
#   '',
#   "'Shereen",
#   "Fatimah'",
#   '',
#   "'Ming",
#   "'",
#   '',
#   "'Lindie",
#   '.',
#   "Liang'",
#   '',
#   "'Huiwen",
#   "Lian'",
#   '',
#   "'Douglas",
#   '.',
#   "Brown']"],
#  [''],
#  ["['Bart",
#   "Langhe'",
#   '',
#   "'Stijn",
#   '..',
#   "Osselaer'",
#   '',
#   "'Berend",
#   "Wierenga']"],
#  ["['Andrea", "Larney'", '', "'Amanda", "Rotella'", '', "'", "Barclay']"],
#  [''],
#  [''],
#  ['Kristin', 'Laurin'],
#  [''],
#  ['"',
#   'Frank',
#   '.',
#   'Schmidt',
#   'James',
#   '.',
#   'Harter',
#   'Kristy',
#   '.',
#   'Lauver"'],
#  ['.', 'David', 'Lebel'],
#  ['"Robyn', '.', 'LeBoeuf', 'Eldar', 'Shafir', 'Julia', 'Belyavsky', 'Bayuk"'],
#  ["['Alice", '.', "'", '', "'Daniel", '.', "Ames']"],
#  ['Jooa', 'Julia', ''],
#  ['Fiona', 'LeeLarissa', '.', 'Tiedens'],
#  ["['Sunyoung",
#   "'",
#   '',
#   "'Marko",
#   "Pitesa'",
#   '',
#   "'Madan",
#   "Pillutla'",
#   '',
#   "'Stefan",
#   "Thau']"],
#  ["['", 'Whee', "'", '', "'", "Choi'", '', "'Seongsu", "']"],
#  ["['Alice",
#   '.',
#   "'",
#   '',
#   "'David",
#   '.',
#   "Loschelder'",
#   '',
#   "'Martin",
#   "Schweinsberg'",
#   '',
#   "'Malia",
#   '.',
#   "Mason'",
#   '',
#   "'Adam",
#   '.',
#   "Galinsky']"],
#  ["['TomÃ¡", "Lejarraga'", '', "'Cleotilde", "Gonzalez']"],
#  ["['Geoffrey",
#   '.',
#   "Leonardelli'",
#   '',
#   "'",
#   "'",
#   '',
#   "'Geordie",
#   "McRuer'",
#   '',
#   "'Victoria",
#   'Husted',
#   "Medvec'",
#   '',
#   "'Adam",
#   '.',
#   "Galinsky']"],
#  ['LePine', '', '.', '.', ''],
#  ['"Sophie', 'Leroy"'],
#  ["['Sophie", "Leroy'", '', "'Aaron", '.', "Schmidt']"],
#  ['"Lisa', '.', 'Leslie', 'Michele', '.', 'Gelfand"'],
#  ['Levin', '', '.', '.', '.'],
#  ['Levin', '', '.', '.', ''],
#  ["['Emma", '.', "Levine'", '', "'Maurice", '.', "Schweitzer']"],
#  ["['Emma", '.', "Levine'", '', "'Maurice", '.', "Schweitzer']"],
#  ["['Emma", '.', "Levine'", '', "'Kristina", '.', "Wald']"],
#  ['Levine', '', '.', '.', '.', ''],
#  [''],
#  [''],
#  [''],
#  ["['Meng", "'", '', "'Gretchen", '.', "Chapman']"],
#  ["['Xilin", "'", '', "'Christopher", '.', "Hsee']"],
#  ["['Xilin", "'", '', "'Christopher", '.', "Hsee']"],
#  ["['Andrew",
#   "'",
#   '',
#   "'Joel",
#   "Evans'",
#   '',
#   "'Michael",
#   '.',
#   "Christian'",
#   '',
#   "'Stephen",
#   '.',
#   "Gilliland'",
#   '',
#   "'Edgar",
#   '.',
#   "Kausel'",
#   '',
#   "'Jordan",
#   '.',
#   "Stein']"],
#  ["['Shaobo",
#   '(Kevin)',
#   "'",
#   '',
#   "'Michail",
#   '.',
#   "Kokkoris'",
#   '',
#   "'Krishna",
#   "Savani']"],
#  ["['Huiwen",
#   "Lian'",
#   '',
#   "'.",
#   'Lance',
#   "Ferris'",
#   '',
#   "'Douglas",
#   '.',
#   "Brown']"],
#  [''],
#  [''],
#  ["['Alicea", "Lieberman'", '', "'Kristen", '.', "Duke'", '', "'", "Amir']"],
#  ['"Michael', '.', 'Liersch', 'Craig', '..', 'McKenzie"'],
#  ["['Katrina",
#   "'",
#   '',
#   "'Remus",
#   "Ilies'",
#   '',
#   "'Helen",
#   "Pluut'",
#   '',
#   "'",
#   'Ying',
#   "']"],
#  ["['Fern", "Healy'", '', "'Deborah", '.', "Small']"],
#  ['Lind', '', '.', '.', ''],
#  ["['", "'", '', "'", "Friedman'", '', "'Ying", "Hong']"],
#  ["['Peggy",
#   '.',
#   "'",
#   '',
#   "'Troy",
#   '.',
#   "Campbell'",
#   '',
#   "'Gavan",
#   '.',
#   "Fitzsimons'",
#   '',
#   "'Gráinne",
#   '.',
#   "Fitzsimons']"],
#  ["['Dong",
#   "'",
#   '',
#   "'Kaifeng",
#   "Jiang'",
#   '',
#   "'Christina",
#   '.',
#   "Shalley'",
#   '',
#   "'Sejin",
#   "Keem'",
#   '',
#   "'Jing",
#   "Zhou']"],
#  ["['",
#   "'",
#   '',
#   "'Xiao",
#   'xiao',
#   "'",
#   '',
#   "'Ying",
#   "Hong'",
#   '',
#   "'Joel",
#   "Brockner'",
#   '',
#   "'",
#   'pong',
#   "'",
#   '',
#   "'",
#   "']"],
#  ["['",
#   "'",
#   '',
#   "'Evan",
#   "Polman'",
#   '',
#   "'Yongfang",
#   "'",
#   '',
#   "'Jiangli",
#   "Jiao']"],
#  ["['Stefano",
#   "Livi'",
#   '',
#   "'Arie",
#   '.',
#   "Kruglanski'",
#   '',
#   "'Antonio",
#   "Pierro'",
#   '',
#   "'Lucia",
#   "Mannetti'",
#   '',
#   "'David",
#   '.',
#   "Kenny']"],
#  [''],
#  ["['Jennifer",
#   '.',
#   "Logg'",
#   '',
#   "'Julia",
#   '.',
#   "Minson'",
#   '',
#   "'",
#   '.',
#   "Moore']"],
#  ["['Robert",
#   '.',
#   "Lord'",
#   '',
#   "'Paola",
#   "Gatti'",
#   '',
#   "'Susanna",
#   '..',
#   "Chui']"],
#  [''],
#  ['Robert', '.', 'Lount', '.'],
#  ["['Robert",
#   '.',
#   'Lount',
#   ".'",
#   '',
#   "'Nathan",
#   '.',
#   "Pettit'",
#   '',
#   "'Sarah",
#   '.',
#   "Doyle']"],
#  [''],
#  ["['Jingyi", "'", '', "'Xiaofei", "']"],
#  ["['Jackson",
#   '.',
#   "'",
#   '',
#   "'Modupe",
#   "Akinola'",
#   '',
#   "'Malia",
#   '.',
#   "Mason']"],
#  ["['Shenghua", "Luan'", '', "'Jochen", "']"],
#  ['Luce', '', '.', '.', '.', ''],
#  ["['Matthew",
#   '.',
#   "Lupoli'",
#   '',
#   "'Emma",
#   '.',
#   "Levine'",
#   '',
#   "'Adam",
#   'Eric',
#   "Greenberg']"],
#  ['"Nicholas', '.', 'Lurie', 'Jayashankar', '.', 'Swaminathan"'],
#  ["['Brent", '.', "Lyons'", '', "'Brent", '.', "Scott']"],
#  ['Anyi', ''],
#  ["['Anyi", "'", '', "'", "Yang'", '', "'Krishna", "Savani']"],
#  ['Macchi', '', ''],
#  ['Robert', '.', 'MacCoun'],
#  ["['Boris", "Maciejovsky'", '', "'David", '.', "Budescu']"],
#  ['"Carl', '.', 'Maertz', 'Ahmad', 'Hassan', 'Peter', 'Magnusson"'],
#  ["['Vincent", "'", '', "'Amnon", "Rapoport']"],
#  ["['Vincent", "'", '', "'Amnon", "Rapoport'", '', "'Darryl", '.', "Seale']"],
#  ["['Vincent",
#   "'",
#   '',
#   "'Rami",
#   "Zwick'",
#   '',
#   "'Akshay",
#   '.',
#   "'",
#   '',
#   "'Jake",
#   '.',
#   "Pattaratanakun']"],
#  [''],
#  ['"Deepak', 'Malhotra"'],
#  ["['Selin",
#   '.',
#   "Malkoc'",
#   '',
#   "'",
#   "Zauberman'",
#   '',
#   "'James",
#   '.',
#   "Bettman']"],
#  ['Mandel', '', '.', '.', ''],
#  [''],
#  [''],
#  ["['Shannon",
#   '.',
#   "Marlow'",
#   '',
#   "'Christina",
#   '.',
#   "Lacerenza'",
#   '',
#   "'Jensine",
#   "Paoletti'",
#   '',
#   "'.",
#   'Shawn',
#   "Burke'",
#   '',
#   "'Eduardo",
#   "Salas']"],
#  ["['Jennifer",
#   'Carson',
#   "Marr'",
#   '',
#   "'Stefan",
#   "Thau'",
#   '',
#   "'Karl",
#   "Aquino'",
#   '',
#   "'Laurie",
#   '.',
#   "Barclay']"],
#  ["['Ashley", '.', "Martin'", '', "'Katherine", '.', "Phillips']"],
#  ["['Sean",
#   '.',
#   "Martin'",
#   '',
#   "'Julia",
#   '.',
#   "'",
#   '',
#   "'Bidhan",
#   'Lalit',
#   "Parmar']"],
#  ["['Elena",
#   "Martinescu'",
#   '',
#   "'Onne",
#   "Janssen'",
#   '',
#   "'Bernard",
#   '.',
#   "Nijstad']"],
#  [''],
#  ['"Malia', '.', 'Mason', 'Rebecca', 'Dyer', 'Michael', '.', 'Norton"'],
#  ["['Pragya",
#   "Mathur'",
#   '',
#   "'Shailendra",
#   'Pratap',
#   "Jain'",
#   '',
#   "'Meng",
#   "Hsieh'",
#   '',
#   "'Charles",
#   '.',
#   "Lindsey'",
#   '',
#   "'Durairaj",
#   "Maheswaran']"],
#  ['Matsumoto', '', '.', '.'],
#  ['"David',
#   '.',
#   'Mayer',
#   'Maribeth',
#   'Kuenzi',
#   'Rebecca',
#   'Greenbaum',
#   'Mary',
#   'Bardes',
#   'Rommel',
#   '(Bombie)',
#   'Salvador"'],
#  ["['David",
#   '.',
#   "Mayer'",
#   '',
#   "'Stefan",
#   "Thau'",
#   '',
#   "'Kristina",
#   '.',
#   "Workman'",
#   '',
#   "'Marius",
#   "Dijke'",
#   '',
#   "'David",
#   "Cremer']"],
#  ["['David",
#   '.',
#   "Mayer'",
#   '',
#   "'Samir",
#   "Nurmohamed'",
#   '',
#   "'Linda",
#   'Klebe',
#   "Treviño'",
#   '',
#   "'Debra",
#   '.',
#   "Shapiro'",
#   '',
#   "'Marshall",
#   "Schminke']"],
#  ['Ketti', 'Mazzocco'],
#  [''],
#  ['"Matthew',
#   '.',
#   'McCarter',
#   'Kevin',
#   '.',
#   'Rockmann',
#   'Gregory',
#   '.',
#   'Northcraft"'],
#  ["['Matthew",
#   '.',
#   "McCarter'",
#   '',
#   "'David",
#   '.',
#   "Budescu'",
#   '',
#   "'Jürgen",
#   "Scheffran']"],
#  ["['Julie",
#   '.',
#   "McCarthy'",
#   '',
#   "'Talya",
#   '.',
#   "Bauer'",
#   '',
#   "'Donald",
#   '.',
#   "Truxillo'",
#   '',
#   "'Michael",
#   '.',
#   "Campion'",
#   '',
#   "'Chad",
#   '.',
#   "Iddekinge'",
#   '',
#   "'Michael",
#   '.',
#   "Campion']"],
#  ["['James",
#   '.',
#   "McElroy'",
#   '',
#   "'James",
#   '.',
#   "Summers'",
#   '',
#   "'Kelly",
#   "Moore']"],
#  [''],
#  ["['.",
#   'Peter',
#   "McGraw'",
#   '',
#   "'Alexander",
#   "Todorov'",
#   '',
#   "'Howard",
#   "Kunreuther']"],
#  ['McKenzie', '', '.', '.', '.', ''],
#  ['"Craig', '..', 'McKenzie', 'Michael', '.', 'Liersch', 'Ilan', 'Yaniv"'],
#  [''],
#  [''],
#  ['"Geeta', 'Menon', 'Ellie', '.', 'Kyung', 'Nidhi', 'Agrawal"'],
#  ["['Tanya",
#   "Menon'",
#   '',
#   "'Jessica",
#   "'",
#   '',
#   "'Jeanne",
#   'Ying',
#   "'",
#   '',
#   "'",
#   "Chiu'",
#   '',
#   "'Ying",
#   "Hong']"],
#  ["['Christoph", "Merkle'", '', "'Martin", "Weber']"],
#  ["['Jessica",
#   '.',
#   'Mesmer',
#   "Magnus'",
#   '',
#   "'Leslie",
#   '.',
#   "DeChurch'",
#   '',
#   "'Miliani",
#   'Jimenez',
#   "Rodriguez'",
#   '',
#   "'Jessica",
#   "Wildman'",
#   '',
#   "'Marissa",
#   "Shuffler']"],
#  ['"Kerry',
#   '.',
#   'Milch',
#   'Elke',
#   '.',
#   'Weber',
#   'Kirstin',
#   '.',
#   'Appelt',
#   'Michel',
#   '..',
#   'Handgraaf',
#   'David',
#   '.',
#   'Krantz"'],
#  ["['Edward", '.', "Miles'", '', "'Elizabeth", '.', "Clenney']"],
#  ['Katherine', '.', 'Milkman'],
#  ["['Katherine",
#   '.',
#   "Milkman'",
#   '',
#   "'Mary",
#   'Carol',
#   "Mazza'",
#   '',
#   "'Lisa",
#   '.',
#   "'",
#   '',
#   "'Chia",
#   'Jung',
#   "Tsay'",
#   '',
#   "'",
#   '.',
#   "Bazerman']"],
#  ["['Kobe", "Millet'", '', "'Lien", "Lamey'", '', "'Bram", "Bergh']"],
#  ['"Andrew', '.', 'Miner', 'Theresa', '.', 'Glomb"'],
#  ["['Julia",
#   '.',
#   "Minson'",
#   '',
#   "'Eric",
#   '.',
#   "VanEpps'",
#   '',
#   "'Jeremy",
#   '.',
#   "'",
#   '',
#   "'Maurice",
#   '.',
#   "Schweitzer']"],
#  ["['Ella", 'Miron', "Spektor'", '', "'Gerard", "Beenen']"],
#  ["['Ella",
#   'Miron',
#   "Spektor'",
#   '',
#   "'Francesca",
#   "Gino'",
#   '',
#   "'Linda",
#   "Argote']"],
#  ["['Dorothee",
#   "Mischkowski'",
#   '',
#   "'Andreas",
#   "Glöckner'",
#   '',
#   "'Peter",
#   "Lewisch']"],
#  ["['Himanshu",
#   "Mishra'",
#   '',
#   "'Arul",
#   "Mishra'",
#   '',
#   "'Jessica",
#   "Rixom'",
#   '',
#   "'Promothesh",
#   "Chatterjee']"],
#  ['Alexandra', '.', 'Mislin'],
#  [''],
#  ["['Daniel", "Mochon'", '', "'Shane", "Frederick']"],
#  ["['Susan", "Mohammed'", '', "'David", '.', "Harrison']"],
#  ['Mohammed', '', '.', ''],
#  ["['Welmer",
#   '.',
#   "Molenmaker'",
#   '',
#   "'Erik",
#   '.',
#   "Kwaadsteniet'",
#   '',
#   "'Eric",
#   "Dijk']"],
#  ["['Welmer",
#   '.',
#   "Molenmaker'",
#   '',
#   "'Erik",
#   '.',
#   "Kwaadsteniet'",
#   '',
#   "'Eric",
#   "Dijk']"],
#  ["['Andrew",
#   '.',
#   "Molinsky'",
#   '',
#   "'Adam",
#   '.',
#   "Grant'",
#   '',
#   "'Joshua",
#   '.',
#   "Margolis']"],
#  [''],
#  ['Marlon', 'Mooijman'],
#  [''],
#  [''],
#  [''],
#  [''],
#  [''],
#  ["['Celia", "Moore'", '', "'", '.', "Tenbrunsel']"],
#  ["['Sarah",
#   '.',
#   "Moore'",
#   '',
#   "'David",
#   '.',
#   "Neal'",
#   '',
#   "'Gavan",
#   '.',
#   "Fitzsimons'",
#   '',
#   "'Baba",
#   "Shiv']"],
#  ['', '.', 'Moore'],
#  ['Moreland', '', '.', '.', '.', ''],
#  ['Morgan', '', '.', '.', ''],
#  ["['Michael",
#   '.',
#   "Morris'",
#   '',
#   "'Ying",
#   "Hong'",
#   '',
#   "'",
#   "Chiu'",
#   '',
#   "'",
#   "']"],
#  ['Jennifer', '.', 'Mueller'],
#  ["['Laetitia", '.', "Mulder'", '', "'Karl", "Aquino']"],
#  ["['Laetitia",
#   '.',
#   "Mulder'",
#   '',
#   "'Jennifer",
#   "Jordan'",
#   '',
#   "'Floor",
#   "Rink']"],
#  ["['.", 'Keith', "Murnighan'", '', "'Long", "Wang']"],
#  ['Brian', '.', 'Murtha'],
#  [''],
#  ['Mussweiler', '', '.', ''],
#  ['"Jennifer',
#   '.',
#   'Nahrgang',
#   'Frederick',
#   '.',
#   'Morgeson',
#   'Remus',
#   'Ilies"'],
#  ["['Jennifer",
#   '.',
#   "Nahrgang'",
#   '',
#   "'.",
#   'Scott',
#   "DeRue'",
#   '',
#   "'John",
#   '.',
#   "Hollenbeck'",
#   '',
#   "'Matthias",
#   "Spitzmuller'",
#   '',
#   "'Dustin",
#   '.',
#   "Jundt'",
#   '',
#   "'Daniel",
#   '.',
#   "Ilgen']"],
#  ["['Inbal", 'Nahum', "Shani'", '', "'Peter", '.', "Bamberger']"],
#  ["['Nathaniel",
#   '.',
#   "Nakashima'",
#   '',
#   "'David",
#   '.',
#   "Daniels'",
#   '',
#   "'Kristin",
#   "Laurin']"],
#  [''],
#  [''],
#  [''],
#  ["['Jayanth", "Narayanan'", '', "'Kenneth", "'", '', "'", "Kinias']"],
#  ["['Anne",
#   'Nederveen',
#   "Pieterse'",
#   '',
#   "'Daan",
#   "Knippenberg'",
#   '',
#   "'Wendy",
#   '.',
#   "Ginkel']"],
#  ['Nelson', '', '.', '.', ''],
#  ['Daniel', '.', 'Newark'],
#  ["['Daniel",
#   '.',
#   "Newark'",
#   '',
#   "'Vanessa",
#   '.',
#   "Bohns'",
#   '',
#   "'Francis",
#   '.',
#   "Flynn']"],
#  [''],
#  ['.', 'NgLinn', 'Dyne'],
#  ["['", "'", '', "'Linn", "Dyne'", '', "'Soon", "']"],
#  ["['Jessica",
#   '.',
#   "Nicklin'",
#   '',
#   "'Rebecca",
#   "Greenbaum'",
#   '',
#   "'Laurel",
#   '.',
#   "McNall'",
#   '',
#   "'Robert",
#   "Folger'",
#   '',
#   "'Kevin",
#   '.',
#   "Williams']"],
#  ['"Nicos', 'Nicolaou', 'Scott', 'Shane', 'Lynn', 'Cherkas', '.', 'Spector"'],
#  ["['Michael",
#   '.',
#   "Norton'",
#   '',
#   "'Elizabeth",
#   '.',
#   "Dunn'",
#   '',
#   "'Dana",
#   '.',
#   "Carney'",
#   '',
#   "'",
#   "Ariely']"],
#  ['Laura', '.', 'Noval'],
#  ["['Laura",
#   '.',
#   "Noval'",
#   '',
#   "'Andrew",
#   "Molinsky'",
#   '',
#   "'Günter",
#   '.',
#   "Stahl']"],
#  [''],
#  ['Kathleen', '.', '’ConnorJosh', '.', 'Arnold'],
#  ["['Burak",
#   "'",
#   '',
#   "'Michael",
#   '.',
#   "Daniels'",
#   '',
#   "'James",
#   '.',
#   "Diefendorff'",
#   '',
#   "'Michael",
#   '.',
#   "Bashshur'",
#   '',
#   "'Gary",
#   '.',
#   "Greguras']"],
#  ['Ofir', '', '.'],
#  [''],
#  ["['Greg", '.', "Oldham'", '', "'Yitzhak", "Fried']"],
#  [''],
#  ['Madeline', ''],
#  ['Ordo´', '˜', '', '', '.', '.', '.', ''],
#  [''],
#  ['"Jennifer',
#   '.',
#   'Overbeck',
#   'Margaret',
#   '.',
#   'Neale',
#   'Cassandra',
#   '.',
#   'Govan"'],
#  ['"Shweta', '.', 'Joydeep', 'Srivastava', 'Nevena', '.', 'Koukova"'],
#  ['"Neeru',
#   'Paharia',
#   'Karim',
#   '.',
#   'Kassam',
#   'Joshua',
#   '.',
#   'Greene',
#   '.',
#   'Bazerman"'],
#  ["['Neeru",
#   "Paharia'",
#   '',
#   "'Kathleen",
#   '.',
#   "Vohs'",
#   '',
#   "'Rohit",
#   "Deshpandé']"],
#  ['Mauricio', 'Palmeira'],
#  [''],
#  ['Mauricio', 'Palmeira'],
#  ["['Karthik",
#   "Panchanathan'",
#   '',
#   "'Willem",
#   '.',
#   "Frankenhuis'",
#   '',
#   "'Joan",
#   '.',
#   "Silk']"],
#  ["['Guihyun", "Park'", '', "'Richard", '.', "DeShon']"],
#  ["['", 'Youn', "Park'", '', "'Seongsu", "'", '', "'", "Sung']"],
#  ["['Shefali", '.', "Patil'", '', "'.", 'David', "Lebel']"],
#  ['Paulus', '', '.', '.', '.', ''],
#  ["['Craig",
#   '.',
#   "Pearce'",
#   '',
#   "'Christina",
#   '.',
#   "Wassenaar'",
#   '',
#   "'Yair",
#   "Berson'",
#   '',
#   "'Rivka",
#   'Tuval',
#   "Mashiach']"],
#  ['"Matthew',
#   '.',
#   'Pearsall',
#   'Aleksander',
#   '..',
#   'Ellis',
#   'Jordan',
#   '.',
#   'Stein"'],
#  ['', '.', 'Peng'],
#  [''],
#  ['Pettibone', '', '.', '.', '.'],
#  ["['Nathan",
#   '.',
#   "Pettit'",
#   '',
#   "'Sarah",
#   '.',
#   "Doyle'",
#   '',
#   "'Robert",
#   '.',
#   'Lount',
#   ".'",
#   '',
#   "'Christopher",
#   "']"],
#  ['"Michel', 'Tuan', 'Pham', 'Tamar', 'Avnet"'],
#  ["['Michel",
#   'Tuan',
#   "Pham'",
#   '',
#   "'",
#   'Faraji',
#   "'",
#   '',
#   "'Olivier",
#   "Toubia'",
#   '',
#   "'Leonard",
#   "']"],
#  ['Jean', '.', 'Phillips'],
#  [''],
#  [''],
#  [''],
#  ['".', 'David', 'Piercey"'],
#  [''],
#  [''],
#  ["['Nashita",
#   "Pillay'",
#   '',
#   "'Guihyun",
#   "Park'",
#   '',
#   "'",
#   'Kang',
#   "'",
#   '',
#   "'Sujin",
#   "']"],
#  ["['Robin",
#   '.',
#   "Pinkley'",
#   '',
#   "'Donald",
#   '.',
#   "Conlon'",
#   '',
#   "'John",
#   '.',
#   "Sawyer'",
#   '',
#   "'Dustin",
#   '.',
#   "Sleesman'",
#   '',
#   "'",
#   "Vandewalle'",
#   '',
#   "'Maribeth",
#   "Kuenzi']"],
#  ["['Marko",
#   "Pitesa'",
#   '',
#   "'Stefan",
#   "Thau'",
#   '',
#   "'Madan",
#   '.',
#   "Pillutla']"],
#  ["['Timothy",
#   '.',
#   "Pleskac'",
#   '',
#   "'Jessica",
#   "Keeney'",
#   '',
#   "'Stephanie",
#   '.',
#   "Merritt'",
#   '',
#   "'Neal",
#   "Schmitt'",
#   '',
#   "'Frederick",
#   '.',
#   "Oswald']"],
#  ["['Helen",
#   "Pluut'",
#   '',
#   "'Remus",
#   "Ilies'",
#   '',
#   "'Petru",
#   '.',
#   "Curşeu'",
#   '',
#   "'Yukun",
#   "']"],
#  [''],
#  ['Evan', 'Polman'],
#  ["['Evan", "Polman'", '', "'.", 'Edward', "Russo']"],
#  [''],
#  ['"Christine', '.', 'Porath', 'Amir', 'Erez"'],
#  ["['Steven",
#   '.',
#   "Posavac'",
#   '',
#   "'Frank",
#   '.',
#   "Kardes'",
#   '',
#   "'.",
#   'Joško',
#   "Brakus']"],
#  [''],
#  ['Kenneth',
#   '.',
#   'Price',
#   '',
#   'Thomas',
#   '.',
#   'Hall',
#   '',
#   'Kees',
#   '',
#   '',
#   'James',
#   '.',
#   'Hunton',
#   '',
#   'Steve',
#   'Lovett',
#   '',
#   'Mark',
#   '.',
#   'Tippett'],
#  [''],
#  ["['Devon", "Proudfoot'", '', "'Aaron", '.', "'", '', "'Heather", "Mann']"],
#  ["['Christina",
#   '.',
#   "Rader'",
#   '',
#   "'Jack",
#   '.',
#   "Soll'",
#   '',
#   "'Richard",
#   '.',
#   "Larrick']"],
#  ['"Joseph', '.', 'Radzevick', '.', 'Moore"'],
#  ["['Joseph", '.', "Radzevick'", '', "'", '.', "Moore']"],
#  [''],
#  ["['Tage", '.', "'", '', "'Daniel", "Diermeier']"],
#  [''],
#  ['Rapoport', '', '.', ''],
#  [''],
#  ['..', 'Services'],
#  ['Rettinger', '', '.', '.', ''],
#  ['Anine', 'Riege'],
#  [''],
#  ["['Claudia",
#   '.',
#   "Sacramento'",
#   '',
#   "'Doris",
#   "'",
#   '',
#   "'Michael",
#   '.',
#   "West']"],
#  ["['Sunita", "'", '', "'", '.', "Moore'", '', "'Robert", '.', "MacCoun']"],
#  [''],
#  ['Daniel.Schwartz',
#   '',
#   'Elizabeth..Keenan',
#   '',
#   'Alex.Imas',
#   '',
#   'Ayelet.Gneezy'],
#  [''],
#  ['Robert', 'SneddonR.', 'Duncan', 'Luce'],
#  ["['Antonios",
#   "Stamatogiannakis'",
#   '',
#   "'Amitava",
#   "Chattopadhyay'",
#   '',
#   "'Dipankar",
#   "Chakravarti']"],
#  ['Stone', '', '.', '.', '.'],
#  ['Unknown'],
#  ['Gabriel', 'Szulanski'],
#  ['Francesca', 'Gino'],
#  ["['Christian",
#   "¶ster'",
#   '',
#   "'Ajay",
#   "Mehra'",
#   '',
#   "'Daan",
#   "Knippenberg']"],
#  ['Chia', 'Jung', 'Tsay'],
#  ['Michel', 'Tuan', 'Pham', '', 'MeyvisRongrong', 'Zhou'],
#  [''],
#  ['Venkatesh', '', '.', '.'],
#  ['Weiss',
#   'Cohen',
#   '',
#   '',
#   '',
#   'Konstantinidis',
#   '',
#   '',
#   '',
#   'Speekenbrink',
#   '',
#   'MHarvey',
#   '',
#   ''],
#  [''],
#  ['Windschitl', '', '.', '.', ''],
#  ['Windschitl', '', '.', '.', ''],
#  [''],
#  ['Yaniv', '', '.', '.'],
#  [''],
#  [''],
#  [''],
#  ['Zeelenberg', '', '.', '.'],
#  ['']]

# %%
pdf_text_subject = [] #title

for i in pdf_ref:
    line = i
    # for author
    for j in pdf_title:
        line = re.sub(j, '', line)
        
    pdf_text_subject.append(line)

# %%
pdf_text_subject[0] # it is title
# Out:
# '\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\ninterest (mis)alignments in representative s: do pro-social agents fuel or reduce inter-group conflict?\n\n\n 120 (2013) 240–250\ncontents lists available at sciverse sciencedirect\n\n\n\njournal homepage: www.elsevier .com/ locate /obhdp\ninterest (mis)alignments in representative s: do pro-social agents fuel\nor reduce inter-group conflict?\n\nhillie aaldering ⇑, lindred l. greer, gerben a. van kleef, carsten k.w. de dreu\ndepartment of psychology, university of amsterdam, the netherlands\n\na r t i c l e i n f o\narticle history:\nreceived 23 december 2011\naccepted 4 june 2012\n\nkeywords:\npersonality\ncooperation\ncompetition\naltruism\nprincipal agent theory\nsocial value orientation\n0749-5978/$ - see front matter � 2012 elsevier inc. a\nhttp://dx.doi.org/10.1016/j.obhdp.2012.06.001\n\n⇑ corresponding author. address: university of\npsychology, weesperplein 4, 1018 xa amsterdam, th\n\ne-mail address: h.aaldering@uva.nl (h. aaldering)\na b s t r a c t\n\nin representative s, interests of the representative and the represented constituency are not\nalways aligned. we investigated how interest (mis)alignment and representative’s social value orienta-\ntion influence representative s. past theory and research on the principal–agent problem,\nsocial value orientation, and cooperation in social dilemmas offer different perspectives, which we exam-\nined in two experiments. experiment 1 revealed that both representatives with a pro-social and a pro-self\nvalue orientation were reluctant to accommodate the  adversary at a cost to themselves and\ntheir constituency, while pro-social representatives were more willing to sacrifice self-interest to benefit\nconstituency and adversary combined. experiment 2 replicated this finding, and clarified that pro-social\nrepresentatives were more willing to self-sacrifice when this served their constituency only than when it\nindirectly served the adversary too. such parochial altruism demonstrates the discriminatory nature of\npro-socials’ cooperation and reveals the potential dark side of a pro-social orientation in constructive\nintergroup s.\n\n� 2012 elsevier inc. all rights reserved.\nintroduction\n\nto reduce inter-group tension, to facilitate dispute resolution,\nor to strike mutually beneficial deals, competing groups often en-\ngage representatives who negotiate on their behalf. these repre-\nsentatives may be core members of the group, but can also be\nexternal agents with specific skills, knowledge or expertise in the\nrelevant  domain. a potential problem arises when\nthe interests of the representative are not unequivocally aligned\nwith the interests of the represented party. such a conflict of inter-\nest exists, for example, among investment bankers representing\nbidding firms during merger s: they receive compensa-\ntion based on the premium paid for target firms. while it is in the\ntarget firms’ interest to reach a maximum possible premium, the\nbidding firm strives for a premium as low as possible, potentially\nresulting in lower compensation for the investment banker (kes-\nner, shapiro, & sharma, 1994).\n\nthe problem of interest (mis)alignment is often referred to as\nthe principal–agent problem, in which the agent (representative)\nhas other preferences than the principal (represented group or\norganization) (allcock & filatotchev, 2010; eisenhardt, 1989; jen-\nsen & meckling, 1976) and may even have personal preferences\nmore aligned with the opposing group. this may lead the represen-\ntative to negotiate agreements that benefit him- or herself at the\nll rights reserved.\n\namsterdam, department of\ne netherlands.\n.\n\nexpense of the group he or she represents (bazerman, neale, val-\nley, zajac, & kim, 1992; valley, white, neale, & bazerman, 1992).\nhere we integrate theory on the principal–agent problem with\nthe growing body  ...

# %%
# not required
def eliminate_method_result(method, discussion):
    
    import re    
    start = method
    end = discussion
    #start of pattern, followed by any number of times 'any character OR a newline' and terminated by the end pattern.
    pattern = start + '.*'+'(.|\n)*'+end
    pdf_method_dis = [re.sub(pattern, '', f) for f in pdf_text]

    return pdf_method_dis

# %%
# not required
def eliminate_method_result_ref(method, dis, ref):
    
    import re

    start = method
    end = dis
    
    #start of pattern, followed by any number of times 'any character OR a newline' and terminated by the end pattern.
    pattern = start + '.*'+'(.|\n)*'+end
    pdf_method_dis = [re.sub(pattern, '', f) for f in pdf_text]
    
    start_ref = ref
    pattern_ref = start_ref +'(.|\n)*$'

    pdf_ref= [re.sub(pattern_ref, '', f) for f in pdf_method_dis]
    
    return pdf_ref

# %% [markdown]
# # Pre-processing
# Regular expression is used to clean up the pre-processed data and saved as a Master data

# %%
import re
pdf_p= [re.sub(r"-\n(\n)*", "", t)for t in pdf_text_subject]

pdf_p= [re.sub(r"\n(\n)*", "\n", t)for t in pdf_p]

pdf_p= [re.sub(r"\n", " ", t)for t in pdf_p]
# remove text with [] eg citation
pdf_p = [re.sub(r"\[[^)]*\]", "", t)for t in pdf_p]
#Remove numbers
pdf_p = [re.sub('[0-9]+', '', f) for f in pdf_p]
#pdf_p = [re.sub("r[\S]+\.(net|com|org|info|edu|gov|uk|de|ca|jp|fr|au|us|ru|ch|it|nel|se|no|es|mil)[\S]*\s?", " ", t)for t in pdf_p]
pdf_p = [re.sub('[!@/%“”‘:#©β<>+=δχ*&$]', ' ', f) for f in pdf_p]
pdf_p = [re.sub('’s','', f) for f in pdf_p]
pdf_p = [re.sub('’re','', f) for f in pdf_p]
pdf_p = [re.sub('’t','', f) for f in pdf_p]
pdf_p = [re.sub('’ve','', f) for f in pdf_p]
pdf_p = [re.sub('’ll','', f) for f in pdf_p]
pdf_p = [re.sub('’m','', f) for f in pdf_p]

pdf_p = [re.sub('[:()-]', ' ', f) for f in pdf_p]
pdf_p = [re.sub('[\.!?]+ ', 'XYZXYZ', t) for t in pdf_p]
# \w will match alphanumeric characters and underscores
# [^\w] will match anything that's not alphanumeric or underscore
pdf_p = [re.sub(r'[^\w]', ' ', f) for f in pdf_p]
pdf_p = [re.sub('XYZXYZ', '.', f) for f in pdf_p]
pdf_p = [re.sub(' +', ' ', f) for f in pdf_p]
# Replace multiple dots with one dot
pdf_p = [re.sub('\.\.+',".", f) for f in pdf_p]
pdf_p = [re.sub(r'\b\w{1,3}\b',"", f) for f in pdf_p]
pdf_p = [re.sub(' +', ' ', f) for f in pdf_p]

pdf_p = [re.sub("^\s+","", f) for f in pdf_p]# remove the front space
pdf_p = [re.sub("\s+\Z","", f) for f in pdf_p]#remove the back space

# %%
author_list = ["hillie", "aaldering","lindred","greer", "gerben", "kleef", "carsten", "dreu","susanne"]
author_list += ["abele", "garold", "stasser", "christopher", "chartier", "hajo", "adam", "otilia", "obodaru", "adam"]
author_list += ["galinsky", 'hajo', 'adam', "gabrielle", "adams", "inesi", "madan", "pillutla", "ishani", "aggarwal"]
author_list += ["anita", 'williams', "woolley", "nidhi", "agrawal","dahee","adam", "duhachek", "emily"]
author_list += ["amanatullah","catherine","tinsley", "maureen", "ambrose", "marshall", "schminke", "scott"]
author_list += ["reynolds", "daniel","ames","elke","weber" "amit","lilach", "sagiv"]
author_list += ['eduardo','andrade', "eduardo','andrade', 'ariely", "frederik", 'anseel', 'filip', 'lievens', 'eveline']
author_list += ["schollaert", 'ayala', 'arad', "nicholas","aramovich","james","larson", "linda", "argote",]
author_list += ["erin", "fahrenkopf", 'argote','arkes','arkes', 'david', 'hirshleifer']
author_list += ['danling', 'jiang', "sonya", "rachel","arnett", "sidanius", "laurence", "ashworth", "peter"]
author_list += ["darke", "lindsay", "mcshane", "tiffany", "giuseppe", "attanasi", "aurora", 'garcía', "gallego"]
author_list += ["nikolaos", "georgantzís", "aldo", "montesano", "evelyn", "zhang", "brandy"]
author_list += ["aven","lily", "morse","alessandro", "iorio", 'derek','avery', "shahar", "ayal","jérémy"]
author_list += ["celse" "hochman", "markus", "baer","graham", "brown", "feng","grace", 'ching'] 
author_list += ["daniel", "balliet","lance", "ferris", "gary", "ballinger", "david", "lehman", "schoorman"]
author_list += ['baltes','baltes',"alixandra", "barasch", "emma", "levine", "maurice"]
author_list += ["schweitzer", "christopher", "barnes", "john", "schaubroeck", "megan", "huth", "sonia", "ghumman", "andrew"]
author_list += ["michael", "karpman", "sharon", "long", "yaniv", "hanoch", "thomas", "rice", "shankha", "basu",]
author_list += ["krishna", "savani", "bauman", "leigh", 'plunkett', "tost", "madeline","bazerman","ovul"]
author_list += ["sezer", "james","beck","aaron","schmidt", 'beersma',"bianca", 'beersma', 'john']
author_list += ['hollenbeck', 'donald', 'conlon', 'stephen', 'humphrey', 'henry', 'moon', 'daniel', "ilgen", "bianca", "beersma"]
author_list += ["astrid", "homan", "peter", "belmi","margaret", "neale", 'benbasat','justin','berg']
author_list += ["peter", "bergman", "jessica", 'lasky', "fink", "todd", "rogers", "jonathan", "berman", "amit"]
author_list += ["bhattacharjee", "deborah", "small", "zauberman", "john", "beshears", "james", "choi", "laibson", "brigitte"]
author_list += ["madrian", 'tilmann', 'betsch', 'susanne', 'haberstroh', 'andreas', 'ckner', 'rthomas', 'haar', 'klaus']
author_list += ['fiedler', "constant','beugré", 'syon','bhanot', 'rajesh', 'bhargave', "nazlı", "bhatia","brian"]
author_list += ["gunia", "emily","bianchi","joel", "brockner", "guido", 'biele', 'jörg', 'rieskamp']
author_list += ["czienskowski", 'baler', 'bilgin', "baler", "bilgin","lyle", "brenner", "mark", "bing", "kluemper"]
author_list += ['kristl', "davison", "shannon", "taylor", "milorad", "novicevic", "dipayan", "biswas","cornelia"]
author_list += ["pechmann",'bradford', 'bitterly', "steven", "blader", "batia", "wiesenfeld", "marion", "fortin", "sara"]
author_list += ['wheeler', "smith", 'sean', 'blair', "allen", "blay", "kathryn", "kadous", "kimberly", "sawers", 'blount',]
author_list += ["hayley", "blunden", "jennifer", "logg", "alison", 'wood', "brooks", "leslie", "john", "francesca"]
author_list += ["gino", 'boehne', 'fong', "wong", 'vanessa','bohns', 'boles']
author_list += ["bolino", "jaron", "harvey", "daniel", "bachrach", "bryan","bonner","alexander"]
author_list += ["bolinger", "simona', 'botti', 'christopher','hsee", "susanne", "braun","claudia", "peus",]
author_list += ["dieter", "frey", "lyle", "brenner","baler", "bilgin", "jeanne", "brett","leigh", "thompson"]
author_list += ['brief','brief',"sebastien", "brion","cameron", "anderson", 'brockner']
author_list += ['joel', 'brockner', 'brodt',"alison", 'wood', "brooks","maurice"]
author_list += ["schweitzer", 'alison', 'wood', 'brooks', "graham", "brown","markus", "baer", "patrick", "bruning"]
author_list += ["bradley", "alge", "hsin", 'chen', "roger", 'buehler', 'johanna', 'peetz', 'dale', "griffin", "roger", "buehler"]
author_list += ["dale", "griffin", "kent", "deslauriers", "katherine", "burson", "faro", "yuval", "rottenstreich", "marcus"]
author_list += ["butts", "devin", "lunt", "traci", "freling", "allison", "gabriel", "adrian","camilleri"]
author_list += ["newell", "kurt","carlson","abhijit", "guha", "kurt", "carlson", "robin", "tanner", "margaret"]
author_list += ["meloy", 'edward', "russo", "joel", "carnevale", "huang", "harms", "lisa", "cavanaugh", "gino", "gavan"]
author_list += ["fitzsimons", "brianna", 'barker', "caza", "larissa", "tiedens", "fiona", 'wook', "chang", "rosalind"]
author_list += ["chow", "anita", "woolley", "christopher","chartier","susanne", "abele", "jennifer", 'chatman']
author_list += ['alicia', 'boisnier', 'sandra', 'spataro', 'cameron', 'anderson', 'jennifer', "berdahl", "anne", 'sophie', "chaxe_listl"]
author_list += ["catherine", "wiggins", "jieru", 'xiao', 'ping', 'chen', "xiao", "chen","gary","latham", "xiao"]
author_list += ['ping', "chen" "morgan", "gilad", 'ruth', 'kanfer', 'richard', 'deshon', 'mathieu', 'steve', "kozlowski"]
author_list += ["chao", "chen", "friedman", "mcallister", "tingting", "fuli", "xiao", 'ping', "zhanying", "arik", "cheshin"]
author_list += ["anat", "rafaeli","nathan", 'arik', 'cheshin', "arik", "cheshin" "amit","gerben"]
author_list += ["kleef", "cheung", "emily", "song", "liqun", 'tsan', "chang","hsien", 'lier']
author_list += ["huang","sinhui", "chong", 'whee', "russell", "johnson", 'joanna', "jessica", 'siegel']
author_list += ["christian", "matthew", "pearsall", "erin", "long", "chua","michael"]
author_list += ["morris","shira", "jinseok", "chun", "joel", "brockner", "cremer", 'corinne', 'coen', 'cohen']
author_list += ['charash',"irina", "cojuharenco","natalia", "karelaia", "irina", "cojuharenco", "patient"]
author_list += ["bashshur", "jason", "colquitt", "kate", "zipay", "lynch", "ryan", "outlaw", "donald", "conlon", "tinsley"]
author_list += ["samuel", "birk", "stephen", "humphrey", "aleksander", "ellis", "benjamin","converse","patrick"]
author_list += ["dennis", 'copeland',"yann", "cornil","david","hardisty","yakov", "bart"]
author_list += ['coughlan',"william", 'cron', 'mary', 'gilly', 'graham', 'slocum", "matthew','cronin']
author_list += ['cleotilde', 'gonzalez', 'john','sterman", "craig',"crossley", "cynthia", "cryder", "george"]
author_list += ["loewenstein", "richard", "scheines", "jared", 'curhan', 'margaret', 'neale', 'ross', 'jesse', 'rosencranz']
author_list += ["engelmann", 'shawn','curleyglenn','browne', "serge",'motta', "veiga","daniel"]
author_list += ["turban", "dahling", "shaun", "wiley", "zachary", "fishman", "amber", "loihle", 'hengchen',"xianchi"]
author_list += ["zlatev", 'david','daniels', 'darr',"tina", "davidson","linn", "dyne"]
author_list += ["bilian", "mark','davis",'bruin',"david", 'cremer', 'eric', "dijk", "erik"]
author_list += ["kwaadsteniet", "sanne", "rijkhoff", "eric", "dijk", "frank", "karen", "jehn", "daan", "scheepers"]
author_list += ["michael', 'dekay', 'dalia', 'patiño', 'echeverri', 'paul', 'fischbeck", "michael", "dekay", "seth", "miller"]
author_list += ["schley", "breann", "erford", "rellie', 'derfler', 'rozin', 'madan', 'pillutla', 'stefan', 'thau", "sreedhari"]
author_list += ["desai","maryam", "kouchaki", 'sreedhari','desai', "pieter", "desmet","david"]
author_list += ["cremer","eric", "dijk", "dirks", "donald", "ferrin", "cecily", "cooper", "jeremy", "douthit"]
author_list += ["melanie", "millar", "roger", "white", 'ning',"ning", "budescu", "marjorie", "shelly", "omer", 'michelle']
author_list += ['duguid', "james', 'dulebohn', 'issidoros', 'sarinopoulos', 'robert', 'davison', 'gerry', 'mcnamara", "jennifer"]
author_list += ["dunn", "nicole", "ruedy", "sunasir", "dutta","hayagreeva", 'charlotte', 'mayne', "jane"]
author_list += ["ebert", "mahdi", "ebrahimi", "maryam", "kouchaki", "vanessa", "patrick", 'none', 'emir', 'efendić', "daniel"]
author_list += ["effron","dale","miller", "daniel", "effron", "brian", "lucas", "kieran", "’connor", "casey"]
author_list += ["eggleston", "timothy", "wilson", "minha", "gilbert", 'kyle','emich', "kyle","emich","lynne"]
author_list += ["vincent", "kimmo", "eriksson", "pontus", "strimling", "julie", "coultas", 'arvid', 'erlandsson', "lauren"]
author_list += ['eskreis', "winkler","ayelet", "fishbach", "nathanael", "fast", "niro", "sivanathan", "mayer", "sean"]
author_list += ["fath","aaron" "alberto", "feduzi","jochen", "runde", "sanne", "feenstra", "jordan"]
author_list += ["frank", "walter", "janka", "stoker", "ryan", "fehr","michele","gelfand", "ryan", "fehr", "jack"]
author_list += ['ting', "chiang", "welsh", "baer", "manuel", "vaulont", "philip", "fernbach", "york", "hagmayer", "steven"]
author_list += ["sloman", "donald', 'ferrin', 'michelle', 'bligh', 'jeffrey', 'kohles", 'lance', 'ferris', 'douglas']
author_list += ['brown', 'daniel', "heller", "florian", 'fessel', 'epstude', 'neal',"roese", 'fiedler',"klaus"]
author_list += ["fiedler", "franz", "wöllert", "benjamin", "tauber", "philipp", "hess", "susann", "andreas", "glöckner"]
author_list += ["nicklisch", "stephan", "dickert", "fischer", "kastenmüller", "tobias", "greitemeyer", "julia", "dieter"]
author_list += ["frey", "ayelet", "fishbach","jinhee", "choi", 'colin','fisher', 'forgas',"alison"]
author_list += ['fragale', 'benson', 'rosen', 'carol', 'iryna', "merideth", "douglas", "frank", "klaus", "wertenbroch"]
author_list += ["william", "maddux", 'fraser', "mackenzie","sung", "johnson", "traci", "vincent"]
author_list += ["henard", "jane", "fung","wing", 'tung', "deshani","ganegoda","robert", "folger"]
author_list += ['ganzach',"stephen", "garcia", "hyunjin", "song", "abraham", "tesser", "varun", "gauri"]
author_list += ["julian", "jamison", "nina", "mazar", "owen", "ozier", 'phillip',"jennifer","george","erik"]
author_list += ["dane", "robert','giambatista', 'anita','bhappu", 'gibson',"kerry", 'roberts']
author_list += ["gibson", "dana", "harari", 'carson', "marr", 'gilbert',"francesca", "gino", "francesca"]
author_list += ["gino","adam","galinsky", "francesca", "gino","joshua","margolis", "francesca", 'gino']
author_list += ['lamar', "pierce", "francesca", 'gino', 'shang', 'rachel', "croson", "francesca", 'gino', 'linda', 'argote', 'ella']
author_list += ['miron', 'spektor', 'gergana', "todorova", "francesca", 'gino', 'lisa',"bazerman", "francesca"]
author_list += ["zachariah", "sharek", "moore", "schweitzer", "mead", "ariely", "francesca", "gino","ovul", "sezer"]
author_list += ["laura", "huang", "eric", "gladstone","kathleen","’connor", "jack",'goncalo', 'michelle']
author_list += ["duguid", "jack","goncalo","michelle","duguid", "jack", "goncalo", "evan", "polman"]
author_list += ["christina", "maslach", 'helena','gonzã¡', 'gã³mez', 'gonza´', 'vallejo',"claudia", 'gonzã¡']
author_list += ["vallejo", "jason", "harman", "etienne", "mullet", "maria", 'muñoz', "sastre", "jodi", "goodman", "robert"]
author_list += ["wood", "zheng", "chen", "james", "grand", "juliya", "golubovich", 'marie', "ryan", "neal", "schmitt"]
author_list += ["adam","grant","david","hofmann", "adam','grant', 'sabine', 'sonnentag", "adam", "grant"]
author_list += ["samir", "nurmohamed", "susan", "ashford", "dekas", "lindred", "heather", "caruso", "jehn"] 
author_list += ['gruenfeld',"cristiano","guarana","christopher","barnes", "brian","gunia"]
author_list += ["emma","levine", 'guyse',"philip", "gylfe","henrika", "franck","eero"]
author_list += ["vaara", "andrew","hafenbrack","kathleen","vohs", "hafenbrack", "lindsey", "cameron"]
author_list += ["gretchen", "spreitzer", "chen", "zhang", "laura", "noval", "samah", "shaffakat", 'lydia', 'paine', 'hagtvedt']
author_list += ["jeffrey', 'hales", "rebecca', 'hamilton', 'stefano', 'puntoni', 'nader', 'tavassoli", "hamilton", "kathleen"]
author_list += ["vohs", "anne", 'laure', "sellier", "meyvis", "sean", "hannah", "bruce", "avolio", "fred", "walumbwa"]
author_list += ["adrian", "chan", "jennings", "dustin", "bluhm", 'chunyan', "peng", "schaubroeck", 'uriel', 'haran', 'andrew']
author_list += ['hardin', 'hardy', 'anthony', "hughes", "xiaoqian", "wang", "schuelke", 'harinck',"einav"]
author_list += ["hart","maurice","schweitzer", 'harvey',"neil", "hauenstein", "kevin", "bradley"]
author_list += ["patrick", 'gavan', "’shea", "yashna", "shah", "douglas", "magill", "madeline", "heilman", "manzi", "suzette"]
author_list += ["caleo", 'henry','sandy', "hershcovis", "lukas", "neville", "tara", "reich", "christie"]
author_list += ["lilia", "cortina", 'valerie', "shan", "hershfield", "taya", "cohen", "thompson", "ivona", "hideg"]
author_list += ['lance', "ferris", "ivona", "hideg","anne","wilson", 'tory', "higgins","james"]
author_list += ["cornwell", 'angus', "hildreth", "bazerman", 'sharon', 'hill', 'kathryn', 'bartol', 'tesluk', 'gosia']
author_list += ["langa", 'hinds',"violet","dejun", 'tony', "kong", "hollenbeck", "ellis"]
author_list += ["adela", "garza", "ilgen", "peter","zhixing", "xiao", 'horvath',"lawrence"]
author_list += ["houston", "alicia", "grandey", "katina", "sawyer", "hsee", "luxi", "shen", "shirley", "jingqiu", "zhang"]
author_list += ["christopher","hsee","yang", "yang","xilin", "kaifeng", "jiang", "shenjiang", "honghui"]
author_list += ["junqi", "yanliu", "huang",'wesley', "hutchinson", ", 'huang','keith', 'murnighan",'huang']
author_list += ["dong", "huang","liyin","ying", "zhang", 'huber',"michaela", "huber"]
author_list += ["leaf", "boven", 'peter', "mcgraw", 'johnson', "graham", "hilde", "huizenga", "ruud", "wetzels", "ravenzwaaij"]
author_list += ["wagenmakers", "federico", "aime", "lily", "cushenbery", "aaron", "hill", "joshua", "fairchild", 'daniel']
author_list += ['ilgen', "remus", "ilies", "keeney", "brent", "scott", "lynn", 'imai', 'michele',"gelfand", "inesi"]
author_list += ["chester", "insko", "wildschut", "cohen", 'julie','irwinjonathan', 'baron', "jachimowicz", "shira"]
author_list += ["agasi", "stéphane", "côté", 'jack', "walker", "hubert", "feild", "giles", "jeremy", "bernerth", "short"]
author_list += ["karen','jehn', 'katerina', 'bezrukova", "lars', 'olof', 'johansson', 'henrik', 'svedsäter", "leslie"]
author_list += ["rick", "alessandro", "acquisti", "joachim", "vosgerau", "martha", "jeong", "huang", 'johnson']
author_list += ['scott', "derue", "jundt", "stefanie", "sitzmann", 'thuy', "nguyen", "russell", "danielle", "king"]
author_list += ["scott", 'jackson', "wang", "eric","jones","janice","kelly", "dong", "mingpeng", "dong"]
author_list += ["qiongjing", "marie", "juanchich", "miroslav", "sirota", "butler", 'judge',"timothy"]
author_list += ["judge","remus", "ilies","zhen", "zhang", "jung","sujin",'juvina', "ariel"]
author_list += ["kalil", "sebastian", "gallegos", "ruth", "kanfer","gilad", "chen", "dana", "kanze", "mark", "conley"]
author_list += ['tory', "higgins", "gokhan", "karagonlar","david","kuhlman", 'natalia', 'karelaia', "yoshihisa"]
author_list += ["kashima", "simon", "laham", "bianca", "levis", "darlene", "wong", "melissa", "wheeler", "edgar"]
author_list += ["kausel","jerel","slaughter", "edgar", "kausel", "satoris", "culbertson", "pedro", "leiva"]
author_list += ["jerel", "slaughter", "alexander", "jackson", "hector", "madrid", "eric", "kearney", "meir", "shemla"]
author_list += ["knippenberg", "florian", "scholz", 'steffen', 'keck', 'kelly',"jessica","kennedy",]
author_list += ["cameron", "anderson", "jessica","kennedy","maurice","schweitzer", "kennedy", "cameron"]
author_list += ["anderson", "kray", "gillian", "yeun", 'joon',"chen", "zhong", "cooper", "kurt", "ferrin", "linn"]
author_list += ["dyne", "dishan", "kamdar", "johnson", "hakkyun","kyoungmi","kiwan", "park", "kinias"]
author_list += ["heejung", "andrew", "jina", 'nadav', 'klein', 'klein',"klein", "knight", "jonathan"]
author_list += ["ziegert", "beng", 'chong', "saltz", "jesse", "kluver", "rebecca", "frazier", "haidt", 'knez']
author_list += ['tehila', 'kogut', "michail", "kokkoris", "baumeister", "ulrich", "kühnen", "lukas", "koning", "wolfgang"]
author_list += ["steinel", "ilja", "beest", "koopman", "fadel", "matta", "conlon", "shirli', 'kopelman", 'maryam', 'kouchaki']
author_list += ["maryam", "kristin", 'smith', "crowe", "arthur", "brief", "carlos", "sousa", 'kozlowski']
author_list += ["thomas", "kramer","lauren","block", "thomas", "kramer", "ozge", 'yucel', "aybat", "loraine"]
author_list += ["gesk", "michal", "maimaran", "itamar", "simonson", "florian", "kraus", "ahearne", "wieseke", 'kray']
author_list += ['kray',"laura", "alex", "zant", 'krishnamurthy',"justin", 'kruger', 'kenneth']
author_list += ["savitsky", "tamar", "kugler","gary", "bornstein", 'daniella', 'kupor', "letty","kwan"]
author_list += ["suhui", "chiu", 'kwong','¨hberger',"chak", "elizabeth"]
author_list += ["karam", "hollenbeck", 'klodiana', 'lanaj', 'lance','lance', "ferris", "shereen", "fatimah"]
author_list += ["ming", "lindie", "liang", "huiwen", "lian", "brown", "bart", "langhe", "stijn", "osselaer", "berend"]
author_list += ["wierenga", "andrea", "larney","amanda", "rotella" "barclay", 'kristin', 'laurin', 'frank']
author_list += ['schmidt', 'james', 'harter', 'kristy', "lauver",'david', 'lebel', "robyn",'leboeuf', 'eldar', 'shafir']
author_list += ['julia', 'belyavsky', "bayuk", "alice","daniel","ames", 'jooa', 'julia','fiona']
author_list += ['leelarissa','tiedens', "sunyoung", "marko", "pitesa", "pillutla", "stefan", "thau", 'whee',]
author_list += ["choi","seongsu", "alice", "loschelder", "martin", "schweinsberg", "malia", "mason", "tomã¡"]
author_list += ["lejarraga","cleotilde", "gonzalez", "geoffrey", "leonardelli", "geordie", "mcruer", "victoria", 'husted']
author_list += ["medvec", 'lepine',"sophie", "leroy", "sophie", "leroy","aaron","schmidt", "lisa"]
author_list += ['leslie', 'michele',"gelfand", 'levin','levin',"emma"]
author_list += ["levine","maurice","schweitzer", "emma","levine","kristina","wald", 'levine',"meng","gretchen","chapman","xilin","christopher","hsee"]
author_list += ["evans", "gilliland", "edgar", "jordan", "stein", "shaobo", 'kevin', "michail", "krishna", "savani", "huiwen",]
author_list += ["alicea", "lieberman","kristen","duke" "amir", "michael",'liersch', 'craig']
author_list += ["mckenzie", "katrina", "remus", "helen", "pluut", 'ying', "fern", "healy","deborah","small", 'lind',"friedman","ying"] 
author_list += ["hong", "peggy", "troy", "campbell", "fitzsimons"]
author_list += ["gráinne", "shalley", "sejin", "keem", "jing", "zhou", 'xiao', "ying", "hong", 'pong', "yongfang", "jiangli"]
author_list += ["jiao", "stefano", "livi", "arie", "kruglanski", "antonio", "pierro", "lucia", "mannetti", "kenny", "minson"]
author_list += ["robert", "lord", "paola", "gatti", "susanna", "chui", 'robert','lount','lount', "nathan"]
author_list += ["pettit", "sarah", "doyle", "jingyi","xiaofei", "jackson", "modupe", "akinola", "mason"]
author_list += ["shenghua", "luan","jochen", 'luce',"matthew", "lupoli", 'eric', "greenberg"]
author_list += ["nicholas','lurie', 'jayashankar','swaminathan", "brent","lyons","brent","scott"]
author_list += ['anyi',"anyi", "yang","krishna", "savani", 'macchi','robert','maccoun']
author_list += ["boris", "maciejovsky","david","budescu", "carl",'maertz', 'ahmad', 'hassan', 'peter']
author_list += ["magnusson", "vincent","amnon", "rapoport", "vincent","amnon", "rapoport","darryl"]
author_list += ["seale", "vincent", "rami", "zwick", "akshay", "jake", "pattaratanakun", "deepak', 'malhotra", "selin"]
author_list += ["malkoc", "zauberman", "bettman", 'mandel',"shannon", "marlow", "lacerenza", "jensine"]
author_list += ["paoletti", 'shawn', "burke", "eduardo", "salas", "marr", "thau", "karl", "aquino", "laurie", "barclay"]
author_list += ["ashley","martin","katherine","phillips", "martin", "bidhan", 'lalit', "parmar", "elena"]
author_list += ["martinescu", "onne", "janssen", "bernard", "nijstad", "malia",'mason', 'rebecca', 'dyer', 'michael']
author_list += ["norton", "pragya", "mathur", "shailendra", 'pratap', "jain", "meng", "hsieh", "charles", "lindsey"]
author_list += ["durairaj", "maheswaran", 'matsumoto',"david", 'mayer', 'maribeth', 'kuenzi', 'rebecca', 'greenbaum']
author_list += ['bardes', 'rommel', 'bombie', "salvador", "david", "kristina", "workman", "marius", "dijke", "linda", 'klebe']
author_list += ["treviño", "debra", "shapiro", "schminke", 'ketti', 'mazzocco', "matthew", 'mccarter', 'kevin', 'rockmann']
author_list += ['gregory', "northcraft", "mccarter", "jürgen", "scheffran", "julie", "mccarthy", "talya", "bauer", "truxillo"]
author_list += ["campion", "chad", "iddekinge", "campion", "mcelroy", "summers", "kelly", "todorov", "howard", "kunreuther"]
author_list += ['mckenzie',"craig", 'mckenzie', 'michael','liersch', 'ilan', "yaniv", "geeta"]
author_list += ['menon', 'ellie','kyung', 'nidhi', "agrawal", "tanya", "menon", "jeanne", "chiu", "hong", "christoph"]
author_list += ["merkle","martin", "weber", 'mesmer', "magnus", "dechurch", "miliani", 'jimenez', "rodriguez", "wildman"]
author_list += ["marissa", "shuffler", "kerry', 'milch', 'elke', 'weber', 'kirstin', 'appelt', 'michel', 'handgraaf', 'krantz"]
author_list += ["edward","miles","elizabeth","clenney", 'katherine','milkman', "milkman", "mary", 'carol']
author_list += ["mazza", "lisa", "chia", 'jung', "tsay", "kobe", "millet","lien", "lamey","bram", "bergh"]
author_list += ["andrew','miner', 'theresa','glomb", "julia", "vanepps", "ella", 'miron', "spektor","gerard"]
author_list += ["beenen", "ella", "spektor", "argote", "dorothee", "mischkowski", "lewisch", "himanshu", "mishra", "arul"]
author_list += ["rixom", "promothesh", "chatterjee", 'alexandra','mislin', "daniel", "mochon","shane", "frederick"]
author_list += ["susan", "mohammed","david","harrison", 'mohammed',"welmer", "molenmaker", "erik"]
author_list += ["molinsky", "margolis", 'marlon', 'mooijman', "celia", "moore","tenbrunsel", "sarah", "moore"]
author_list += ["neal", "baba", "shiv",'moore', 'moreland','morgan',"morris"]
author_list += ['jennifer','mueller', "laetitia","mulder","karl", "aquino", "laetitia", "mulder", "floor"]
author_list += ["rink", 'keith', "murnighan","long", "wang", 'brian','murtha', 'mussweiler']
author_list += ['nahrgang', 'frederick', 'morgeson', 'remus', "ilies", "nahrgang", "matthias", "spitzmuller", "jundt", "inbal"]
author_list += ['nahum', "shani","peter","bamberger", "nathaniel", "nakashima", "daniels", "laurin", "jayanth"]
author_list += ["narayanan","kenneth", "kinias", 'nederveen', "pieterse", "wendy", "ginkel", 'nelson','daniel','newark', "newark", "bohns"] 
author_list += ["francis", "flynn",'nglinn', 'dyne']
author_list += ["linn", "dyne","soon", "nicklin", "greenbaum", "laurel", "mcnall", "folger", "williams", "nicos"]
author_list += ['nicolaou', 'scott', 'shane', 'lynn', 'cherkas',"spector", "norton", "carney", 'laura','noval']
author_list += ["günter", "stahl", 'kathleen','’connorjosh','arnold', "burak", "diefendorff", "bashshur", "gary"]
author_list += ["greguras", 'ofir',"greg","oldham","yitzhak", "fried", 'madeline','ordo','overbeck', 'cassandra', "govan",'hweta','joydeep','srivastava', 'nevena']
author_list += ['koukova", "neeru', 'paharia', 'karim', 'kassam', 'joshua', 'greene', "bazerman", "neeru", "paharia", "rohit"]
author_list += ["deshpandé", 'mauricio', 'palmeira', "karthik", "panchanathan", "willem", "frankenhuis", "joan", "silk"]
author_list += ["guihyun", "park","richard","deshon", 'youn', "park","seongsu", "sung"]
author_list += ["shefali","patil",'david', "lebel", 'paulus',"craig", "pearce"]
author_list += ["wassenaar", "yair", "berson", "rivka", 'tuval', "mashiach", 'pearsall', 'aleksander', 'ellis', 'jordan', "stein"]
author_list += ['peng', 'pettibone','nathan', "doyle", "michel', 'tuan', 'pham', 'tamar', 'avnet"]
author_list += ["michel", 'tuan', "pham", 'faraji', "olivier", "toubia", "leonard", 'jean','phillips', 'david']
author_list += ["piercey", "nashita", "pillay", "guihyun", "park", 'kang', "sujin", "robin", "pinkley", "sawyer", "sleesman"]
author_list += ["vandewalle", "maribeth", "kuenzi", "marko", "timothy", "pleskac", "stephanie", "merritt", "schmitt"]
author_list += ["frederick", "oswald", "helen", "petru", "curşeu", "yukun", 'evan', 'polman', "evan", "polman"]
author_list += ['edward', "russo", "christine','porath', 'amir', 'erez", "posavac", "kardes", 'joško', "brakus", 'kenneth']
author_list += ['price', 'thomas', 'hall', 'kees', 'hunton', 'lovett', 'mark', 'tippett', "devon", "proudfoot","aaron"]
author_list += ["heather", "mann", "christina", "rader", "soll", "larrick", "joseph','radzevick','moore"]
author_list += ["joseph","radzevick","moore", "tage","daniel", "diermeier", 'rapoport', 'services', 'rettinger','anine', 'riege'] 
author_list += ["sacramento", "doris", "west", "sunita"]
author_list += ["moore","robert","maccoun", 'daniel','schwartz', 'elizabeth','keenan', 'alex','imas']
author_list += ['ayelet','gneezy', 'robert', 'sneddonr', 'duncan', 'luce', "antonios", "stamatogiannakis", "amitava"]
author_list += ["chattopadhyay", "dipankar", "chakravarti", 'stone','unknown', 'gabriel', 'szulanski']
author_list += ['francesca', 'gino', "christian", "¶ster", "ajay", "mehra", "knippenberg", 'chia', 'jung', 'tsay', 'michel']
author_list += ['tuan', 'pham','meyvisrongrong', 'zhou', 'venkatesh','weiss', 'cohen', 'konstantinidis']
author_list += ['speekenbrink', 'mharvey','windschitl','yaniv','zeelenberg']
author_list += ['ines', 'meyer','stuart','carr','lori', 'foster', 'joseph','allen','nale', 'lehmann']
author_list += ['willenbrock', 'steven', 'rogelberg', 'david', 'antons', 'mathieu', 'declerck', 'kathleen', 'diener', 'iring', 'koch']
author_list += ['frank', 'piller', 'kara', 'arnold', 'catherine', 'connelly', 'gellatly', 'megan', 'walsh', 'michael', 'withey']
author_list += ['susan', 'ashford', 'wellman', 'mary', 'sully', 'luque', 'katleen',  'stobbeleir', 'melody', 'wollan', 'blake']
author_list += ['ashforth', 'glen', 'kreiner', 'mark', 'clark', 'fugate', 'neal','ashkanasy', 'uqbweave', "neal", "ashkanasy"]
author_list += ['william', "becker", 'david', "waldman", 'oluremi', "ayoko", 'karen', "jehn", "soroush", "aslani", 'jimena']
author_list += ['ramirez', "marin", 'jeanne', "brett", 'jingjing', 'zhaleh', 'semnani', "azad", "zhang", "tinsley", 'laurie']
author_list += ["weingart", 'wendi', "adair", 'prasad', 'balkundi','wang','rajiv', 'kishore', "boris", "baltes", 'kevin']
author_list += ["wynne", 'mgrdich', "sirabian", 'daniel', "krenn", 'annet', "lange", 'sarah', 'bankins', 'george', 'banks', 'sven']
author_list += ['kepes', 'mahendra', 'joshi', 'anson', 'seers', 'larissa','barberchristopher','budnick', 'william','beckerrussell'] 
author_list += ['cropanzano', 'thomas', 'becker', 'guclu', 'atinc', 'james', 'breaugh', 'carlson', 'jeffrey']
author_list += ['edwards', 'paul', 'spector', 'terry','beehr', "terry", "beehr", 'jennifer', "ragsdale", 'jonathan']
author_list += ["kochert", 'peter', 'belmijeffrey', 'pfeffer', 'andrew', 'bennett', 'bakker', 'field', 'carmen', 'binnewies','sabine']
author_list += ['sonnentag', 'mojza', 'michal', 'bironmarc', 'veldhoven', 'douglas','bonettthomas','wright', "anthony"] 
author_list += ["boyce", 'levi', "nieminen", "gillespie", 'marie', "ryan", "denison", 'kimberley']
author_list += ['breevaart', 'evangelia', 'demerouti', 'daantje', 'derks', 'nicola', 'breugst', 'rebecca', 'preller', 'holger']
author_list += ['patzelt', 'dean', 'shepherd', 'roman', 'briker','frank', 'walter','michael','cole', 'robert', 'buch','bård', 'kuvaas']
author_list += ['anders', 'dysvik', "claudia", "buengeler", 'astrid', "homan", "voelpel",'travis']
author_list += ['maynard', 'deanna', 'kennedy', 'christian', 'resick', 'anne', 'burmeister', 'yixuan', 'wang', 'junqi', 'yanghua']
author_list += ['vantilborgh','joeri', 'hofmans','timothy','judge', 'olivia', 'byza', 'sebastian', 'schuh']
author_list += ['stefan', 'dörr', 'matthias', 'spörrle', 'günter', 'maier', 'paul', 'harveymarie', 'dasborough', 'francesco']
author_list += ['cangiano', 'sharon', 'parker', 'gillian', 'dawn', 'merideth', 'thompson', 'wayne', 'crawford', 'michele', 'kacmar']
author_list += ['abraham', 'carmeli', 'stephen', 'brammer', 'emanuel', 'gomes', 'shlomo', 'tarba', 'mark','martinkojeremy','mackey']
author_list += ['filipa', 'castanheira', 'fabrice', 'cavarretta', 'laura', 'trinchera', 'dong', 'choi', 'sean', 'hannah']
author_list += ['lucia', 'ceja', 'heesun', 'chae','jisung', 'park','choi', 'melissa', 'chamberlin', 'newton', 'jeffery']
author_list += ['lepine','ling', 'chang', "jennifer", 'chatman', 'caldwell', 'charles', "reilly", 'bernadette', 'doerr']
author_list += ["caldwell",  "reilly", "doerr", "david", "charles", "bernadette", "doerr", 'tingting', 'chen','kwok']
author_list += ['leung','fuli','zhanying','ying', 'chen', 'zhen', 'xiong', 'lifeng', 'zhong', 'jooyeon', 'xiujuan']
author_list += ['zhang', 'zhiqiang', 'daniel', 'ming', 'chngjoyce', 'cong', 'ying', 'wang', 'jaee', 'chomichael','morris']
author_list += ['jaepil', 'andrea', 'kyongji', 'seongmin', 'jong', 'park', 'bora', 'kwon','chun','kyoungmin','john','sosik','hyeok']
author_list += ['chung','choi','jing','peter','colemankatharina','kugler']
author_list += ['brizzi', 'catherine', 'matej', 'černe', 'anders', 'dysvik', 'miha', 'škerlavaj', 'samantha','conroynina']
author_list += ['gupta', 'samantha', 'conroy', 'christine', 'henle', 'lynn', 'shore', 'samantha', 'stelman', 'neil', 'conway']
author_list += ['clinton', 'jane', 'sturges', 'budjanovcanin', 'jose','cortina','cristina', 'costa', 'ashley', 'fulmer']
author_list += ['neil', 'anderson','services', 'marcus', 'credépeter','harms', 'jeffrey','cucinamichael','mcdaniel', 'carla', 'gomes'] 
author_list += ['costa','zhou','aristides','ferreira', 'jason','dahlingmelissa','gutworth', 'marie','dasborough', 'marie']
author_list += ['dasboroughpaul', 'harvey', "emily", "david", 'derek', "avery"]
author_list += ["witt", 'patrick', "mckay", 'sarah', 'dawkins', 'tian', 'alexander', 'newman', 'angela', 'martin', 'kevin', 'dawson']
author_list += ['kimberly', "brien", 'terry', 'beehr','meulenaere','christophe', 'boone','tine', 'buyl', 'frank']
author_list += ['daan', 'scheepers', 'naomi', 'ellemers', 'sassenberg', 'annika', 'scholl', 'nathalie', 'delobbe', 'helena', 'cooper']
author_list += ['thomas', 'roxane', 'hong', 'deng','frank', 'walter','yanjun', 'guan', 'lindsay', 'dhanani', 'amanda', 'main']
author_list += ['andrew', 'pueschel', 'rebekah', 'dibble', 'mihaela', 'dimitrova', 'angela','dionisijulian', 'barling', 'direnzo']
author_list += ['marco', 'greenhaus', 'weer', 'christy','stanislav','dobrevjennifer', 'merluzzi', 'yuntao', 'kathryn']
author_list += ['bartol', 'chenwei', 'danyang', 'derks', 'chang', 'erin', 'eatough', 'laurenz', 'meier', 'ivana', 'igic', 'achim']
author_list += ['elfering', 'spector', 'norbert', 'semmer', 'ludvig', 'levasseur', 'abbie', 'shipp', 'yitzhak', 'fried', 'denise']
author_list += ['rousseau', 'philip', 'zimbardo', 'silke', 'astrid', 'eisenbeissdaan', 'knippenberg', "robert", "eisenberger"]
author_list += ['mindy', 'krischer', "shoss", 'gökhan', "karagonlar", 'gloria', 'gonzalez', "morales", 'robert', "wickham", 'louis']
author_list += ["buffardi", 'gabi', 'eissascott','lester', 'liat', 'eldoritzhak', 'harpaz', 'pervez', 'ghauri', 'john', 'child']
author_list += ['simon', 'collinson','parker', 'ellen','kyle','emichli','olga', 'epitropaki', 'ilias']
author_list += ['kapoutsis', 'ellen', 'gerald', 'ferris', 'konstantinos', 'drivas', 'anastasia', 'ntotsi', 'miriam', 'erez','andrew']
author_list += ['cynthia','jinyan', 'fanlei','steven','farmerlinn', 'dyne', 'kayla', 'follmer']
author_list += ['isaac', 'emmanuel', 'sabat', 'rose', 'siuta', "marion", "fortin", 'irina', "cojuharenco", "patient", 'hayley']
author_list += ["german", 'katherine', 'frear', 'paustian', 'underdahl', 'eric', 'heggestad', 'lisa', 'slattery', 'walker','ashley']
author_list += ['fulmercheri', 'ostroff', 'marylène', 'gagné', 'khee', 'seng', 'benjamin', 'katrina', 'hosszu', 'xiaohan']
author_list += ['urhahn','torsten', 'biemann','stephen','jaros', 'patrick', 'raymund', 'garcia', 'prashant', 'bordia']
author_list += ['lloyd', 'restubog', 'valerie', 'caines', 'michele', 'gelfand', 'severance', 'tiane', 'bayan', 'bruss', 'janetta']
author_list += ['abdel', 'hamid', 'latif', 'asmaa', 'ahmed', 'moghazy', 'sally', 'moustafa', 'ahmed', 'sonia', 'ghumman','marie']
author_list += ['ryan','park', 'elisabeth', 'gilbert','trevor', 'foulk','joyce', 'bono', 'paula', 'giordano', 'patient']
author_list += ['margarida', 'passos', 'francesco', 'sguera', 'barry', 'goldmanrussell', 'cropanzano', 'ryan','gottfredsonherman']
author_list += ['aguinis', 'laura', 'goverlinda', 'duxbury', "alicia", "grandey", 'deborah', "rupp", "brice", 'rebecca']
author_list += ['greenbaum', 'mawritz', 'julena', 'bonner', 'brian', 'webster', 'joseph', 'truit', 'gray', 'mawritz', 'martin']
author_list += ['gubler', 'yves', 'guillaume', 'jeremy', 'lilian', 'otaye', 'ebede', 'woods', 'west', "naina", "gupta", 'violet']
author_list += ["pollack", 'felipe','guzmanalvaro', 'espejo', 'dana','haggardhee', 'park', 'daniel', 'halgin']
author_list += ['borgatti', 'ajay', 'mehra', 'scott', 'soltis', 'angela', 'hall', 'dwight', 'frink', 'ronald', 'buckley', 'jing']
author_list += ['hanjuan', 'ling', "sean", "hannah", "sumanth", "lester", 'fabrice', "cavarretta", 'crystal','haroldbrian','holtz']
author_list += ['brad', 'harris', 'teresa', 'cardador', 'cole', 'mistry', 'bradley', 'kirkman', 'paul', 'harveymarie','dasborough']
author_list += ['jeffrey', 'haynie', 'mossholder', 'stanley', 'harris','ryan', 'fehr','rong', 'long','design', 'unit', 'london']
author_list += ['school', 'economics', "guido", "hertel", 'cornelia']
author_list += ["rauschenbach", 'markus', "thielgen", "krumm", 'ivona', 'hideggerben','kleef', 'higginmo', 'gerard','hodgkinsonj']
author_list += ['kevin', 'ford', 'joeri', 'hofmans', 'edina', 'dóci', 'omar', 'solinger', 'woohee', 'timothy', 'judge']
author_list += ['anthony', 'hood', 'bachrach', 'suzanne', 'zivnuska', 'elliot', 'bendoly', 'annekatrin', 'hoppe', 'toker', 'vivian']
author_list += ['schachler', 'ziegler', 'matt','howardrick','jacobs', 'ryan', 'shuwei', 'hsujames','stanworth']
author_list += ['xiaoxiao', 'huseth', 'kaplan', 'xiaoxiao', 'hujunqi','xiaoxiao', 'yujie', 'zhan', 'xiang', 'garden','huang','dina']
author_list += ['krasikova','peter','harms', "ronald", "humphrey", 'blake', "ashforth", "diefendorff"]
author_list += ['samuel', 'hunter', 'lily', 'cushenbery', 'jayne', 'seulki', 'jang', 'winny', 'shen', 'tammy', 'haiyan', 'zhang']
author_list += ["peter", "jennings", "mitchell", "hannah", 'jaclyn', 'jensen', 'rubin', 'yuan', 'jiang','susan','jackson','saba']
author_list += ['colakoglu', 'zhou', 'jiang', 'xiaowen', 'zhongmin', 'xuan', 'jiang', 'gary', 'johnsraghid']
author_list += ['hajj', 'andrew','johnsonkatherine','roberto', 'kristen', 'jones', 'eden', 'king', 'afra', 'ahmad', 'tracy']
author_list += ['mccausland', 'tiffani', 'chen', "dustin", "jundt", 'jason', "huang", 'jvanrooyen', 'gökhan', 'karagonlar']
author_list += ['eisenberger', 'justin', 'aselage', 'olli', 'pekka', 'kauppila', 'steffen', 'kecklinda', 'babcock', 'stacey','kessler']
author_list += ['kaitlin', 'kiburz', 'french', 'yeol', 'kyoung', 'yong','robert', 'eisenberger','kibok']
author_list += ['baik', 'sooyeol','youngah', 'park','qikun','linn', 'dyne','stephanie','scott','kingfred','bryant', 'danielle']
author_list += ['king','alexander', 'newman','fred', 'luthans']
author_list += ['howard', 'klein', 'anne‐kathrin', 'kleine', 'cort', 'rudolph', 'hannes', 'zacher', 'petra', 'klumb', 'manuel']
author_list += ['voelkle', 'siegler', 'michaela', 'knecht', 'bettina', 'wiese', 'alexandra', 'freund', 'kniffin', 'jubo', 'wansink']
author_list += ['schulze', 'caroline', 'knight','malcolm', 'patterson','jeremy', 'dawson', 'young', 'kojin', 'choi']
author_list += ['dohyoung','kyootai','kailash', 'joshi', "jaclyn", "koopmann", 'klodiana', "lanaj", 'joyce']
author_list += ["bono", 'kristie', "campana", 'jörg', 'korff','torsten', 'biemann','sven','voelpel', 'kristof']
author_list += ['brown', 'young', 'seong', 'degeest', 'seung', 'hong', 'mukta', 'kulkarni', "kunze","florian","menges",'jochen']
author_list += ['florian', 'kunze','stephan','boehmheike', 'bruch', 'lauren', 'kuykendall','lydia']
author_list += ['craig','louis','letty', 'kwanchi', 'chiu', 'jana', 'kühnel','ronald', 'bledow','nicolas']
author_list += ['feuerhahn', 'catherine','frank', 'walter','huang', 'lance', 'frazier', 'christina', 'tupper']
author_list += ['stav', 'fainshmidt', 'laurent', 'lapierre', 'elianne', 'steenbergen', 'maria', 'peeters', 'esther', 'kluwer']
author_list += ['lapierre', 'laurent', 'yanhong', 'kwan', 'kwong', 'direnzo', 'shao', 'ping', 'james', 'lavelle', 'christopher', 'rupp']
author_list += ['herda', 'randall', 'hargrove', 'meghan', 'thornton', 'lugo', 'gary', 'mcmahan', 'allan','sara', 'willis','tian', 'seth']
author_list += ['kaplan', 'carol', 'wong', 'kwok', 'leungjie', 'wang', 'author', 'alexander', 'lewisjonathan', 'clark','yuan', 'zhang']
author_list += ['xiao', 'ming', 'tian', 'zhaoli', 'song', 'richard', 'arvey', 'junchao', 'jason','tyler','burch','thomas','bertolt']
author_list += ['meyer','meir', 'shemla','jürgen']
author_list += ['wegge', 'schaubroeck', 'anita', 'keller', 'junchao', 'jason', 'barnes', 'cristiano', 'guaranalin', 'wang', 'jian']
author_list += ['liang','crystal',  'farh','liaohui', 'chun', "chenwei", "liao", 'sandy', "wayne"]
author_list += ["rousseau", "weipeng", "wang", "wang", 'dirk', 'lindebaumdeanna', 'geddes', 'dirk', 'lindebaumpeter','jordan']
author_list += ['jukka', 'lipponen','barbara', 'wisse','jolanda', 'jetten', "songqi", 'aleksandra', "luksyte", "zhou",'leigh']
author_list += ['anne','jian', 'dong', 'zhang', 'subrahmaniam', 'tangirala', 'cynthia', 'parker', 'natalia','lorinkovasara']
author_list += ['jansen', 'perry', 'fuli', 'kwok', 'leung', 'krishna', 'savani', 'morris', 'aleksandra']
author_list += ['luksytechristiane', 'spitzmueller', 'aleksandra', 'luksyte', 'kerrie', 'unsworth', 'avery','luria', "luria"]
author_list += ['yuval', "kalish", 'miriam', "weinstein", 'luria', 'allon', 'kahana', 'judith', 'goldenberg', 'yair', 'noam']
author_list += ['jeremy', 'mackey', 'charn', 'mcallister', 'brees', 'huang', 'jack', 'carson', 'leticia', 'maia', 'antônio', 'virgílio']
author_list += ['bittencourt', 'bastos', 'nathanaël', 'solinger', "muhammad", 'abdur', 'rahman', "malik", 'arif', "butt", "choi"]
author_list += ['muhammad', 'malik', 'nazir', 'butt', "charles", "manz", 'bruce', "skaggs", 'craig', "pearce", "wassenaar"]
author_list += ["mark", "martinko", "harvey", "mackey", 'suzanne','masterson', 'courtney','mastersonjenny','hoobler', 'john']
author_list += ['mathieu', "fadel", 'matta', 'tuğba', 'erol', 'korkmaz', 'russell', 'johnson', 'pinar']
author_list += ["b𝚤çaks𝚤z", "korkmaz", "johnson", 'ella', 'miron', 'spektor', 'susannah', 'paletz', 'chun', 'rebecca']
author_list += ['mitchellbrendan', 'boyle', 'darya', 'moghimi', 'zacher', 'susanne', 'scheibe', 'nico', 'yperen', "tassilo", "momm"]
author_list += ['gerhard', "blickle", 'yongmei', 'andreas', "wihler", 'mareike', "kholin", 'jochen', "menges", 'francesco']
author_list += ['montani','massimo', 'maoret','lucas', 'dufour', 'diego', 'montano', 'anna', 'reeske', 'franziska', 'franke']
author_list += ['joachim', 'hüffmeier', 'frank','ramona', 'bobocel', 'michael','mumfordyitzhak', 'fried', 'timothy','munyonrachel']
author_list += ['kane', 'frieder', 'charles', 'murnieks', 'anthony', 'klotz', 'teresa', 'müllercornelia']
author_list += ['niessen', 'mohamed', 'ikram', 'nasr', 'assâad', 'akremi', 'jacqueline', 'coyle', 'shapiro', "eitan", "naveh",'katz']
author_list += ["navon","stern", 'thomas','nglorenzo', 'lucianetti', 'jessica','nicklinpaul','spector', 'cornelia', 'niessen', 'müller']
author_list += ['sabine', 'hommelhoff', 'mina', 'westman', 'karen', 'nivenluke']
author_list += ['boorman', 'norton', 'stacey', 'neal', 'ashkanasy', 'rikki', 'nouri', 'erez', 'jian', 'liang', 'brendan', 'bannister']
author_list += ['warren', 'chiu', 'kimberly',"brienterry",'beehr', 'jane', "learyjörgen", 'sandberg', 'anna', 'carmella']
author_list += ['ocampo', 'kohyar', 'kiazad', 'jacoba', 'oedzes', 'gerben', 'vegt', 'floor', 'rink', 'walter', 'florian', 'offergelt']
author_list += ['klaus', 'moser', 'shaw','brian', 'holtz','seongsu','sandra', 'ohly','sabine', 'sonnentag','franziska', 'pluntke', 'hakan']
author_list += ['ozcelik', 'youngah', 'parkverena','haun', 'youngah']
author_list += ['parkjustin','sprung', "vesa", "peltokorpi", "allen", 'fabian', "froese","pengdongkyu",'chunyan', 'pengwei', 'zeng']
author_list += ['mark','petersontais', 'siqueira', 'barreto', 'mark', 'edward', 'pickering']
author_list += ['matthew','piszczek', 'pollack', 'ernest', "boyle", 'corinne', 'post', 'roman', 'prem', 'sandra', 'ohly']
author_list += ['kubicek', 'korunka', 'manuela', 'priesemuthregina','taylor', 'alexander', 'pundtlaura', 'venz', 'minya', 'duan']
author_list += ["yilong", "direnzo", 'yilong', "duan", 'jennifer','ragsdaleterry','beehr', 'stefan', 'razinskasmartin']
author_list += ['hoegl', 'young', 'rheejin', 'choi', 'kirsten', 'robertsonjane', "reilly", 'mark','roehlingjason', 'huang']
author_list += ['jade', 'talbot', 'alex', 'rubenstein', 'kammeyer', 'mueller', 'tomas', 'thundiyil', 'jörgen', 'sandbergharidimos']
author_list += ['tsoukas', 'carsten','schermulybertolt', 'meyer', "pauline", "schilpzand", 'irene', "pater", 'amir', "erez"]
author_list += ['benjamin', 'schneider', 'allison', 'yost', 'kropp', 'cory', 'kind', 'holly', 'jeremy','schoen', 'selenko','mäkikangas']
author_list += ['stride','shan','joshua', 'keller','damien', 'joseph', 'ping']
author_list += ['shao','andrew','mary', 'mawritz', "meir", "shemla", 'bertolt', "meyer", 'lindred', "greer", 'shung']
author_list += ['shin','feirong', 'yuan','jing', 'zhou', 'shockley', 'heather', 'ureksoy', 'ozgun', 'burcu', 'rodopman']
author_list += ['poteat', 'ryan', 'dullaghan', 'shoham','almor','smahammad','jost']
author_list += ['siewekebin', 'zhao', 'barjinder', 'singh', 'margaret', 'shaffer', 'selvarajan', 'adam', 'smale', 'silvia', 'bagdadli']
author_list += ['rick', 'cotton', 'dello', 'russo', 'dickmann', 'martina', 'gianecchini', 'kaše', 'mila', 'lazarova', 'reichel', 'rozo']
author_list += ['marijke', 'verbruggen', 'ifedapo', 'adeleye', 'maike', 'andresen', 'eleni', 'apospori', 'olusegun', 'babalola']
author_list += ['briscoe', 'seok', 'katharina', 'chudzikowski', 'nicky', 'dries', 'petra', 'eggenhofer', 'rehart', 'zhangfeng']
author_list += ['martin', 'gubler', 'douglas', 'svetlana', 'khapova', 'najung', 'evgenia', 'lysova', 'sergio', 'madero', 'debbie']
author_list += ['mandel', 'wolfgang', 'mayrhofer', 'biljana', 'bogićević', 'milikić', 'sushanta', 'kumar', 'mishra', 'chikae', 'naito']
author_list += ['emma', 'parry', 'noreen', 'saher', 'richa', 'saxena', 'nanni', 'schleicher', 'florian', 'schramm', 'pamela', 'mami']
author_list += ['taniguchi', 'julie', 'unite']
author_list += ["bryan", "acton","roseanne", "foti", "robert", "lord", "jessica", "gladfelter", "mats"]
author_list += ["alvesson","katja", "einola", 'steina', 'jantonak', "john", "antonakis", "samuel", "bendahan", "philippe"]
author_list += ["jacquart", "rafael", "lalive", "george", "banks", "nicolas", "bastardoz", "michael", "cole", "david","alice"]
author_list += ["eagly", "olga", "epitropaki"]
author_list += ["william", "gardner", 'alexander', "haslam", "hogg", "ronit"]
author_list += ["kark", "kevin", "lowe", "philip", "podsakoff", "seth", "spain", "janka", "stoker", "niels", "quaquebeke"]
author_list += ["mark", "vugt", "dusya", "vera", "roberto", "weber", "nicolas", "bastardoz","mark", "vugt", 'stephane']
author_list += ['brutus', 'shawn', 'burke', 'dana', 'sims', 'elizabeth', 'lazzara', 'eduardo', 'salas', 'abraham', 'carmeli']
author_list += ['meyrav', 'yitzack', 'halevi', "david", "carrington", "combe", "mumford", 'jingnan', 'chen', "minyoung", "cheong"]
author_list += ["francis", "yammarino", "shelley", "dionne", "chou", "tsai",'cheng', "steve","shin", 'guang']
author_list += ["liang", "amon", "chizema","ganna", "pogrebna", 'neil', 'stewart', "joseph", "crawford",'anne', "kelder", "stéphane"]
author_list += ["côté", "paulo", "lopes", "peter", "salovey", "christopher", "miners"]
author_list += ['uqbweave', 'david',"david", "hock", 'peng',"belle", "derks","colette", "laar","naomi", "ellemers", 'shelley', 'dionne']
author_list += ['yvonne', 'budden', 'nathan',"bassam", "farah", "rida"]
author_list += ["elias", "cristine", "clercy", "glenn", "rowe", 'christopher', 'watkins', "louis", "sean", "hannah", "noel"]
author_list += ["fred", "walumbwa", "zachary", "garfield", "rueden", "edward", "hagen", 'geys', 'steffen', 'giessner']
author_list += ['daan', 'knippenberg', 'sleebos', "laura", "giurge", "marius", "dijke", "michelle", "zheng", "cremer", 'design']
author_list += ['unit', 'london', 'school', 'economics','activepdf', 'kelly', 'hannum', "anna", 'luca', "heimann"]
author_list += ["ingold", "martin", "kleinmann", "nathan", "hiller", "hock", 'peng', "ajay", "ponnapalli", "sibel", "ozgen"]
author_list += ['crystal', 'hoyt', 'stefanie', 'johnson', 'susan', 'elaine', 'murphy', 'kerry', 'hogue', 'skinnell', 'hendrik']
author_list += ['huettermann', 'sebastian', 'doering', 'sabine', 'boerner', "hughes", "allan", "tian", "alex", "newman", "alison"]
author_list += ["legood", 'center', 'applied', 'social', 'research', 'dongil', 'jung', 'francis', 'yammarino',"thomas"]
author_list += ["kelemen", "matthews", "kimberley", "breevaart", 'michael', 'kosfeld', "lindie", "liang", "douglas", "brown"]
author_list += ["huiwen", "lian", "hanig", 'lance', "ferris", "lisa", "keeping", "jukka", "lipponen", "janne", "kaltiainen"]
author_list += ["werff", "niklas", "steffens", "jeffrey", "lovelace", "brett", "neely", "julian", "allen", "hunter"]
author_list += ['bourgoin', "charles", "reilly", "bernadette", "doerr", "caldwell", "jennifer", "chatman", "reilly"]
author_list += ['dawn', 'eubanks', "philip", "podsakoff","nathan", "podsakoff", "therese", "reitan","sten"]
author_list += ["stenberg", 'chester', 'schriesheim', 'joshua', 'terri', 'scandura', 'jeroen', 'staff', "maria"]
author_list += ["tims", "arnold", "bakker", "despoina", "xanthopoulou", "chou", "tsai", 'chih', "wang", 'shiuan', "cheng"]
author_list += ["herman","huang","wing",'hardin','kragt','djohnston', 'billings']
author_list += ["fred", "walumbwa", "peng", "john", "schaubroeck", "bruce", "avolio", 'user', "philip", "yang"]
author_list += ["riepe", "katharina", "moser", "kerstin", "pull", "siri", "terjesen", "christian", "zehnder", "holger"]
author_list += ["herz", "jean", 'philippe', "bonardi", 'school', 'business', 'msmhh']
author_list += ['ambika', 'ambika', 'natalie', 'allen', 'tracy', 'hecht', 'neil', 'anderson', 'sarah', 'sleap', 'nikos']
author_list += ['bozionelos', 'adam', 'butler', 'amie', 'skattebo', 'john', 'cordery', 'kevin', 'daniels', 'claire', 'harris']
author_list += ['briner', 'taru', 'feldt', 'mika', 'kivimaumlki', 'anne', 'rantala', 'asko', 'tolvanen', 'donald', 'gardner']
author_list += ['linn', 'dyne', 'pierce', 'filip', 'lievens', 'frederik', 'anseel', 'adam', 'meade', 'james', 'meindl']
author_list += ['paul', 'paulus', 'karen', 'charlie', 'reeve', 'eric', 'heggestad', 'astrid', 'richardsen','zhao','zhou','jing']
author_list += ['monica', 'martinussen', 'anit', 'somech', 'anat', 'drach', 'zahavy', 'gigi', 'sutton', 'mark', 'griffin']
author_list += ['william', 'turnley', 'mark', 'bolino', 'scott', 'lester', 'james', 'bloodgood', 'joan', 'horn', 'toon', 'taris']
author_list += ['wilmar', 'schaufeli', 'paul', 'schreurs', 'fred', 'walumbwa', 'peng', 'wang', 'john', 'lawler']
author_list += ['michael', 'west', 'felix', 'brodbeck', 'andreas', 'richter', 'mark', 'wilson', 'david', 'dejoy']
author_list += ['robert', 'vandenberg', 'hettie', 'richardson', 'allison', 'mcgrath', 'ambika','david','micheal']
author_list += ['elena','belogolovsky','peter','bamberger','karlene','roberts','chris','bingham','campbell','seung','hwan','jeong','scott','graffin']
author_list += ['robert','messen','andrew','carton','brice','roberts','dattée','oliver','alexy','erkko','autio','sreedhari','desai','patricio']
author_list += ['duran','nadine','kammerlander','marc','essen','thomas','zellweger','john','joseph','wshong','gokhan','ertug','tamar','yogev']
author_list += ['yonghoon','lee','peter','hedström','kibler','ewald','markus','perkmann','brenda','flannery','douglas','michael','florin','lubatkin']
author_list += ['william','schulze','raghu','garud','sanjay','jain','arun','kumaraswamy','gerard','george','christopher','corbishley','jane','khayesi']
author_list += ['martine','haas','laszlo','tihanyi','wakenshaw','gibbons','deborah','brian','gunia','joo','hun','han','saehee','kang']
author_list += ['rebecca','kehoe','david','lepak','hausknecht','nathan','hiller','robert','vance','hitt','tina','dacin','edward','levita']
author_list += ['jean','arregle','luc','anca','borza','fmurray','philippe','jacquart','antonakis','jason','jay','fuller','elfenbeinh','cynthia']
author_list += ['kim','jensen','lorraine','crystal','hkpu','margaret','luciano','amy','bartels','lauren','innocenzo','travis','maynard','mathieu']
author_list += ['hardy','smagui','johanna','mair','ignasi','marti','marc','ventresca','dellring','jcarson','mmcardle','erez','mia','mathieu']
author_list += ['monin','niels','noorderhaven','eero','vaara','kroon','jeroen','neckebrouck','gina','dokko','lisa','hisae','nishii','sonja']
author_list += ['opper','donde','ashmos','plowman','lakami','baker','tammy','beck','mukta','kulkarni','stephanie','solansky','deandra','villarreal']
author_list += ['ridge','ingram','aaron','hill','bloy','drew','harry','dwight','lemke','richard','dino','staf','guillaume','soenen']
author_list += ['tessa','melkonian','maureen','ambrose','evans','bennett','tepper','nikolaos','dimotakis','schurer','lambert','joel','koopman','fadel']
author_list += ['matta','hee','man','park','wongun','goo','tepper','varkey','titus','owen','parker','francesca','gino','bass']
author_list += ['erin','charlie','trevor','home','computer','martins','martín','esmt','european','varkey','gmbh','cwbauman','school','francesca','gino','bass']

# %%
# Function to filter out the stopwords and authors names
def filterWords(msg, words):
    m = msg.split(' ')
    words_end = [w + '.' for w in words]
    filtered_words = list(filter(lambda word: word not in words, m))
    filtered_words = [(w if w not in words_end else '.') for w in filtered_words]
    result = ' '.join(filtered_words)
    return(result)

# %%
data_proc_auth = [filterWords(f, author_list) for f in pdf_p]

# %%
#data_proc_auth[2]

# %%
stopwords = ['a', 'about', 'above', 'across', 'after', 'afterwards']
stopwords += ['again', 'against', 'all', 'almost', 'alone', 'along']
stopwords += ['already', 'also', 'although', 'always', 'am', 'among']
stopwords += ['amongst', 'amoungst', 'amount', 'an', 'and', 'another']
stopwords += ['any', 'anyhow', 'anyone', 'anything', 'anyway', 'anywhere']
stopwords += ['are', 'around', 'as', 'at', 'back', 'be', 'became']
stopwords += ['because', 'become', 'becomes', 'becoming', 'been']
stopwords += ['before', 'beforehand', 'behind', 'being', 'below']
stopwords += ['beside', 'besides', 'between', 'beyond', 'bill', 'both']
stopwords += ['bottom', 'but', 'by', 'call', 'can', 'cannot', 'cant']
stopwords += ['co', 'computer', 'con', 'could', 'couldnt', 'cry', 'de']
stopwords += ['describe', 'detail', 'did', 'do', 'done', 'down', 'due']
stopwords += ['during', 'each', 'eg', 'eight', 'either', 'eleven', 'else']
stopwords += ['elsewhere', 'empty', 'enough', 'etc', 'even', 'ever']
stopwords += ['every', 'everyone', 'everything', 'everywhere', 'except']
stopwords += ['few', 'fifteen', 'fifty', 'fill', 'find', 'fire', 'first']
stopwords += ['five', 'for', 'former', 'formerly', 'forty', 'found']
stopwords += ['four', 'from', 'front', 'full', 'further', 'get', 'give']
stopwords += ['go', 'had', 'has', 'hasnt', 'have', 'he', 'hence', 'her']
stopwords += ['here', 'hereafter', 'hereby', 'herein', 'hereupon', 'hers']
stopwords += ['herself', 'him', 'himself', 'his', 'how', 'however']
stopwords += ['hundred', 'i', 'ie', 'if', 'in', 'inc', 'indeed']
stopwords += ['interest', 'into', 'is', 'it', 'its', 'itself', 'keep']
stopwords += ['last', 'latter', 'latterly', 'least', 'less', 'ltd', 'made']
stopwords += ['many', 'may', 'me', 'meanwhile', 'might', 'mill', 'mine']
stopwords += ['more', 'moreover', 'most', 'mostly', 'move', 'much']
stopwords += ['must', 'my', 'myself', 'name', 'namely', 'neither', 'never']
stopwords += ['nevertheless', 'next', 'nine', 'no', 'nobody', 'none']
stopwords += ['noone', 'nor', 'not', 'nothing', 'now', 'nowhere', 'of']
stopwords += ['off', 'often', 'on','once', 'one', 'only', 'onto', 'or']
stopwords += ['other', 'others', 'otherwise', 'our', 'ours', 'ourselves']
stopwords += ['out', 'over', 'own', 'part', 'per', 'perhaps', 'please']
stopwords += ['put', 'rather', 're', 's', 'same', 'see', 'seem', 'seemed']
stopwords += ['seeming', 'seems', 'serious', 'several', 'she', 'should']
stopwords += ['show', 'side', 'since', 'sincere', 'six', 'sixty', 'so']
stopwords += ['some', 'somehow', 'someone', 'something', 'sometime']
stopwords += ['sometimes', 'somewhere', 'still', 'such', 'system', 'take']
stopwords += ['ten', 'than', 'that', 'the', 'their', 'them', 'themselves']
stopwords += ['then', 'thence', 'there', 'thereafter', 'thereby']
stopwords += ['therefore', 'therein', 'thereupon', 'these', 'they']
stopwords += ['thick', 'thin', 'third', 'this', 'those', 'though', 'three']
stopwords += ['three', 'through', 'throughout', 'thru', 'thus', 'to']
stopwords += ['together', 'too', 'top', 'toward', 'towards', 'twelve']
stopwords += ['twenty', 'two', 'un', 'under', 'until', 'up', 'upon']
stopwords += ['us', 'very', 'via', 'was', 'we', 'well', 'were', 'what']
stopwords += ['whatever', 'when', 'whence', 'whenever', 'where']
stopwords += ['whereafter', 'whereas', 'whereby', 'wherein', 'whereupon']
stopwords += ['wherever', 'whether', 'which', 'while', 'whither', 'who']
stopwords += ['whoever', 'whole', 'whom', 'whose', 'why', 'will', 'with']
stopwords += ['within', 'without', 'would', 'yet', 'you', 'your']
stopwords += ['yours', 'yourself', 'yourselves']
stopwords += ['january', 'february', 'march', 'february', 'march', 'april', 'may', 'june', 'july', 'august', 'september', 'october', 'november', 'december']
# metadata- subject
stopwords += ['business administration', 'economics and finance']
# author name to remove
stopwords +=['karina nielsen','kevin daniels','elaine', 'jaewan yang','andrew O herdman','amanda', 'sabine','kerstin','kertin','sagepub','journalspermissions','catheine','chidiebere ogbonnaya','john wiley','sons ltd','martin','jeffrey B arthur']

# %%
data_proc = [filterWords(f, stopwords) for f in data_proc_auth]

# %% [markdown]
# # Get country name

# %%
import pycountry

country_list = []
for country in pycountry.countries:
    a = (country.name).lower()
    country_list.append(a)

# %%
data_proc_country =[] 
for j in data_proc:
    line = j
    for k in country_list:
        line = re.sub(k, '', line)
        
    data_proc_country.append(line)

# %%
data_proc_country[2]
# Out:
# 'contents lists available sciencedirect journal homepage elsevier locate obhdp matter elsevier . rights reserved.http . obhdp. corresponding . mail addresses abeles miamioh .abele stassegl miamioh .stasser cchartie ashland .chartier . present address ashland university department psychology miami university department psychology avenue oxford article history received accepted available online accepted keywords decision making tacit coordination group processes focal point theory predicts matching people search shared characteristic makes decision option salient mismatching search complementary characteristics make different options salient coordinating parties. studies participants learned partner activity preferences tried match mismatch choices series pictures remotely associated preferences.being relevant preference facilitated matching different facilitated mismatching. second study participants used overall perceived similarity supplement specific trait information.coordination performance affected interpersonal impressions successful matching increased interpersonal attraction successful mismatching .these downstream effects obtained participants considerable prior information partners.tacit coordination compared mimicry synchrony implications coordinated team performance discussed. elsevier . rights reserved.introduction interdependence theory kelley thibaut kelley thibaut kelley asserts consequences actions frequently depend . broad categories interdependencies afford coordinated solution . coordination interacting parties interests correspondent combinations choices.focal points emergent solutions coordination problems mehta starmer sugden schelling .although focal points characterized conspicuous prominent salient options decision space argue emergent solutions coordination problems depend relationship characteristics actors decision options.even interests correspondent successful coordination difficult achieve particularly people explicitly communicate coordination tacit.whether negotiating traffic collaborating colleagues completing household chores coordination essential successful interactions. review distinction matching mismatching problems .next review concept focal point schelling applies matching mismatching coordination. outline theory focal points summarize supporting evidence theory existing studies. current examined critical features theory repeated interactions actors extensive knowledge other.study examined proposition actors search useful cues array information rely repeated interactions feedback develop coordination. identify focal point based shared knowledge. second study contrasted kinds knowledge used defining focal points generalized impression similarity versus knowledge specific trait associated choices coordination task.both studies address idea coordination affects subsequent knowledge form interpersonal impressions . sense street knowledge coordination.distinction matching mismatching distinguished types coordination problems bramoullé .matching problems require actors choose action successful coordination friends trying meet mall.mismatching problems require actors choose different actions successful coordination.past used primarily matching games mehta mismatching problems encountered life. example cleaning crew efficient members avoid dusting desk domestic http crossmark crossref dialog . obhdp.domain http . obhdp.mailto abeles miamioh mailto stassegl miamioh mailto cchartie ashland http . obhdp.http sciencedirect science journal http elsevier locate obhdp overall pattern results studies reported . support patterns predicted focal point hypothesis findings strong expect searching cues dominant strategy solving coordination problems. example study participants choose typical choice told playing partner.thus matched typical choice time randomly selected partner.given gender information available study chance match expect active information yield higher success rate. .abele . partners benef ...

# %%
# save removed title
pickle.dump(data_proc_country, open( "C:/Thesis/Data/save/Organizational_behavior_and_HDP/metadata/removed_country/metadata_all.p", "wb" ) )

# %%
# Authors names are saved already (code is available at author name folder-get name list notebook)
#load authors names
import pickle
author_nam = pickle.load(open("C:/Thesis/Data/save/Master_Data/auth_ref_filter_num_char/auth_Organizational_behavior_and_HDP.p", "rb"))

# %%
# GET REFERENCE LISTS OF STOPWORDS, I.E. WORDS THAT ARE ESSENTIALLY MEANINGLESS
# Get all the list of authors names

from nltk.corpus import stopwords

sw = stopwords.words('english') + author_nam

# %%
data_proc_1 = [filterWords(f, sw) for f in data_proc_country] # running

# %%
data_proc_1[2]
# Out:
# 'contents lists available sciencedirect journal homepage elsevier locate obhdp matter elsevier . reserved.http . obhdp. corresponding . mail addresses abeles miamioh .abele stassegl miamioh .stasser cchartie ashland .chartier . present address ashland miami avenue article history received accepted available online accepted keywords tacit coordination processes focal point theory predicts matching people search shared characteristic makes option salient mismatching search complementary characteristics make different options salient coordinating parties. studies participants learned partner activity preferences tried match mismatch series pictures remotely preferences.being relevant preference facilitated matching different facilitated mismatching. study participants used overall perceived similarity supplement specific trait information.coordination performance affected interpersonal impressions successful matching increased interpersonal attraction successful mismatching .these downstream effects obtained participants considerable prior information partners.tacit coordination compared mimicry synchrony implications coordinated performance discussed. elsevier . reserved.introduction interdependence theory asserts consequences actions frequently depend . broad categories interdependencies afford coordinated solution . coordination interacting parties interests correspondent combinations choices.focal points emergent solutions coordination problems .although focal points characterized conspicuous prominent salient options space argue emergent solutions coordination problems depend relationship characteristics actors options.even interests correspondent successful coordination difficult achieve particularly people explicitly communicate coordination tacit.whether negotiating traffic collaborating colleagues completing household chores coordination essential successful interactions. review distinction matching mismatching problems .next review concept focal point applies matching mismatching coordination. outline theory focal points summarize supporting evidence theory existing studies. current examined critical features theory repeated interactions actors extensive knowledge other.study examined proposition actors search useful cues array information rely repeated interactions feedback develop coordination. identify focal point based shared knowledge. study contrasted kinds knowledge used defining focal points generalized impression similarity versus knowledge specific trait coordination task.both studies address idea coordination affects subsequent knowledge form interpersonal impressions . sense knowledge coordination.distinction matching mismatching distinguished types coordination problems .matching problems require actors choose action successful coordination trying meet mall.mismatching problems require actors choose different actions successful coordination.past used primarily matching mismatching problems encountered life. example cleaning crew efficient members avoid dusting desk domestic crossmark crossref dialog . obhdp.domain . obhdp.mailto abeles miamioh mailto stassegl miamioh mailto cchartie ashland . obhdp.http sciencedirect journal elsevier locate obhdp overall pattern results studies reported . support patterns predicted focal point findings expect searching cues dominant strategy solving coordination problems. example study participants choose typical told playing partner.thus matched typical randomly selected partner.given gender information available study match expect active information yield higher success rate. .abele . partners benefit stop store milk work.social knowledge preferences attitudes past behavior expectations future behavior.however usefulness knowledge depends coordination requirements match mismatch.focal points constructs focal point theory trying meet fountain likely chosen options examples . fountain uniquely different structural features shops multiple entries parking lots .however coordi ...

# %%
data_proc_2 = [re.sub(' \.+', ' ', f) for f in data_proc_1]
data_proc_2 = [re.sub(' +', ' ', f) for f in data_proc_2]
data_proc_2 = [re.sub('http', '', f) for f in data_proc_2]
data_proc_2 = [re.sub('www', '', f) for f in data_proc_2]
data_proc_2 = [re.sub('iweb', '', f) for f in data_proc_2]
data_proc_2 = [re.sub(' +', ' ', f) for f in data_proc_2]

# %%
data_proc_2[2]
# Out:
# 'contents lists available sciencedirect journal homepage elsevier locate obhdp matter elsevier reserved. obhdp. corresponding mail addresses abeles miamioh abele stassegl miamioh stasser cchartie ashland chartier present address ashland miami avenue article history received accepted available online accepted keywords tacit coordination processes focal point theory predicts matching people search shared characteristic makes option salient mismatching search complementary characteristics make different options salient coordinating parties. studies participants learned partner activity preferences tried match mismatch series pictures remotely preferences.being relevant preference facilitated matching different facilitated mismatching. study participants used overall perceived similarity supplement specific trait information.coordination performance affected interpersonal impressions successful matching increased interpersonal attraction successful mismatching these downstream effects obtained participants considerable prior information partners.tacit coordination compared mimicry synchrony implications coordinated performance discussed. elsevier reserved.introduction interdependence theory asserts consequences actions frequently depend broad categories interdependencies afford coordinated solution coordination interacting parties interests correspondent combinations choices.focal points emergent solutions coordination problems although focal points characterized conspicuous prominent salient options space argue emergent solutions coordination problems depend relationship characteristics actors options.even interests correspondent successful coordination difficult achieve particularly people explicitly communicate coordination tacit.whether negotiating traffic collaborating colleagues completing household chores coordination essential successful interactions. review distinction matching mismatching problems next review concept focal point applies matching mismatching coordination. outline theory focal points summarize supporting evidence theory existing studies. current examined critical features theory repeated interactions actors extensive knowledge other.study examined proposition actors search useful cues array information rely repeated interactions feedback develop coordination. identify focal point based shared knowledge. study contrasted kinds knowledge used defining focal points generalized impression similarity versus knowledge specific trait coordination task.both studies address idea coordination affects subsequent knowledge form interpersonal impressions sense knowledge coordination.distinction matching mismatching distinguished types coordination problems matching problems require actors choose action successful coordination trying meet mall.mismatching problems require actors choose different actions successful coordination.past used primarily matching mismatching problems encountered life. example cleaning crew efficient members avoid dusting desk domestic crossmark crossref dialog obhdp.domain obhdp.mailto abeles miamioh mailto stassegl miamioh mailto cchartie ashland obhdp. sciencedirect journal elsevier locate obhdp overall pattern results studies reported support patterns predicted focal point findings expect searching cues dominant strategy solving coordination problems. example study participants choose typical told playing partner.thus matched typical randomly selected partner.given gender information available study match expect active information yield higher success rate. abele partners benefit stop store milk work.social knowledge preferences attitudes past behavior expectations future behavior.however usefulness knowledge depends coordination requirements match mismatch.focal points constructs focal point theory trying meet fountain likely chosen options examples fountain uniquely different structural features shops multiple entries parking lots however coordination problems alternative structurally uniq ...

# %%
# save data
pickle.dump(data_proc_2, open( "C:/Thesis/Data/save/Master_Data/MD_4/data_proc_latest/org_B_and_HDP_data_proc.p", "wb" ) )

# %%
#import io
with open("C:/Thesis/Data/save/Master_Data/MD_4/data_proc_latest/org_B_and_HDP_data_proc_txt.txt", "w",encoding="utf-8") as outfile:
    for i in range(len(data_proc_2)):
        outstring = ""
        outstring += str(data_proc_2[i])
        outfile.write(outstring)
